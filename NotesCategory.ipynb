# %%
import pandas as pd

# %%
df=pd.read_csv("Merge_Proccessed.csv")
df.columns
# Out:
# Index(['Transaction Date', 'Value Date', 'Description',
#        'Reference No./Cheque No.', 'Debit', 'Credit', 'Balance',
#        'Transaction Type', 'Transaction Mode', 'DR/CR Indicator',
#        'Transaction ID', 'Recipient Name', 'Bank', 'UPI ID', 'Note'],
#       dtype='object')

# %%
df.shape
# Out:
# (741, 15)

# %%
# df=df[['Description','Recipient Name','UPI ID','Note']]

# %%
company_keywords={
  "McDonald's": ["mcdonald", "mcd", "mc donalds"],
  "BurgerKing": ["burgerking", "burger king", "burgerkingindia"],
  "Dominos": ["dominos", "domino's"],
  "PizzaHut": ["pizzahut", "pizza hut"],
  "KFC": ["kfc", "kentucky fried chicken"],
  "Subway": ["subway sandwiches", "subway"],
  "Starbucks": ["starbucks", "starbucks coffee"],
  "JumboKing": [ "jumboki"],
  "Cafe Coffee Day": ["ccd", "cafe coffee day"],
  "Haldiram's": ["haldiram", "haldirams"],
  "Baskin Robbins": ["baskin robbins", "baskinrobbins"],
  
  "Swiggy": ["swiggy"],
  "Zomato": ["zomato"],
  "Dunzo": ["dunzo"],
  "Zepto": ["zepto"],
  "BigBasket": ["bigbasket", "big basket"],
  "Blinkit": ["blinkit", "grofers"],

  "Amazon": ["amazon", "amazon pay"],
  "Flipkart": ["flipkart"],
  "Myntra": ["myntra"],
  "Nykaa": ["nykaa"],
  "Ajio": ["ajio"],
  "Tata Cliq": ["tata cliq", "tatacliq"],
  "Reliance Digital": ["reliance digital"],
  "Croma": ["croma"],
  "Vijay Sales": ["vijay sales"],
  "Snapdeal": ["snapdeal"],
  "FirstCry": ["firstcry"],
  "Pepperfry": ["pepperfry"],

  "Netflix": ["netflix"],
  "Hotstar": ["hotstar", "disney hotstar"],
  "Amazon Prime": ["amazon prime", "prime video"],
  "Tata Sky": ["tatasky"],
  "Airtel DTH": ["airtel dth"],
  "Jio Cinema": ["jio cinema", "jio tv"],
  "BookMyShow": ["bookmyshow", "bms"],
  "SonyLIV": ["sonyliv"],
  "Zee5": ["zee5"],
  "Spotify": ["spotify"],
  "Apple Music": ["apple music"],
  "Gaana": ["gaana"],
  "Wynk Music": ["wynk music"],

  "Airtel": ["airtel", "airtelpay", "bharti a", "bhartia"],
  "Vodafone": ["vodafone", "vodapay", "vi india"],
  "Jio": ["jio", "reliance jio"],
  "BSNL": ["bsnl", "bharat sanchar nigam"],
  "ACT Fibernet": ["act fibernet", "act internet"],
  "Hathway": ["hathway", "hathway broadband"],
  "Spectra": ["spectra", "spectra internet"],

  "Uber": ["uber"],
  "Rapido": ["rapido"],
  "RedBus": ["redbus"],
  "MumbaiMetro": ["mumbaim","mumbai metro"],
  "IRCTC": ["irctc", "railway"],
  "Goibibo": ["goibibo"],
  "MakeMyTrip": ["makemytrip", "mmt"],
  "Cleartrip": ["cleartrip"],
  "Yatra": ["yatra"],
  "Air India": ["airindia"],
  "IndiGo": ["indigo"],
  "SpiceJet": ["spicejet"],
  "Vistara": ["vistara"],
  "Go First": ["go first", "goair"],

  "Bajaj Finserv": ["bajaj finserv", "bajaj finance"],
  "HDFC Bank": ["hdfc", "hdfc bank"],
  "ICICI Bank": ["icici", "icici bank"],
  "SBI": ["sbi", "state bank"],
  "Axis Bank": ["axis", "axis bank"],
  "Kotak Bank": ["kotak", "kotak mahindra"],
  "IDFC First Bank": ["idfc", "idfc first"],
  "IndusInd Bank": ["indusind", "indusind bank"],
  "Razorpay": ["razorpay"],
  
  "Zerodha": ["zerodha"],
  "Upstox": ["upstox"],
  "Groww": ["groww"],
  "Paytm Money": ["paytm money"],
  "ETMoney": ["etmoney"],
  "LIC": ["lic", "life insurance corporation"],
  "ICICI Lombard": ["icici lombard"],
  "HDFC Life": ["hdfc life"],
  "SBI Life": ["sbi life"],
  "Max Bupa": ["max bupa"],

  "Apollo Pharmacy": ["apollo pharmacy"],
  "1mg": ["1mg", "tata 1mg"],
  "NetMeds": ["netmeds"],
  "MedPlus": ["medplus"],
  "PharmEasy": ["pharmeasy"],

  "Cult.fit": ["cultfit", "cult fit"],
  "Decathlon": ["decathlon"],
  "Nike": ["nike"],
  "Adidas": ["adidas"],
  "Reebok": ["reebok"],

  "OYO Rooms": ["oyo", "oyo rooms"],
  "Airbnb": ["airbnb"],
  "Trivago": ["trivago"],
  "Thrillophilia": ["thrillophilia"],
  "Klook": ["klook"],

  "LinkedIn Premium": ["linkedin premium"],
  "Udemy": ["udemy"],
  "Coursera": ["coursera"],
  "Skillshare": ["skillshare"],
  "Adobe Creative Cloud": ["adobe cc"],
  "Microsoft Office 365": ["office365", "microsoft 365"],

  "GiveIndia": ["giveindia"],
  "Ketto": ["ketto"],
  "Milaap": ["milaap"],

  "BookMyShow": ["bookmyshow", "bms"],
  "Insider.in": ["insider", "insider in"],
  "EventsHigh": ["eventshigh"],
  "MeraEvents": ["meraevents"],
  "Explara": ["explara"]
}

# %%
from tqdm import tqdm

df['merged_text'] = (
    df['Recipient Name'].fillna('').str.strip().str.lower() + " " + 
    df['UPI ID'].fillna('').str.strip().str.lower()
).str.strip()


def map_to_company(text):
    for company, keywords in company_keywords.items():
        if any(keyword in text for keyword in keywords):
            return company

tqdm.pandas(desc="Mapping Companies")
df['Company'] = df['merged_text'].progress_apply(map_to_company)

print("✅ Processing complete!")
# Out:
# Mapping Companies: 100%|██████████████████████████████████████████████████████████| 741/741 [00:00<00:00, 15270.45it/s]
# ✅ Processing complete!

# %%
df['Company'].isna().sum()
df['Company'].unique()
# Out:
# array([None, 'Airtel', 'Netflix', 'SBI', 'MumbaiMetro', "McDonald's",
#        'IRCTC', 'BurgerKing', 'JumboKing', 'Jio', 'Zomato', 'PizzaHut'],
#       dtype=object)

# %%
filtered_df = df[df['Company'].notna() & (df['Company'] != "")]
len(filtered_df)
# Out:
# 74

# %%
df
# Out:
#     Transaction Date  Value Date  \
# 0         2024-04-02  2 Apr 2024
# 1         2024-04-04  4 Apr 2024
# 2         2024-04-05  5 Apr 2024
# 3         2024-04-06  6 Apr 2024
# 4         2024-04-09  9 Apr 2024
# ..               ...         ...
# 736       2023-03-27  27 Mar2023
# 737       2023-03-29  29 Mar2023
# 738       2023-03-29  29 Mar2023
# 739       2023-03-31  31 Mar2023
# 740       2023-03-31  31 Mar2023
#
#                                            Description  \
# 0    TO TRANSFER-UPI/DR/409378221768/JULFIKAR/YESB/...
# 1    BY TRANSFER-INBIMPS409519772968/9890160567/XX8...
# 2    TO TRANSFER-UPI/DR/409652615602/VINAYAK /HDFC/...
# 3    BY TRANSFER-INBIMPS409719092273/9890160567/XX8...
# 4    TO TRANSFER-UPI/DR/410014886005/BHARTI A/AIRP/...
# ..                                                 ...
# 736  TO TRANSFER-UPI/DR/308658377002/SHUBHAM /BKID/...
# 737  TO TRANSFER-UPI/DR/308817813760/GUPTAGE/PYTM/p...
# 738  TO TRANSFER-UPI/DR/308818878817/RESTAURA/HDFC/...
# 739  BY TRANSFER-INBIMPS309022656347/9890160567/XX8...
# 740  TO TRANSFER-UPI/DR/309006157977/TECHANA/ICIC/t...
#
#            Reference No./Cheque No.   Debit  Credit  Balance Transaction Type  \
# 0          TRANSFER TO4897691162095    30.0     0.0   954.40               TO
# 1    MAM000078685023MAM000078685023     0.0   500.0  1454.40               BY
# 2          TRANSFER TO4897694162092    64.0     0.0  1390.40               TO
# 3    MAP000077101378MAP000077101378     0.0  1500.0  2890.40               BY
# 4          TRANSFER TO4897691162095   719.0     0.0  2171.40               TO
# ..                              ...     ...     ...      ...              ...
# 736        TRANSFER TO5097572162095    80.0     0.0  1355.38               TO
# 737        TRANSFER TO4692522162094    15.0     0.0  1340.38               TO
# 738        TRANSFER TO4696875162092   375.9     0.0   964.48               TO
# 739  MAC001235046499MAC001235046499     0.0   150.0  1114.48               BY
# 740        TRANSFER TO4692613162092  1000.0     0.0   114.48               TO
#
#     Transaction Mode DR/CR Indicator Transaction ID Recipient Name  Bank  \
# 0                UPI              DR   409378221768       JULFIKAR  YESB
# 1                INB              CR     9890160567         XX8237   NaN
# 2                UPI              DR   409652615602       VINAYAK   HDFC
# 3                INB              CR     9890160567         XX8237   NaN
# 4                UPI              DR   410014886005       BHARTI A  AIRP
# ..               ...             ...            ...            ...   ...
# 736              UPI              DR   308658377002       SHUBHAM   BKID
# 737              UPI              DR   308817813760        GUPTAGE  PYTM
# 738              UPI              DR   308818878817       RESTAURA  HDFC
# 739              INB              CR     9890160567         XX8237   NaN
# 740              UPI              DR   309006157977        TECHANA  ICIC
#
#          UPI ID   Note          merged_text     Company
# 0    paytmqr1jc  baker  julfikar paytmqr1jc        None
# 1           NaN   Son-               xx8237        None
# 2    vinayakpbh    UPI   vinayak vinayakpbh        None
# 3           NaN   Son-               xx8237        None
# 4    airtelprep  Payme  bharti a airtelprep      Airtel
# ..          ...    ...                  ...         ...
# 736  shubhamraj    UPI   shubham shubhamraj        None
# 737  paytmqr281    UPI   guptage paytmqr281        None
# 738  burgerking    UPI  restaura burgerking  BurgerKing
# 739         NaN   Son-               xx8237        None
# 740  techanalog  Payvi   techana techanalog        None
#
# [741 rows x 17 columns]

# %%
def print_transaction_details(df):
    """
    Prints every row with all the extracted details from the DataFrame.
    """
    for index, row in df.iterrows():
        print(f"Row {index}:")
        for col in df.columns:
            print(f"  {col}: {row[col]}")
        print("-" * 50)  # Separator for better readability
# print_transaction_details()
print_transaction_details(filtered_df)
# Out:
# Row 4:
#   Transaction Date: 2024-04-09
#   Value Date: 9 Apr 2024
#   Description: TO TRANSFER-UPI/DR/410014886005/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 719.0
#   Credit: 0.0
#   Balance: 2171.4
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 410014886005
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 6:
#   Transaction Date: 2024-04-10
#   Value Date: 10 Apr2024
#   Description: TO TRANSFER-UPI/DR/410168592583/NETFLIX /HDFC/netflixupi/Month-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 199.0
#   Credit: 0.0
#   Balance: 4472.4
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 410168592583
#   Recipient Name: NETFLIX
#   Bank: HDFC
#   UPI ID: netflixupi
#   Note: Month
#   merged_text: netflix netflixupi
#   Company: Netflix
# --------------------------------------------------
# Row 29:
#   Transaction Date: 2024-04-16
#   Value Date: 16 Apr2024
#   Description: TO TRANSFER-UPI/DR/410752896719/IndianR/SBIN/railsbiupi/Railw-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 345.0
#   Credit: 0.0
#   Balance: 2178.02
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 410752896719
#   Recipient Name: IndianR
#   Bank: SBIN
#   UPI ID: railsbiupi
#   Note: Railw
#   merged_text: indianr railsbiupi
#   Company: SBI
# --------------------------------------------------
# Row 43:
#   Transaction Date: 2024-04-22
#   Value Date: 22 Apr2024
#   Description: TO TRANSFER-UPI/DR/411363550608/MumbaiM/YESB/q06492713@/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897690162095
#   Debit: 100.0
#   Credit: 0.0
#   Balance: 940.02
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 411363550608
#   Recipient Name: MumbaiM
#   Bank: YESB
#   UPI ID: q06492713@
#   Note: UPI
#   merged_text: mumbaim q06492713@
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 57:
#   Transaction Date: 2024-04-27
#   Value Date: 27 Apr2024
#   Description: TO TRANSFER-UPI/DR/411807991116/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897695162091
#   Debit: 265.0
#   Credit: 0.0
#   Balance: 2147.02
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 411807991116
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 60:
#   Transaction Date: 2024-04-28
#   Value Date: 28 Apr2024
#   Description: TO TRANSFER-UPI/DR/411928306314/HARDCAST/YESB/mcdonaldsi/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897696162090
#   Debit: 78.99
#   Credit: 0.0
#   Balance: 858.03
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 411928306314
#   Recipient Name: HARDCAST
#   Bank: YESB
#   UPI ID: mcdonaldsi
#   Note: Payme
#   merged_text: hardcast mcdonaldsi
#   Company: McDonald's
# --------------------------------------------------
# Row 72:
#   Transaction Date: 2024-05-01
#   Value Date: 1 May 2024
#   Description: TO TRANSFER-UPI/DR/412272410751/HARDCAST/YESB/mcdonaldsi/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 78.99
#   Credit: 0.0
#   Balance: 2877.04
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 412272410751
#   Recipient Name: HARDCAST
#   Bank: YESB
#   UPI ID: mcdonaldsi
#   Note: Payme
#   merged_text: hardcast mcdonaldsi
#   Company: McDonald's
# --------------------------------------------------
# Row 85:
#   Transaction Date: 2024-05-07
#   Value Date: 7 May 2024
#   Description: TO TRANSFER-UPI/DR/412810637181/MCDONALDS/HDFC/mcdonalds./UPI-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 78.99
#   Credit: 0.0
#   Balance: 3579.05
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 412810637181
#   Recipient Name: MCDONALDS
#   Bank: HDFC
#   UPI ID: mcdonalds.
#   Note: UPI
#   merged_text: mcdonalds mcdonalds.
#   Company: McDonald's
# --------------------------------------------------
# Row 95:
#   Transaction Date: 2024-05-13
#   Value Date: 13 May2024
#   Description: TO TRANSFER-UPI/DR/413472765006/NETFLIX /HDFC/netflixupi/Month-
#   Reference No./Cheque No.: TRANSFER TO4897690162095
#   Debit: 199.0
#   Credit: 0.0
#   Balance: 1210.05
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 413472765006
#   Recipient Name: NETFLIX
#   Bank: HDFC
#   UPI ID: netflixupi
#   Note: Month
#   merged_text: netflix netflixupi
#   Company: Netflix
# --------------------------------------------------
# Row 97:
#   Transaction Date: 2024-05-15
#   Value Date: 15 May2024
#   Description: TO TRANSFER-UPI/DR/413601634712/IndianR/SBIN/railsbiupi/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 5.0
#   Credit: 0.0
#   Balance: 1705.05
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 413601634712
#   Recipient Name: IndianR
#   Bank: SBIN
#   UPI ID: railsbiupi
#   Note: UPI
#   merged_text: indianr railsbiupi
#   Company: SBI
# --------------------------------------------------
# Row 98:
#   Transaction Date: 2024-05-15
#   Value Date: 15 May2024
#   Description: TO TRANSFER-UPI/DR/413601691459/IndianR/SBIN/railsbiupi/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 15.0
#   Credit: 0.0
#   Balance: 1690.05
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 413601691459
#   Recipient Name: IndianR
#   Bank: SBIN
#   UPI ID: railsbiupi
#   Note: UPI
#   merged_text: indianr railsbiupi
#   Company: SBI
# --------------------------------------------------
# Row 102:
#   Transaction Date: 2024-05-22
#   Value Date: 22 May2024
#   Description: TO TRANSFER-UPI/DR/450936511023/HARDCAST/YESB/mcdonaldsi/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 427.0
#   Credit: 0.0
#   Balance: 608.05
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 450936511023
#   Recipient Name: HARDCAST
#   Bank: YESB
#   UPI ID: mcdonaldsi
#   Note: Payme
#   merged_text: hardcast mcdonaldsi
#   Company: McDonald's
# --------------------------------------------------
# Row 103:
#   Transaction Date: 2024-05-22
#   Value Date: 22 May2024
#   Description: TO TRANSFER-UPI/DR/414350027763/HARDCAST/YESB/mcdonaldsi/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 78.99
#   Credit: 0.0
#   Balance: 529.06
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 414350027763
#   Recipient Name: HARDCAST
#   Bank: YESB
#   UPI ID: mcdonaldsi
#   Note: Payme
#   merged_text: hardcast mcdonaldsi
#   Company: McDonald's
# --------------------------------------------------
# Row 104:
#   Transaction Date: 2024-05-23
#   Value Date: 23 May2024
#   Description: TO TRANSFER-UPI/DR/414422726774/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897693162093
#   Debit: 265.0
#   Credit: 0.0
#   Balance: 264.06
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 414422726774
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 160:
#   Transaction Date: 2024-06-21
#   Value Date: 21 Jun2024
#   Description: TO TRANSFER-UPI/DR/417390977285/MCDONALDS/HDFC/mcdonalds./UPI-
#   Reference No./Cheque No.: TRANSFER TO4897694162092
#   Debit: 99.0
#   Credit: 0.0
#   Balance: 312.31
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 417390977285
#   Recipient Name: MCDONALDS
#   Bank: HDFC
#   UPI ID: mcdonalds.
#   Note: UPI
#   merged_text: mcdonalds mcdonalds.
#   Company: McDonald's
# --------------------------------------------------
# Row 161:
#   Transaction Date: 2024-06-22
#   Value Date: 22 Jun2024
#   Description: TO TRANSFER-UPI/DR/417409733541/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897695162091
#   Debit: 265.0
#   Credit: 0.0
#   Balance: 47.31
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 417409733541
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 176:
#   Transaction Date: 2024-07-02
#   Value Date: 2 Jul 2024
#   Description: TO TRANSFER-UPI/DR/418422620473/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 265.0
#   Credit: 0.0
#   Balance: 975.59
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 418422620473
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 179:
#   Transaction Date: 2024-07-08
#   Value Date: 8 Jul 2024
#   Description: TO TRANSFER-UPI/DR/419094757070/HARDCAST/YESB/mcdonaldsi/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897690162095
#   Debit: 403.0
#   Credit: 0.0
#   Balance: 1442.59
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 419094757070
#   Recipient Name: HARDCAST
#   Bank: YESB
#   UPI ID: mcdonaldsi
#   Note: Payme
#   merged_text: hardcast mcdonaldsi
#   Company: McDonald's
# --------------------------------------------------
# Row 180:
#   Transaction Date: 2024-07-09
#   Value Date: 9 Jul 2024
#   Description: TO TRANSFER-UPI/DR/455738810470/AirtelP/ICIC/airtel-rec/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 299.0
#   Credit: 0.0
#   Balance: 1143.59
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 455738810470
#   Recipient Name: AirtelP
#   Bank: ICIC
#   UPI ID: airtel-rec
#   Note: UPI
#   merged_text: airtelp airtel-rec
#   Company: Airtel
# --------------------------------------------------
# Row 181:
#   Transaction Date: 2024-07-09
#   Value Date: 9 Jul 2024
#   Description: TO TRANSFER-UPI/DR/419163334127/NETFLIX /HDFC/netflixupi/Month-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 199.0
#   Credit: 0.0
#   Balance: 944.59
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 419163334127
#   Recipient Name: NETFLIX
#   Bank: HDFC
#   UPI ID: netflixupi
#   Note: Month
#   merged_text: netflix netflixupi
#   Company: Netflix
# --------------------------------------------------
# Row 192:
#   Transaction Date: 2024-07-20
#   Value Date: 20 Jul 2024
#   Description: TO TRANSFER-UPI/DR/420258915545/Airtel/YESB/airtel-pre/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897695162091
#   Debit: 299.0
#   Credit: 0.0
#   Balance: 701.79
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 420258915545
#   Recipient Name: Airtel
#   Bank: YESB
#   UPI ID: airtel-pre
#   Note: UPI
#   merged_text: airtel airtel-pre
#   Company: Airtel
# --------------------------------------------------
# Row 200:
#   Transaction Date: 2024-08-01
#   Value Date: 1 Aug 2024
#   Description: TO TRANSFER-UPI/DR/421423672838/IRCTCUTS/YESB/paytm-8727/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897693162093
#   Debit: 100.0
#   Credit: 0.0
#   Balance: 997.79
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 421423672838
#   Recipient Name: IRCTCUTS
#   Bank: YESB
#   UPI ID: paytm-8727
#   Note: UPI
#   merged_text: irctcuts paytm-8727
#   Company: IRCTC
# --------------------------------------------------
# Row 202:
#   Transaction Date: 2024-08-02
#   Value Date: 2 Aug 2024
#   Description: TO TRANSFER-UPI/DR/421532750002/IndianR/SBIN/railsbiupi/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897694162092
#   Debit: 20.0
#   Credit: 0.0
#   Balance: 577.79
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 421532750002
#   Recipient Name: IndianR
#   Bank: SBIN
#   UPI ID: railsbiupi
#   Note: UPI
#   merged_text: indianr railsbiupi
#   Company: SBI
# --------------------------------------------------
# Row 208:
#   Transaction Date: 2024-08-05
#   Value Date: 5 Aug 2024
#   Description: TO TRANSFER-UPI/DR/458434093368/IndianR/SBIN/railsbiupi/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897690162095
#   Debit: 20.0
#   Credit: 0.0
#   Balance: 1667.79
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 458434093368
#   Recipient Name: IndianR
#   Bank: SBIN
#   UPI ID: railsbiupi
#   Note: UPI
#   merged_text: indianr railsbiupi
#   Company: SBI
# --------------------------------------------------
# Row 209:
#   Transaction Date: 2024-08-05
#   Value Date: 5 Aug 2024
#   Description: TO TRANSFER-UPI/DR/458465830805/IndianR/SBIN/railsbiupi/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897690162095
#   Debit: 215.0
#   Credit: 0.0
#   Balance: 1452.79
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 458465830805
#   Recipient Name: IndianR
#   Bank: SBIN
#   UPI ID: railsbiupi
#   Note: UPI
#   merged_text: indianr railsbiupi
#   Company: SBI
# --------------------------------------------------
# Row 220:
#   Transaction Date: 2024-08-12
#   Value Date: 12 Aug2024
#   Description: TO TRANSFER-UPI/DR/422510273238/MumbaiM/YESB/q09778271@/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 200.0
#   Credit: 0.0
#   Balance: 599.25
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 422510273238
#   Recipient Name: MumbaiM
#   Bank: YESB
#   UPI ID: q09778271@
#   Note: UPI
#   merged_text: mumbaim q09778271@
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 224:
#   Transaction Date: 2024-08-16
#   Value Date: 16 Aug2024
#   Description: TO TRANSFER-UPI/DR/422942101580/MCDONALDS/HDFC/mcdonalds./UPI-
#   Reference No./Cheque No.: TRANSFER TO4897695162091
#   Debit: 198.88
#   Credit: 0.0
#   Balance: 179.37
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 422942101580
#   Recipient Name: MCDONALDS
#   Bank: HDFC
#   UPI ID: mcdonalds.
#   Note: UPI
#   merged_text: mcdonalds mcdonalds.
#   Company: McDonald's
# --------------------------------------------------
# Row 226:
#   Transaction Date: 2024-08-18
#   Value Date: 18 Aug2024
#   Description: TO TRANSFER-UPI/DR/423120534141/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897690162095
#   Debit: 299.0
#   Credit: 0.0
#   Balance: 880.37
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 423120534141
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 233:
#   Transaction Date: 2024-09-02
#   Value Date: 2 Sep 2024
#   Description: TO TRANSFER-UPI/DR/424611160977/RESTAURA/HDFC/burgerking/Gener-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 103.96
#   Credit: 0.0
#   Balance: 146.81
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 424611160977
#   Recipient Name: RESTAURA
#   Bank: HDFC
#   UPI ID: burgerking
#   Note: Gener
#   merged_text: restaura burgerking
#   Company: BurgerKing
# --------------------------------------------------
# Row 237:
#   Transaction Date: 2024-09-13
#   Value Date: 13 Sep2024
#   Description: TO TRANSFER-UPI/DR/425716372990/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897695162091
#   Debit: 49.0
#   Credit: 0.0
#   Balance: 1062.81
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 425716372990
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 238:
#   Transaction Date: 2024-09-14
#   Value Date: 14 Sep2024
#   Description: TO TRANSFER-UPI/DR/425810029228/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897696162090
#   Debit: 299.0
#   Credit: 0.0
#   Balance: 763.81
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 425810029228
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 248:
#   Transaction Date: 2024-09-20
#   Value Date: 20 Sep2024
#   Description: TO TRANSFER-UPI/DR/463070183933/JUMBOKI/YESB/paytmqr14h/food-
#   Reference No./Cheque No.: TRANSFER TO4897695162091
#   Debit: 99.0
#   Credit: 0.0
#   Balance: 483.81
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 463070183933
#   Recipient Name: JUMBOKI
#   Bank: YESB
#   UPI ID: paytmqr14h
#   Note: food
#   merged_text: jumboki paytmqr14h
#   Company: JumboKing
# --------------------------------------------------
# Row 257:
#   Transaction Date: 2024-09-29
#   Value Date: 29 Sep2024
#   Description: TO TRANSFER-UPI/DR/427350017233/JioCinema/YESB/viacom18on/Coll-
#   Reference No./Cheque No.: TRANSFER TO4897690162095
#   Debit: 29.0
#   Credit: 0.0
#   Balance: 167.81
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 427350017233
#   Recipient Name: JioCinema
#   Bank: YESB
#   UPI ID: viacom18on
#   Note: Coll
#   merged_text: jiocinema viacom18on
#   Company: Jio
# --------------------------------------------------
# Row 262:
#   Transaction Date: 2024-10-04
#   Value Date: 4 Oct 2024
#   Description: TO TRANSFER-UPI/DR/427836390570/MCDONALDS/HDFC/mcdonalds./Gen-
#   Reference No./Cheque No.: TRANSFER TO4897695162091
#   Debit: 199.0
#   Credit: 0.0
#   Balance: 3383.81
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 427836390570
#   Recipient Name: MCDONALDS
#   Bank: HDFC
#   UPI ID: mcdonalds.
#   Note: Gen
#   merged_text: mcdonalds mcdonalds.
#   Company: McDonald's
# --------------------------------------------------
# Row 268:
#   Transaction Date: 2024-10-11
#   Value Date: 11 Oct2024
#   Description: TO TRANSFER-UPI/DR/428522854603/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897695162091
#   Debit: 299.0
#   Credit: 0.0
#   Balance: 3694.81
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 428522854603
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 271:
#   Transaction Date: 2024-10-12
#   Value Date: 12 Oct2024
#   Description: TO TRANSFER-UPI/DR/428617512021/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897696162090
#   Debit: 299.0
#   Credit: 0.0
#   Balance: 3215.81
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 428617512021
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 288:
#   Transaction Date: 2024-10-30
#   Value Date: 30 Oct2024
#   Description: TO TRANSFER-UPI/DR/430427960886/JioCinema/YESB/viacom18on/Subs-
#   Reference No./Cheque No.: TRANSFER TO4897693162093
#   Debit: 29.0
#   Credit: 0.0
#   Balance: 140.81
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 430427960886
#   Recipient Name: JioCinema
#   Bank: YESB
#   UPI ID: viacom18on
#   Note: Subs
#   merged_text: jiocinema viacom18on
#   Company: Jio
# --------------------------------------------------
# Row 291:
#   Transaction Date: 2024-10-30
#   Value Date: 30 Oct2024
#   Description: TO TRANSFER-UPI/DR/430415540481/ZOMATO L/UTIB/zomatoorde/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897693162093
#   Debit: 576.0
#   Credit: 0.0
#   Balance: 1064.81
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 430415540481
#   Recipient Name: ZOMATO L
#   Bank: UTIB
#   UPI ID: zomatoorde
#   Note: UPI
#   merged_text: zomato l zomatoorde
#   Company: Zomato
# --------------------------------------------------
# Row 295:
#   Transaction Date: 2024-11-04
#   Value Date: 4 Nov 2024
#   Description: TO TRANSFER-UPI/DR/430902812486/ZOMATO L/UTIB/zomatoorde/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 295.78
#   Credit: 0.0
#   Balance: 949.03
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 430902812486
#   Recipient Name: ZOMATO L
#   Bank: UTIB
#   UPI ID: zomatoorde
#   Note: UPI
#   merged_text: zomato l zomatoorde
#   Company: Zomato
# --------------------------------------------------
# Row 310:
#   Transaction Date: 2023-04-05
#   Value Date: 5 Apr 2023
#   Description: TO TRANSFER-UPI/DR/309552913762/MumbaiM/YESB/q06492713@/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 10.0
#   Credit: 0.0
#   Balance: 3364.81
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 309552913762
#   Recipient Name: MumbaiM
#   Bank: YESB
#   UPI ID: q06492713@
#   Note: UPI
#   merged_text: mumbaim q06492713@
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 311:
#   Transaction Date: 2023-04-06
#   Value Date: 6 Apr 2023
#   Description: TO TRANSFER-UPI/DR/309621461326/IndianR/SBIN/railsbiupi/Railw-
#   Reference No./Cheque No.: TRANSFER TO4897693162093
#   Debit: 345.0
#   Credit: 0.0
#   Balance: 3019.81
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 309621461326
#   Recipient Name: IndianR
#   Bank: SBIN
#   UPI ID: railsbiupi
#   Note: Railw
#   merged_text: indianr railsbiupi
#   Company: SBI
# --------------------------------------------------
# Row 312:
#   Transaction Date: 2023-04-09
#   Value Date: 9 Apr 2023
#   Description: TO TRANSFER-UPI/DR/309989609989/HARDCAST/YESB/mcdonaldsi/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897696162090
#   Debit: 58.99
#   Credit: 0.0
#   Balance: 2960.82
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 309989609989
#   Recipient Name: HARDCAST
#   Bank: YESB
#   UPI ID: mcdonaldsi
#   Note: Payme
#   merged_text: hardcast mcdonaldsi
#   Company: McDonald's
# --------------------------------------------------
# Row 319:
#   Transaction Date: 2023-04-12
#   Value Date: 12 Apr2023
#   Description: TO TRANSFER-UPI/DR/310291029880/JUMBOKI/PYTM/paytmqr281/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 39.0
#   Credit: 0.0
#   Balance: 3411.82
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 310291029880
#   Recipient Name: JUMBOKI
#   Bank: PYTM
#   UPI ID: paytmqr281
#   Note: UPI
#   merged_text: jumboki paytmqr281
#   Company: JumboKing
# --------------------------------------------------
# Row 356:
#   Transaction Date: 2023-05-09
#   Value Date: 9 May 2023
#   Description: TO TRANSFER-UPI/DR/312921935495/JUMBOKI/PYTM/paytmqr281/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 69.0
#   Credit: 0.0
#   Balance: 1614.82
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 312921935495
#   Recipient Name: JUMBOKI
#   Bank: PYTM
#   UPI ID: paytmqr281
#   Note: UPI
#   merged_text: jumboki paytmqr281
#   Company: JumboKing
# --------------------------------------------------
# Row 385:
#   Transaction Date: 2023-05-24
#   Value Date: 24 May2023
#   Description: TO TRANSFER-UPI/DR/314458727994/JUMBOKI/PYTM/paytmqr281/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 69.0
#   Credit: 0.0
#   Balance: 1407.82
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 314458727994
#   Recipient Name: JUMBOKI
#   Bank: PYTM
#   UPI ID: paytmqr281
#   Note: UPI
#   merged_text: jumboki paytmqr281
#   Company: JumboKing
# --------------------------------------------------
# Row 407:
#   Transaction Date: 2023-06-06
#   Value Date: 6 Jun 2023
#   Description: TO TRANSFER-UPI/DR/352326166531/MumbaiM/YESB/q06492713@/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 200.0
#   Credit: 0.0
#   Balance: 1098.82
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 352326166531
#   Recipient Name: MumbaiM
#   Bank: YESB
#   UPI ID: q06492713@
#   Note: UPI
#   merged_text: mumbaim q06492713@
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 410:
#   Transaction Date: 2023-06-07
#   Value Date: 7 Jun 2023
#   Description: TO TRANSFER-UPI/DR/315851111360/RESTAURA/HDFC/burgerking/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 98.7
#   Credit: 0.0
#   Balance: 970.12
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 315851111360
#   Recipient Name: RESTAURA
#   Bank: HDFC
#   UPI ID: burgerking
#   Note: UPI
#   merged_text: restaura burgerking
#   Company: BurgerKing
# --------------------------------------------------
# Row 425:
#   Transaction Date: 2023-06-17
#   Value Date: 17 Jun2023
#   Description: TO TRANSFER-UPI/DR/316809048882/airtel/UTIB/airtel.pay/UPITran-
#   Reference No./Cheque No.: TRANSFER TO4897695162091
#   Debit: 319.0
#   Credit: 0.0
#   Balance: 496.12
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 316809048882
#   Recipient Name: airtel
#   Bank: UTIB
#   UPI ID: airtel.pay
#   Note: UPITran
#   merged_text: airtel airtel.pay
#   Company: Airtel
# --------------------------------------------------
# Row 452:
#   Transaction Date: 2023-07-14
#   Value Date: 14 Jul 2023
#   Description: TO TRANSFER-UPI/DR/319514798673/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897694162092
#   Debit: 299.0
#   Credit: 0.0
#   Balance: 1416.62
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 319514798673
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 472:
#   Transaction Date: 2023-08-14
#   Value Date: 14 Aug2023
#   Description: TO TRANSFER-UPI/DR/322628827207/airtel/UTIB/airtel.pay/UPITran-
#   Reference No./Cheque No.: TRANSFER TO4897690162095
#   Debit: 265.0
#   Credit: 0.0
#   Balance: 1798.62
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 322628827207
#   Recipient Name: airtel
#   Bank: UTIB
#   UPI ID: airtel.pay
#   Note: UPITran
#   merged_text: airtel airtel.pay
#   Company: Airtel
# --------------------------------------------------
# Row 482:
#   Transaction Date: 2023-08-22
#   Value Date: 22 Aug2023
#   Description: TO TRANSFER-UPI/DR/360007231809/IRCTCUTS/PYTM/paytm-8727/Oid8-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 100.0
#   Credit: 0.0
#   Balance: 1396.92
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 360007231809
#   Recipient Name: IRCTCUTS
#   Bank: PYTM
#   UPI ID: paytm-8727
#   Note: Oid8
#   merged_text: irctcuts paytm-8727
#   Company: IRCTC
# --------------------------------------------------
# Row 484:
#   Transaction Date: 2023-08-24
#   Value Date: 24 Aug2023
#   Description: TO TRANSFER-UPI/DR/323626961535/MumbaiM/YESB/Q06492713@/NA-
#   Reference No./Cheque No.: TRANSFER TO4897693162093
#   Debit: 200.0
#   Credit: 0.0
#   Balance: 696.92
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 323626961535
#   Recipient Name: MumbaiM
#   Bank: YESB
#   UPI ID: Q06492713@
#   Note: nan
#   merged_text: mumbaim q06492713@
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 498:
#   Transaction Date: 2023-09-04
#   Value Date: 4 Sep 2023
#   Description: TO TRANSFER-UPI/DR/324768508829/IndianR/SBIN/railsbiupi/Railw-
#   Reference No./Cheque No.: TRANSFER TO4897690162095
#   Debit: 345.0
#   Credit: 0.0
#   Balance: 1076.92
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 324768508829
#   Recipient Name: IndianR
#   Bank: SBIN
#   UPI ID: railsbiupi
#   Note: Railw
#   merged_text: indianr railsbiupi
#   Company: SBI
# --------------------------------------------------
# Row 504:
#   Transaction Date: 2023-09-11
#   Value Date: 11 Sep2023
#   Description: TO TRANSFER-UPI/DR/325439744261/BhartiA/HDFC/airtel.pay/UPITr-
#   Reference No./Cheque No.: TRANSFER TO4897690162095
#   Debit: 265.0
#   Credit: 0.0
#   Balance: 46.92
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 325439744261
#   Recipient Name: BhartiA
#   Bank: HDFC
#   UPI ID: airtel.pay
#   Note: UPITr
#   merged_text: bhartia airtel.pay
#   Company: Airtel
# --------------------------------------------------
# Row 515:
#   Transaction Date: 2023-09-27
#   Value Date: 27 Sep2023
#   Description: TO TRANSFER-UPI/DR/363688284597/MumbaiM/YESB/q06492713@/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 200.0
#   Credit: 0.0
#   Balance: 132.92
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 363688284597
#   Recipient Name: MumbaiM
#   Bank: YESB
#   UPI ID: q06492713@
#   Note: UPI
#   merged_text: mumbaim q06492713@
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 523:
#   Transaction Date: 2023-10-10
#   Value Date: 10 Oct2023
#   Description: TO TRANSFER-UPI/DR/328301517933/AirtelP/INDB/airtelpaym/UPITr-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 265.0
#   Credit: 0.0
#   Balance: 917.92
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 328301517933
#   Recipient Name: AirtelP
#   Bank: INDB
#   UPI ID: airtelpaym
#   Note: UPITr
#   merged_text: airtelp airtelpaym
#   Company: Airtel
# --------------------------------------------------
# Row 544:
#   Transaction Date: 2023-10-30
#   Value Date: 30 Oct2023
#   Description: TO TRANSFER-UPI/DR/330303191462/MumbaiM/YESB/q06492713@/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897690162095
#   Debit: 200.0
#   Credit: 0.0
#   Balance: 946.92
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 330303191462
#   Recipient Name: MumbaiM
#   Bank: YESB
#   UPI ID: q06492713@
#   Note: UPI
#   merged_text: mumbaim q06492713@
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 556:
#   Transaction Date: 2023-11-07
#   Value Date: 7 Nov 2023
#   Description: TO TRANSFER-UPI/DR/331107169588/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897691162095
#   Debit: 265.0
#   Credit: 0.0
#   Balance: 297.92
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 331107169588
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 559:
#   Transaction Date: 2023-11-12
#   Value Date: 12 Nov2023
#   Description: TO TRANSFER-UPI/DR/331614187502/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897696162090
#   Debit: 265.0
#   Credit: 0.0
#   Balance: 1008.92
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 331614187502
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 579:
#   Transaction Date: 2023-12-09
#   Value Date: 9 Dec 2023
#   Description: TO TRANSFER-UPI/DR/334310408852/BHARTI A/AIRP/airtelprep/Payme-
#   Reference No./Cheque No.: TRANSFER TO4897695162091
#   Debit: 265.0
#   Credit: 0.0
#   Balance: 741.92
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 334310408852
#   Recipient Name: BHARTI A
#   Bank: AIRP
#   UPI ID: airtelprep
#   Note: Payme
#   merged_text: bharti a airtelprep
#   Company: Airtel
# --------------------------------------------------
# Row 584:
#   Transaction Date: 2023-12-13
#   Value Date: 13 Dec2023
#   Description: TO TRANSFER-UPI/DR/334751073957/JUMBOKI/PYTM/paytmqr281/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 39.0
#   Credit: 0.0
#   Balance: 632.92
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 334751073957
#   Recipient Name: JUMBOKI
#   Bank: PYTM
#   UPI ID: paytmqr281
#   Note: UPI
#   merged_text: jumboki paytmqr281
#   Company: JumboKing
# --------------------------------------------------
# Row 595:
#   Transaction Date: 2023-12-20
#   Value Date: 20 Dec2023
#   Description: TO TRANSFER-UPI/DR/335414280362/MumbaiM/YESB/q48179062@/UPI-
#   Reference No./Cheque No.: TRANSFER TO4897692162094
#   Debit: 100.0
#   Credit: 0.0
#   Balance: 1200.92
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 335414280362
#   Recipient Name: MumbaiM
#   Bank: YESB
#   UPI ID: q48179062@
#   Note: UPI
#   merged_text: mumbaim q48179062@
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 615:
#   Transaction Date: 2022-10-17
#   Value Date: 17 Oct2022
#   Description: TO TRANSFER-UPI/DR/229064422572/BhartiA/HDFC/airtel.pay/UPITr-
#   Reference No./Cheque No.: TRANSFER TO4692451162093
#   Debit: 319.0
#   Credit: 0.0
#   Balance: 1328.0
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 229064422572
#   Recipient Name: BhartiA
#   Bank: HDFC
#   UPI ID: airtel.pay
#   Note: UPITr
#   merged_text: bhartia airtel.pay
#   Company: Airtel
# --------------------------------------------------
# Row 632:
#   Transaction Date: 2022-11-17
#   Value Date: 17 Nov2022
#   Description: TO TRANSFER-UPI/DR/232170353359/BhartiA/SBIN/bhartiairt/Airte-
#   Reference No./Cheque No.: TRANSFER TO5097784162094
#   Debit: 319.0
#   Credit: 0.0
#   Balance: 1393.88
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 232170353359
#   Recipient Name: BhartiA
#   Bank: SBIN
#   UPI ID: bhartiairt
#   Note: Airte
#   merged_text: bhartia bhartiairt
#   Company: Airtel
# --------------------------------------------------
# Row 642:
#   Transaction Date: 2022-12-09
#   Value Date: 9 Dec 2022
#   Description: TO TRANSFER-UPI/DR/234388276059/MumbaiM/PYTM/paytmqr281/UPI-
#   Reference No./Cheque No.: TRANSFER TO4692611162094
#   Debit: 150.0
#   Credit: 0.0
#   Balance: 1468.88
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 234388276059
#   Recipient Name: MumbaiM
#   Bank: PYTM
#   UPI ID: paytmqr281
#   Note: UPI
#   merged_text: mumbaim paytmqr281
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 650:
#   Transaction Date: 2022-12-19
#   Value Date: 19 Dec2022
#   Description: TO TRANSFER-UPI/DR/235314159763/BhartiA/HDFC/airtel.pay/UPITr-
#   Reference No./Cheque No.: TRANSFER TO4692431162097
#   Debit: 319.0
#   Credit: 0.0
#   Balance: 1540.88
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 235314159763
#   Recipient Name: BhartiA
#   Bank: HDFC
#   UPI ID: airtel.pay
#   Note: UPITr
#   merged_text: bhartia airtel.pay
#   Company: Airtel
# --------------------------------------------------
# Row 651:
#   Transaction Date: 2022-12-19
#   Value Date: 19 Dec2022
#   Description: BY TRANSFER-UPI/CR/235362852144/BhartiA/HDFC/airtel.pay/RRRPP-
#   Reference No./Cheque No.: TRANSFERFROM5098867162093
#   Debit: 0.0
#   Credit: 319.0
#   Balance: 1859.88
#   Transaction Type: BY
#   Transaction Mode: UPI
#   DR/CR Indicator: CR
#   Transaction ID: 235362852144
#   Recipient Name: BhartiA
#   Bank: HDFC
#   UPI ID: airtel.pay
#   Note: RRRPP
#   merged_text: bhartia airtel.pay
#   Company: Airtel
# --------------------------------------------------
# Row 652:
#   Transaction Date: 2022-12-19
#   Value Date: 19 Dec2022
#   Description: TO TRANSFER-UPI/DR/235305522950/MumbaiM/YESB/q09778271@/UPI-
#   Reference No./Cheque No.: TRANSFER TO4696809162090
#   Debit: 150.0
#   Credit: 0.0
#   Balance: 1709.88
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 235305522950
#   Recipient Name: MumbaiM
#   Bank: YESB
#   UPI ID: q09778271@
#   Note: UPI
#   merged_text: mumbaim q09778271@
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 653:
#   Transaction Date: 2022-12-19
#   Value Date: 19 Dec2022
#   Description: TO TRANSFER-UPI/DR/235305553106/MumbaiM/YESB/q09778271@/UPI-
#   Reference No./Cheque No.: TRANSFER TO4695784162092
#   Debit: 50.0
#   Credit: 0.0
#   Balance: 1659.88
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 235305553106
#   Recipient Name: MumbaiM
#   Bank: YESB
#   UPI ID: q09778271@
#   Note: UPI
#   merged_text: mumbaim q09778271@
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 668:
#   Transaction Date: 2023-01-13
#   Value Date: 13 Jan2023
#   Description: TO TRANSFER-UPI/DR/301380894954/MumbaiM/PYTM/paytmqr281/UPI-
#   Reference No./Cheque No.: TRANSFER TO5097887162097
#   Debit: 200.0
#   Credit: 0.0
#   Balance: 2661.88
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 301380894954
#   Recipient Name: MumbaiM
#   Bank: PYTM
#   UPI ID: paytmqr281
#   Note: UPI
#   merged_text: mumbaim paytmqr281
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 698:
#   Transaction Date: 2023-02-24
#   Value Date: 24 Feb2023
#   Description: TO TRANSFER-UPI/DR/305563243213/PIZZAHUT/HDFC/pizzahut.2/UPI-
#   Reference No./Cheque No.: TRANSFER TO4696931162090
#   Debit: 628.0
#   Credit: 0.0
#   Balance: 1084.88
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 305563243213
#   Recipient Name: PIZZAHUT
#   Bank: HDFC
#   UPI ID: pizzahut.2
#   Note: UPI
#   merged_text: pizzahut pizzahut.2
#   Company: PizzaHut
# --------------------------------------------------
# Row 710:
#   Transaction Date: 2023-03-06
#   Value Date: 6 Mar 2023
#   Description: TO TRANSFER-UPI/DR/306577213702/MumbaiM/YESB/q04393494@/UPI-
#   Reference No./Cheque No.: TRANSFER TO5097533162091
#   Debit: 200.0
#   Credit: 0.0
#   Balance: 956.88
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 306577213702
#   Recipient Name: MumbaiM
#   Bank: YESB
#   UPI ID: q04393494@
#   Note: UPI
#   merged_text: mumbaim q04393494@
#   Company: MumbaiMetro
# --------------------------------------------------
# Row 715:
#   Transaction Date: 2023-03-10
#   Value Date: 10 Mar2023
#   Description: TO TRANSFER-UPI/DR/306909627537/RESTAURA/HDFC/burgerking/UPI-
#   Reference No./Cheque No.: TRANSFER TO4696928162095
#   Debit: 94.5
#   Credit: 0.0
#   Balance: 1114.38
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 306909627537
#   Recipient Name: RESTAURA
#   Bank: HDFC
#   UPI ID: burgerking
#   Note: UPI
#   merged_text: restaura burgerking
#   Company: BurgerKing
# --------------------------------------------------
# Row 738:
#   Transaction Date: 2023-03-29
#   Value Date: 29 Mar2023
#   Description: TO TRANSFER-UPI/DR/308818878817/RESTAURA/HDFC/burgerking/UPI-
#   Reference No./Cheque No.: TRANSFER TO4696875162092
#   Debit: 375.9
#   Credit: 0.0
#   Balance: 964.48
#   Transaction Type: TO
#   Transaction Mode: UPI
#   DR/CR Indicator: DR
#   Transaction ID: 308818878817
#   Recipient Name: RESTAURA
#   Bank: HDFC
#   UPI ID: burgerking
#   Note: UPI
#   merged_text: restaura burgerking
#   Company: BurgerKing
# --------------------------------------------------

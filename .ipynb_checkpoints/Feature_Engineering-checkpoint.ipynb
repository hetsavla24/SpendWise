# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from prophet import Prophet

from sklearn.metrics import mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
pd.set_option('display.max_colwidth', None)  # Display full content of each column
pd.set_option('display.max_columns', None)   # Display all columns
pd.set_option('display.width', 5000)         # Set display width

plt.style.use('ggplot')
plt.style.use('fivethirtyeight')

# %%
df=pd.read_csv("Features.csv")

# %%
df['Transaction Date'][0]
# Out:
# '2024-04-02'

# %%
df.columns
# Out:
# Index(['Transaction Date', 'Description', 'Reference No./Cheque No.', 'Debit', 'Credit', 'Balance', 'Transaction Type', 'Transaction Mode', 'DR/CR Indicator', 'Transaction ID', 'Recipient Name', 'Bank', 'UPI ID', 'Note', 'dayofweek', 'quarter', 'month', 'year', 'dayofyear', 'dayofmonth', 'weekofyear', 'weekday', 'is_weekend', 'transaction_amount', 'is_large_transaction', 'Balance.1'], dtype='object')

# %%
# Define Start and End Dates (Modify as needed)
start_date = "2024-01-01"
end_date = "2024-12-31"

# Filter transactions within the date range
df_filtered = df[(df["Transaction Date"] >= start_date) & (df["Transaction Date"] <= end_date)]

# %%
# Count transactions per UPI ID (Daily, Weekly, Monthly, Yearly)
df_filtered["Year"] = df_filtered["Transaction Date"].dt.year
df_filtered["Month"] = df_filtered["Transaction Date"].dt.month
df_filtered["Week"] = df_filtered["Transaction Date"].dt.isocalendar().week
df_filtered["Day"] = df_filtered["Transaction Date"].dt.date

# Daily Count per UPI ID
daily_counts = df_filtered.groupby(["Day", "UPI ID"]).size().reset_index(name="Daily Count")

# Weekly Count per UPI ID
weekly_counts = df_filtered.groupby(["Year", "Week", "UPI ID"]).size().reset_index(name="Weekly Count")

# Monthly Count per UPI ID
monthly_counts = df_filtered.groupby(["Year", "Month", "UPI ID"]).size().reset_index(name="Monthly Count")

# Yearly Count per UPI ID
yearly_counts = df_filtered.groupby(["Year", "UPI ID"]).size().reset_index(name="Yearly Count")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[122], line 2
#       1 # Count transactions per UPI ID (Daily, Weekly, Monthly, Yearly)
# ----> 2 df_filtered["Year"] = df_filtered["Transaction Date"].dt.year
#       3 df_filtered["Month"] = df_filtered["Transaction Date"].dt.month
#       4 df_filtered["Week"] = df_filtered["Transaction Date"].dt.isocalendar().week
#
# File ~\Desktop\Python_Venv\PreProcessor\lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\Desktop\Python_Venv\PreProcessor\lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\Desktop\Python_Venv\PreProcessor\lib\site-packages\pandas\core\indexes\accessors.py:643, in CombinedDatetimelikeProperties.__new__(cls, data)
#     640 elif isinstance(data.dtype, PeriodDtype):
#     641     return PeriodProperties(data, orig)
# --> 643 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
df_filtered
# Out:
#     Transaction Date                                                      Description        Reference No./Cheque No.   Debit  Credit  Balance Transaction Type Transaction Mode DR/CR Indicator Transaction ID Recipient Name  Bank      UPI ID   Note  dayofweek  quarter  month  year  dayofyear  dayofmonth  weekofyear    weekday  is_weekend  transaction_amount  is_large_transaction  Balance.1
# 0         2024-04-02  TO TRANSFER-UPI/DR/409378221768/JULFIKAR/YESB/paytmqr1jc/baker-        TRANSFER TO4897691162095   30.00     0.0   954.40               TO              UPI              DR   409378221768       JULFIKAR  YESB  paytmqr1jc  baker          1        2      4  2024         93           2          14    Tuesday           0               30.00                     0     954.40
# 1         2024-04-04           BY TRANSFER-INBIMPS409519772968/9890160567/XX8237/Son-  MAM000078685023MAM000078685023    0.00   500.0  1454.40               BY              INB              CR     9890160567         XX8237   NaN         NaN   Son-          3        2      4  2024         95           4          14   Thursday           0                0.00                     0    1454.40
# 2         2024-04-05    TO TRANSFER-UPI/DR/409652615602/VINAYAK /HDFC/vinayakpbh/UPI-        TRANSFER TO4897694162092   64.00     0.0  1390.40               TO              UPI              DR   409652615602       VINAYAK   HDFC  vinayakpbh    UPI          4        2      4  2024         96           5          14     Friday           0               64.00                     0    1390.40
# 3         2024-04-06           BY TRANSFER-INBIMPS409719092273/9890160567/XX8237/Son-  MAP000077101378MAP000077101378    0.00  1500.0  2890.40               BY              INB              CR     9890160567         XX8237   NaN         NaN   Son-          5        2      4  2024         97           6          14   Saturday           1                0.00                     0    2890.40
# 4         2024-04-09  TO TRANSFER-UPI/DR/410014886005/BHARTI A/AIRP/airtelprep/Payme-        TRANSFER TO4897691162095  719.00     0.0  2171.40               TO              UPI              DR   410014886005       BHARTI A  AIRP  airtelprep  Payme          1        2      4  2024        100           9          15    Tuesday           0              719.00                     0    2171.40
# ..               ...                                                              ...                             ...     ...     ...      ...              ...              ...             ...            ...            ...   ...         ...    ...        ...      ...    ...   ...        ...         ...         ...        ...         ...                 ...                   ...        ...
# 294       2024-11-04    BY TRANSFER-UPI/CR/430929085524/SAMEER B/ICIC/sawant.123/UPI-       TRANSFERFROM4897733162090    0.00   300.0  1244.81               BY              UPI              CR   430929085524       SAMEER B  ICIC  sawant.123    UPI          0        4     11  2024        309           4          45     Monday           0                0.00                     0    1244.81
# 295       2024-11-04    TO TRANSFER-UPI/DR/430902812486/ZOMATO L/UTIB/zomatoorde/UPI-        TRANSFER TO4897691162095  295.78     0.0   949.03               TO              UPI              DR   430902812486       ZOMATO L  UTIB  zomatoorde    UPI          0        4     11  2024        309           4          45     Monday           0              295.78                     0     949.03
# 296       2024-11-05     TO TRANSFER-UPI/DR/467686807162/DILIPKU/YESB/paytmqr5wr/UPI-        TRANSFER TO4897692162094   79.00     0.0   870.03               TO              UPI              DR   467686807162        DILIPKU  YESB  paytmqr5wr    UPI          1        4     11  2024        310           5          45    Tuesday           0               79.00                     0     870.03
# 297       2024-11-05    TO TRANSFER-UPI/DR/431057312820/SHINDE R/COSB/shinderayc/UPI-        TRANSFER TO4897692162094   15.00     0.0   855.03               TO              UPI              DR   431057312820       SHINDE R  COSB  shinderayc    UPI          1        4     11  2024        310           5          45    Tuesday           0               15.00                     0     855.03
# 298       2024-11-06    TO TRANSFER-UPI/DR/431165845160/Bombay B/UTIB/8850949354/UPI-        TRANSFER TO4897693162093   70.00     0.0   785.03               TO              UPI              DR   431165845160       Bombay B  UTIB  8850949354    UPI          2        4     11  2024        311           6          45  Wednesday           0               70.00                     0     785.03
#
# [299 rows x 26 columns]

# %%
# Define Recurring Transaction Criteria
WEEKLY_THRESHOLD = 5  # If transaction occurs 5+ times in a week
MONTHLY_THRESHOLD = 10  # If transaction occurs 10+ times in a month

# Find Recurring Weekly Transactions
recurring_weekly = weekly_counts[weekly_counts["Weekly Count"] >= WEEKLY_THRESHOLD]

# Find Recurring Monthly Transactions
recurring_monthly = monthly_counts[monthly_counts["Monthly Count"] >= MONTHLY_THRESHOLD]

# Merge both datasets for final recurring transactions
recurring_transactions = pd.concat([recurring_weekly, recurring_monthly])

print("Recurring Transactions Detected:")
recurring_transactions
# Out:
# Recurring Transactions Detected:
#     Year  Week      UPI ID  Weekly Count  Month  Monthly Count
# 53  2024    18  vihaanshin           5.0    NaN            NaN
# 95  2024    24  shloksm28-           5.0    NaN            NaN

# %%
# df

# %%
weekend_spending = df[df["is_weekend"] == 1]["Balance"].sum()
weekday_spending = df[df["is_weekend"] == 0]["Balance"].sum()

print(f"Weekend Spending: {abs(weekend_spending)}")
print(f"Weekday Spending: {abs(weekday_spending)}")

plt.bar(["Weekday", "Weekend"], [abs(weekday_spending), abs(weekend_spending)], color=["blue", "red"])
plt.title("Weekday vs Weekend Spending")
plt.ylabel("Amount Spent")
plt.show()
# Out:
# Weekend Spending: 380433.88999999996
# Weekday Spending: 819965.24

# %%
# Daily Spending
daily_spending = df.groupby("Transaction Date")["Balance"].sum()
plt.figure(figsize=(10, 4))
daily_spending.plot(kind="line", marker="o", color="red")
plt.title("Daily Spending Trend")
plt.ylabel("Amount Spent")
plt.show()

# Weekly Spending
weekly_spending = df.groupby("weekofyear")["Balance"].sum()
plt.figure(figsize=(10, 4))
weekly_spending.plot(kind="bar", color="blue")
plt.title("Weekly Spending Trend")
plt.ylabel("Amount Spent")
plt.show()

# Monthly Spending
monthly_spending = df.groupby("month")["Balance"].sum()
plt.figure(figsize=(10, 4))
monthly_spending.plot(kind="bar", color="green")
plt.title("Monthly Spending Trend")
plt.ylabel("Amount Spent")
plt.show()

# %%
avg_transaction_size = df["Balance"].abs().mean()
print(f"Average Transaction Size: {avg_transaction_size}")
# Out:
# Average Transaction Size: 1619.971835357625

# %%
high_spending_month = monthly_spending.idxmax()
low_spending_month = monthly_spending.idxmin()

print(f"Highest Spending Month: {high_spending_month}")
print(f"Lowest Spending Month: {low_spending_month}")
# Out:
# Highest Spending Month: 4
# Lowest Spending Month: 2

# %%
# Count transactions per UPI ID
transaction_counts = df['UPI ID'].value_counts().reset_index()
transaction_counts.columns = ['UPI ID', 'Transaction Frequency']
# transaction_counts
# Merge with original data
# df = df.merge(transaction_counts, on='UPI ID')

# %%
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])

# Aggregate transaction counts per UPI ID on a weekly basis
df['week'] = df['Transaction Date'].dt.isocalendar().week
weekly_counts = df.groupby(['UPI ID', 'week'])['transaction_amount'].sum().reset_index()

weekly_counts
# Out:
#          UPI ID  week  transaction_amount
# 0    0791363A00    35               30.00
# 1    7045314562     8                0.00
# 2    7264817938    23                0.00
# 3    7448295363    49                1.00
# 4    7770074874    46                0.00
# ..          ...   ...                 ...
# 502  vinayracha    38              116.00
# 503  vyapar.170    24              210.00
# 504  write2adit    17               71.00
# 505  zomatoorde    44              576.00
# 506  zomatoorde    45              295.78
#
# [507 rows x 3 columns]

# %%
# from sklearn.cluster import KMeans
# import numpy as np

# # Prepare clustering data
# X = df[['transaction_amount', 'Transaction Frequency']].values

# # Apply K-Means clustering
# kmeans = KMeans(n_clusters=3, random_state=42)
# df['Cluster'] = kmeans.fit_predict(X)

# df[['UPI ID', 'transaction_amount', 'Transaction Frequency', 'Cluster']]

# %%
def categorize_transaction(amount):
    if amount < 100:
        return 'Small Vendor'
    elif amount <500:
        return 'Medium Vendor'
    else:
        return 'Large Vendor'

df['Category'] = df['Balance'].apply(categorize_transaction)
df[['UPI ID', 'Balance', 'Category']]
# Out:
#          UPI ID  Balance       Category
# 0    paytmqr1jc   954.40   Large Vendor
# 1           NaN  1454.40   Large Vendor
# 2    vinayakpbh  1390.40   Large Vendor
# 3           NaN  2890.40   Large Vendor
# 4    airtelprep  2171.40   Large Vendor
# ..          ...      ...            ...
# 736  shubhamraj  1355.38   Large Vendor
# 737  paytmqr281  1340.38   Large Vendor
# 738  burgerking   964.48   Large Vendor
# 739         NaN  1114.48   Large Vendor
# 740  techanalog   114.48  Medium Vendor
#
# [741 rows x 3 columns]

# %%
def total_transactions():
    grouped = df.groupby(["Recipient Name"]).agg(
        transaction_count=("Transaction ID", "count")
    ).reset_index()
    
    table = PrettyTable(["Recipient Name", "Total Transactions"])
    for _, row in grouped.iterrows():
        table.add_row([row["Recipient Name"], row["transaction_count"]])
    
    print("Total Transactions Summary")
    print(table)

# total_transactions()

# %%
def print_selected_columns(df, columns):
    for index, row in df.iterrows():
        print(f"Row {index}:")
        for col in columns:
            if col in df.columns:
                print(f"  {col}: {row[col]}")
            else:
                print(f"  {col}: Column not found!")
        print("-" * 50)  # Separator for better readability

# Example usage:
selected_columns = ["Recipient Name","UPI ID", "Note"]  # Replace with actual column names
print_selected_columns(df, selected_columns)
# Out:
# Row 0:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: baker
# --------------------------------------------------
# Row 1:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 2:
#   Recipient Name: VINAYAK
#   UPI ID: vinayakpbh
#   Note: UPI
# --------------------------------------------------
# Row 3:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 4:
#   Recipient Name: BHARTI A
#   UPI ID: airtelprep
#   Note: Payme
# --------------------------------------------------
# Row 5:
#   Recipient Name: XX4470
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 6:
#   Recipient Name: NETFLIX
#   UPI ID: netflixupi
#   Note: Month
# --------------------------------------------------
# Row 7:
#   Recipient Name: VINAYAK
#   UPI ID: vinayakpbh
#   Note: UPI
# --------------------------------------------------
# Row 8:
#   Recipient Name: ANUSHKA
#   UPI ID: anushkashe
#   Note: UPI
# --------------------------------------------------
# Row 9:
#   Recipient Name: SHUBHAM
#   UPI ID: shubhamraj
#   Note: wet a
# --------------------------------------------------
# Row 10:
#   Recipient Name: VENKATES
#   UPI ID: chettiarpr
#   Note: UPI
# --------------------------------------------------
# Row 11:
#   Recipient Name: AASHAY M
#   UPI ID: aashayj27@
#   Note: UPI
# --------------------------------------------------
# Row 12:
#   Recipient Name: HARSHBA
#   UPI ID: 9833252222
#   Note: Sent
# --------------------------------------------------
# Row 13:
#   Recipient Name: ALPHAVI
#   UPI ID: alpharane2
#   Note: UPI
# --------------------------------------------------
# Row 14:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 15:
#   Recipient Name: MAYABHA
#   UPI ID: mayabhanus
#   Note: From
# --------------------------------------------------
# Row 16:
#   Recipient Name: IndianR
#   UPI ID: paytm-6467
#   Note: UPI
# --------------------------------------------------
# Row 17:
#   Recipient Name: VINAYAK
#   UPI ID: vinayakpbh
#   Note: UPI
# --------------------------------------------------
# Row 18:
#   Recipient Name: IMAGICAA
#   UPI ID: imagicaalo
#   Note: Payme
# --------------------------------------------------
# Row 19:
#   Recipient Name: VINAYAK
#   UPI ID: vinayakpbh
#   Note: UPI
# --------------------------------------------------
# Row 20:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 21:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: UPI
# --------------------------------------------------
# Row 22:
#   Recipient Name: MAYABHA
#   UPI ID: mayabhanus
#   Note: UPI
# --------------------------------------------------
# Row 23:
#   Recipient Name: BIKANER
#   UPI ID: paytmqr15x
#   Note: groce
# --------------------------------------------------
# Row 24:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 25:
#   Recipient Name: NEWSHRI
#   UPI ID: q168215144
#   Note: UPI
# --------------------------------------------------
# Row 26:
#   Recipient Name: AASHAY M
#   UPI ID: aashayj27@
#   Note: UPI
# --------------------------------------------------
# Row 27:
#   Recipient Name: ASIMHEM
#   UPI ID: asimshah21
#   Note: UPI
# --------------------------------------------------
# Row 28:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 29:
#   Recipient Name: IndianR
#   UPI ID: railsbiupi
#   Note: Railw
# --------------------------------------------------
# Row 30:
#   Recipient Name: MANSAROV
#   UPI ID: paytmqruee
#   Note: UPI
# --------------------------------------------------
# Row 31:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 32:
#   Recipient Name: GOOGLEPAY
#   UPI ID: goog-payme
#   Note: UPI
# --------------------------------------------------
# Row 33:
#   Recipient Name: ALPHAVI
#   UPI ID: alpharane2
#   Note: UPI
# --------------------------------------------------
# Row 34:
#   Recipient Name: SUNILSH
#   UPI ID: paytmqryb4
#   Note: food
# --------------------------------------------------
# Row 35:
#   Recipient Name: AASHAY M
#   UPI ID: aashayj27@
#   Note: UPI
# --------------------------------------------------
# Row 36:
#   Recipient Name: ALPHAVI
#   UPI ID: alpharane2
#   Note: UPI
# --------------------------------------------------
# Row 37:
#   Recipient Name: VINAYAK
#   UPI ID: vinayakpbh
#   Note: UPI
# --------------------------------------------------
# Row 38:
#   Recipient Name: VINAYAK
#   UPI ID: vinayakpbh
#   Note: UPI
# --------------------------------------------------
# Row 39:
#   Recipient Name: DEEPANSH
#   UPI ID: deepanshua
#   Note: UPI
# --------------------------------------------------
# Row 40:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: milk
# --------------------------------------------------
# Row 41:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 42:
#   Recipient Name: ASHARAF P
#   UPI ID: q271085757
#   Note: UPI
# --------------------------------------------------
# Row 43:
#   Recipient Name: MumbaiM
#   UPI ID: q06492713@
#   Note: UPI
# --------------------------------------------------
# Row 44:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 45:
#   Recipient Name: ANUSHKA
#   UPI ID: anushkashe
#   Note: UPI
# --------------------------------------------------
# Row 46:
#   Recipient Name: ADITISH
#   UPI ID: write2adit
#   Note: UPI
# --------------------------------------------------
# Row 47:
#   Recipient Name: SANGEPU
#   UPI ID: sangepuapa
#   Note: UPI
# --------------------------------------------------
# Row 48:
#   Recipient Name: VINAYAK
#   UPI ID: vinayakpbh
#   Note: ipl a
# --------------------------------------------------
# Row 49:
#   Recipient Name: AASHAY M
#   UPI ID: aashayj27@
#   Note: UPI
# --------------------------------------------------
# Row 50:
#   Recipient Name: AASHAY M
#   UPI ID: aashayj27@
#   Note: UPI
# --------------------------------------------------
# Row 51:
#   Recipient Name: HarPass
#   UPI ID: paytg.prem
#   Note: FINO
# --------------------------------------------------
# Row 52:
#   Recipient Name: SHUBHAM
#   UPI ID: shubhamraj
#   Note: UPI
# --------------------------------------------------
# Row 53:
#   Recipient Name: AASHAY M
#   UPI ID: aashayj27@
#   Note: UPI
# --------------------------------------------------
# Row 54:
#   Recipient Name: Tungares
#   UPI ID: q753314637
#   Note: UPI
# --------------------------------------------------
# Row 55:
#   Recipient Name: PRATHAM
#   UPI ID: 8446278122
#   Note: nan
# --------------------------------------------------
# Row 56:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 57:
#   Recipient Name: BHARTI A
#   UPI ID: airtelprep
#   Note: Payme
# --------------------------------------------------
# Row 58:
#   Recipient Name: Pratham
#   UPI ID: prathamshi
#   Note: UPI
# --------------------------------------------------
# Row 59:
#   Recipient Name: ASHARAF P
#   UPI ID: q271085757
#   Note: UPI
# --------------------------------------------------
# Row 60:
#   Recipient Name: HARDCAST
#   UPI ID: mcdonaldsi
#   Note: Payme
# --------------------------------------------------
# Row 61:
#   Recipient Name: SHINDE R
#   UPI ID: shinderayc
#   Note: UPI
# --------------------------------------------------
# Row 62:
#   Recipient Name: XX9209
#   UPI ID: nan
#   Note: Transafer-
# --------------------------------------------------
# Row 63:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 64:
#   Recipient Name: SHUBHAM
#   UPI ID: shubhamraj
#   Note: UPI
# --------------------------------------------------
# Row 65:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 66:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: shubh
# --------------------------------------------------
# Row 67:
#   Recipient Name: Pratham
#   UPI ID: prathamshi
#   Note: UPI
# --------------------------------------------------
# Row 68:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 69:
#   Recipient Name: Romaxes
#   UPI ID: paytg.snap
#   Note: FINO
# --------------------------------------------------
# Row 70:
#   Recipient Name: MANSAROV
#   UPI ID: paytmqruee
#   Note: food
# --------------------------------------------------
# Row 71:
#   Recipient Name: Sahanic
#   UPI ID: q152631433
#   Note: UPI
# --------------------------------------------------
# Row 72:
#   Recipient Name: HARDCAST
#   UPI ID: mcdonaldsi
#   Note: Payme
# --------------------------------------------------
# Row 73:
#   Recipient Name: Fivestar
#   UPI ID: paytg.five
#   Note: FINO
# --------------------------------------------------
# Row 74:
#   Recipient Name: XX9209
#   UPI ID: nan
#   Note: Transafer-
# --------------------------------------------------
# Row 75:
#   Recipient Name: Fivestar
#   UPI ID: pfintec.fi
#   Note: Colle
# --------------------------------------------------
# Row 76:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 77:
#   Recipient Name: XX1642
#   UPI ID: nan
#   Note: Remitterin-
# --------------------------------------------------
# Row 78:
#   Recipient Name: shubhamr
#   UPI ID: shubhamraj
#   Note: UPI
# --------------------------------------------------
# Row 79:
#   Recipient Name: prathams
#   UPI ID: prathamshi
#   Note: UPI
# --------------------------------------------------
# Row 80:
#   Recipient Name: vihaansh
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 81:
#   Recipient Name: SHUBHAM
#   UPI ID: shubhamraj
#   Note: UPI
# --------------------------------------------------
# Row 82:
#   Recipient Name: XX4470
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 83:
#   Recipient Name: Pradhan
#   UPI ID: paytmqr8hy
#   Note: medic
# --------------------------------------------------
# Row 84:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 85:
#   Recipient Name: MCDONALDS
#   UPI ID: mcdonalds.
#   Note: UPI
# --------------------------------------------------
# Row 86:
#   Recipient Name: TECHANA
#   UPI ID: techanalog
#   Note: Payvi
# --------------------------------------------------
# Row 87:
#   Recipient Name: Reliant
#   UPI ID: paytg.fcai
#   Note: FINO
# --------------------------------------------------
# Row 88:
#   Recipient Name: BasicSy
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 89:
#   Recipient Name: BasicSy
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 90:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 91:
#   Recipient Name: Reliant
#   UPI ID: paytg.fcai
#   Note: FINO
# --------------------------------------------------
# Row 92:
#   Recipient Name: SHUBHAM
#   UPI ID: shubhamraj
#   Note: UPI
# --------------------------------------------------
# Row 93:
#   Recipient Name: Anytime
#   UPI ID: pfintec.an
#   Note: Colle
# --------------------------------------------------
# Row 94:
#   Recipient Name: GeetaCl
#   UPI ID: q752133341
#   Note: UPI
# --------------------------------------------------
# Row 95:
#   Recipient Name: NETFLIX
#   UPI ID: netflixupi
#   Note: Month
# --------------------------------------------------
# Row 96:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 97:
#   Recipient Name: IndianR
#   UPI ID: railsbiupi
#   Note: UPI
# --------------------------------------------------
# Row 98:
#   Recipient Name: IndianR
#   UPI ID: railsbiupi
#   Note: UPI
# --------------------------------------------------
# Row 99:
#   Recipient Name: SHUBHAM
#   UPI ID: shubhamraj
#   Note: UPI
# --------------------------------------------------
# Row 100:
#   Recipient Name: GIRISHN
#   UPI ID: nirajpande
#   Note: UPI
# --------------------------------------------------
# Row 101:
#   Recipient Name: SUNILSH
#   UPI ID: paytmqr14k
#   Note: food
# --------------------------------------------------
# Row 102:
#   Recipient Name: HARDCAST
#   UPI ID: mcdonaldsi
#   Note: Payme
# --------------------------------------------------
# Row 103:
#   Recipient Name: HARDCAST
#   UPI ID: mcdonaldsi
#   Note: Payme
# --------------------------------------------------
# Row 104:
#   Recipient Name: BHARTI A
#   UPI ID: airtelprep
#   Note: Payme
# --------------------------------------------------
# Row 105:
#   Recipient Name: Pratham
#   UPI ID: prathamshi
#   Note: UPI
# --------------------------------------------------
# Row 106:
#   Recipient Name: MadAbou
#   UPI ID: madaboutsp
#   Note: Payme
# --------------------------------------------------
# Row 107:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 108:
#   Recipient Name: XX4470
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 109:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 110:
#   Recipient Name: vihaansh
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 111:
#   Recipient Name: PULKITM
#   UPI ID: 8237599879
#   Note: na
# --------------------------------------------------
# Row 112:
#   Recipient Name: FLOURWOR
#   UPI ID: flourworks
#   Note: Payvi
# --------------------------------------------------
# Row 113:
#   Recipient Name: REVERSAL-
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 114:
#   Recipient Name: ROHITMA
#   UPI ID: rohitavshe
#   Note: UPI
# --------------------------------------------------
# Row 115:
#   Recipient Name: SHLOKSA
#   UPI ID: shloksm28-
#   Note: UPI
# --------------------------------------------------
# Row 116:
#   Recipient Name: KARTIK
#   UPI ID: 7264817938
#   Note: Sent
# --------------------------------------------------
# Row 117:
#   Recipient Name: MANASI N
#   UPI ID: mnk2017sam
#   Note: aksha
# --------------------------------------------------
# Row 118:
#   Recipient Name: SHINDE R
#   UPI ID: shinderayc
#   Note: UPI
# --------------------------------------------------
# Row 119:
#   Recipient Name: Mangalde
#   UPI ID: gpay-11204
#   Note: UPI
# --------------------------------------------------
# Row 120:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: milk
# --------------------------------------------------
# Row 121:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 122:
#   Recipient Name: PULKITM
#   UPI ID: pulkit3010
#   Note: UPI
# --------------------------------------------------
# Row 123:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: baker
# --------------------------------------------------
# Row 124:
#   Recipient Name: SHIVSAGA
#   UPI ID: paytmqr1jg
#   Note: panee
# --------------------------------------------------
# Row 125:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: baker
# --------------------------------------------------
# Row 126:
#   Recipient Name: SHLOKSA
#   UPI ID: shloksm28-
#   Note: UPI
# --------------------------------------------------
# Row 127:
#   Recipient Name: PULKITM
#   UPI ID: pulkit3010
#   Note: UPI
# --------------------------------------------------
# Row 128:
#   Recipient Name: PULKITM
#   UPI ID: pulkit3010
#   Note: UPI
# --------------------------------------------------
# Row 129:
#   Recipient Name: PULKITM
#   UPI ID: pulkit3010
#   Note: UPI
# --------------------------------------------------
# Row 130:
#   Recipient Name: SAMEER B
#   UPI ID: sawant.123
#   Note: UPI
# --------------------------------------------------
# Row 131:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: milk
# --------------------------------------------------
# Row 132:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 133:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 134:
#   Recipient Name: VARIETY
#   UPI ID: vyapar.170
#   Note: food
# --------------------------------------------------
# Row 135:
#   Recipient Name: SNEHADI
#   UPI ID: ss280387-1
#   Note: UPI
# --------------------------------------------------
# Row 136:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: baker
# --------------------------------------------------
# Row 137:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: milk
# --------------------------------------------------
# Row 138:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: baker
# --------------------------------------------------
# Row 139:
#   Recipient Name: SOHAM KA
#   UPI ID: sohamgondh
#   Note: UPI
# --------------------------------------------------
# Row 140:
#   Recipient Name: IndianR
#   UPI ID: paytm-6467
#   Note: UPI
# --------------------------------------------------
# Row 141:
#   Recipient Name: IndianR
#   UPI ID: paytm-6467
#   Note: UPI
# --------------------------------------------------
# Row 142:
#   Recipient Name: SOHAM KA
#   UPI ID: sohamgondh
#   Note: UPI
# --------------------------------------------------
# Row 143:
#   Recipient Name: SHLOKSA
#   UPI ID: shloksm28-
#   Note: UPI
# --------------------------------------------------
# Row 144:
#   Recipient Name: SANUKUM
#   UPI ID: q697365409
#   Note: food
# --------------------------------------------------
# Row 145:
#   Recipient Name: SHLOKSA
#   UPI ID: shloksm28-
#   Note: UPI
# --------------------------------------------------
# Row 146:
#   Recipient Name: SHLOKSA
#   UPI ID: shloksm28-
#   Note: UPI
# --------------------------------------------------
# Row 147:
#   Recipient Name: SOHAM KA
#   UPI ID: sohamgondh
#   Note: UPI
# --------------------------------------------------
# Row 148:
#   Recipient Name: GROUPON
#   UPI ID: pfintec.gr
#   Note: Colle
# --------------------------------------------------
# Row 149:
#   Recipient Name: XX9209
#   UPI ID: nan
#   Note: Transafer-
# --------------------------------------------------
# Row 150:
#   Recipient Name: SHLOKSA
#   UPI ID: shloksm28-
#   Note: UPI
# --------------------------------------------------
# Row 151:
#   Recipient Name: SOHAM KA
#   UPI ID: sohamgondh
#   Note: UPI
# --------------------------------------------------
# Row 152:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 153:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: UPI
# --------------------------------------------------
# Row 154:
#   Recipient Name: CHITRA C
#   UPI ID: mswipe.140
#   Note: UPI
# --------------------------------------------------
# Row 155:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: milk
# --------------------------------------------------
# Row 156:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 157:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: baker
# --------------------------------------------------
# Row 158:
#   Recipient Name: SHIVSAGA
#   UPI ID: paytmqr56u
#   Note: panee
# --------------------------------------------------
# Row 159:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: baker
# --------------------------------------------------
# Row 160:
#   Recipient Name: MCDONALDS
#   UPI ID: mcdonalds.
#   Note: UPI
# --------------------------------------------------
# Row 161:
#   Recipient Name: BHARTI A
#   UPI ID: airtelprep
#   Note: Payme
# --------------------------------------------------
# Row 162:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: UPI
# --------------------------------------------------
# Row 163:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: milk
# --------------------------------------------------
# Row 164:
#   Recipient Name: TANISH NX
#   UPI ID: q389445684
#   Note: UPI
# --------------------------------------------------
# Row 165:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 166:
#   Recipient Name: SISINTY
#   UPI ID: sisinty795
#   Note: Paymen
# --------------------------------------------------
# Row 167:
#   Recipient Name: BIKANER
#   UPI ID: paytmqr15x
#   Note: groce
# --------------------------------------------------
# Row 168:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: baker
# --------------------------------------------------
# Row 169:
#   Recipient Name: XX9209
#   UPI ID: nan
#   Note: Transafer-
# --------------------------------------------------
# Row 170:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 171:
#   Recipient Name: SHUBHAM
#   UPI ID: shubhamraj
#   Note: UPI
# --------------------------------------------------
# Row 172:
#   Recipient Name: XX9209
#   UPI ID: nan
#   Note: Transafer-
# --------------------------------------------------
# Row 173:
#   Recipient Name: Pratham
#   UPI ID: prathamshi
#   Note: UPI
# --------------------------------------------------
# Row 174:
#   Recipient Name: POOJANA
#   UPI ID: q699866917
#   Note: UPI
# --------------------------------------------------
# Row 175:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: milk
# --------------------------------------------------
# Row 176:
#   Recipient Name: BHARTI A
#   UPI ID: airtelprep
#   Note: Payme
# --------------------------------------------------
# Row 177:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: baker
# --------------------------------------------------
# Row 178:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 179:
#   Recipient Name: HARDCAST
#   UPI ID: mcdonaldsi
#   Note: Payme
# --------------------------------------------------
# Row 180:
#   Recipient Name: AirtelP
#   UPI ID: airtel-rec
#   Note: UPI
# --------------------------------------------------
# Row 181:
#   Recipient Name: NETFLIX
#   UPI ID: netflixupi
#   Note: Month
# --------------------------------------------------
# Row 182:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: UPI
# --------------------------------------------------
# Row 183:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 184:
#   Recipient Name: SUNILSH
#   UPI ID: paytmqr14k
#   Note: food
# --------------------------------------------------
# Row 185:
#   Recipient Name: PARIJATH
#   UPI ID: paytmqr1d4
#   Note: food
# --------------------------------------------------
# Row 186:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: UPI
# --------------------------------------------------
# Row 187:
#   Recipient Name: XX4470
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 188:
#   Recipient Name: SPIT
#   UPI ID: spit.easeb
#   Note: Pay
# --------------------------------------------------
# Row 189:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: milk
# --------------------------------------------------
# Row 190:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: baker
# --------------------------------------------------
# Row 191:
#   Recipient Name: SAMEER B
#   UPI ID: sawant.123
#   Note: UPI
# --------------------------------------------------
# Row 192:
#   Recipient Name: Airtel
#   UPI ID: airtel-pre
#   Note: UPI
# --------------------------------------------------
# Row 193:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: milk
# --------------------------------------------------
# Row 194:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: baker
# --------------------------------------------------
# Row 195:
#   Recipient Name: SHIVSAGA
#   UPI ID: paytmqr56u
#   Note: panee
# --------------------------------------------------
# Row 196:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: UPI
# --------------------------------------------------
# Row 197:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: milk
# --------------------------------------------------
# Row 198:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr1jc
#   Note: baker
# --------------------------------------------------
# Row 199:
#   Recipient Name: ICI-XX237-SAMEER B
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 200:
#   Recipient Name: IRCTCUTS
#   UPI ID: paytm-8727
#   Note: UPI
# --------------------------------------------------
# Row 201:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 202:
#   Recipient Name: IndianR
#   UPI ID: railsbiupi
#   Note: UPI
# --------------------------------------------------
# Row 203:
#   Recipient Name: CHH.SHIV
#   UPI ID: csmvscurre
#   Note: UPI
# --------------------------------------------------
# Row 204:
#   Recipient Name: VENKATES
#   UPI ID: chettiarpr
#   Note: UPI
# --------------------------------------------------
# Row 205:
#   Recipient Name: ALPHAVI
#   UPI ID: alpharane2
#   Note: be ha
# --------------------------------------------------
# Row 206:
#   Recipient Name: ALPHAVI
#   UPI ID: alpharane2
#   Note: UPI
# --------------------------------------------------
# Row 207:
#   Recipient Name: RE1-XX470-SAMEER B
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 208:
#   Recipient Name: IndianR
#   UPI ID: railsbiupi
#   Note: UPI
# --------------------------------------------------
# Row 209:
#   Recipient Name: IndianR
#   UPI ID: railsbiupi
#   Note: UPI
# --------------------------------------------------
# Row 210:
#   Recipient Name: AakashP
#   UPI ID: paytmqr1di
#   Note: UPI
# --------------------------------------------------
# Row 211:
#   Recipient Name: ALLIIRF
#   UPI ID: q898155370
#   Note: UPI
# --------------------------------------------------
# Row 212:
#   Recipient Name: HOTELSH
#   UPI ID: q060864871
#   Note: UPI
# --------------------------------------------------
# Row 213:
#   Recipient Name: MayankM
#   UPI ID: paytmqr15v
#   Note: UPI
# --------------------------------------------------
# Row 214:
#   Recipient Name: ICI-XX237-SAMEER B
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 215:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 216:
#   Recipient Name: SAKSHI S
#   UPI ID: sakshisawa
#   Note: UPI
# --------------------------------------------------
# Row 217:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 218:
#   Recipient Name: ICI-XX237-SAMEER B
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 219:
#   Recipient Name: Swayam N
#   UPI ID: swayamnpte
#   Note: Swaya
# --------------------------------------------------
# Row 220:
#   Recipient Name: MumbaiM
#   UPI ID: q09778271@
#   Note: UPI
# --------------------------------------------------
# Row 221:
#   Recipient Name: SUNILSH
#   UPI ID: paytmqr3w5
#   Note: food
# --------------------------------------------------
# Row 222:
#   Recipient Name: MayankM
#   UPI ID: paytmqr15v
#   Note: UPI
# --------------------------------------------------
# Row 223:
#   Recipient Name: Pradhan
#   UPI ID: paytmqr1c1
#   Note: medic
# --------------------------------------------------
# Row 224:
#   Recipient Name: MCDONALDS
#   UPI ID: mcdonalds.
#   Note: UPI
# --------------------------------------------------
# Row 225:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: UPI
# --------------------------------------------------
# Row 226:
#   Recipient Name: BHARTI A
#   UPI ID: airtelprep
#   Note: Payme
# --------------------------------------------------
# Row 227:
#   Recipient Name: Amarfas
#   UPI ID: paytmqr1xg
#   Note: UPI
# --------------------------------------------------
# Row 228:
#   Recipient Name: BIKANER
#   UPI ID: paytmqr5an
#   Note: UPI
# --------------------------------------------------
# Row 229:
#   Recipient Name: MANSAROV
#   UPI ID: paytmqruee
#   Note: food
# --------------------------------------------------
# Row 230:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 231:
#   Recipient Name: Pratham
#   UPI ID: prathamshi
#   Note: UPI
# --------------------------------------------------
# Row 232:
#   Recipient Name: OM SAIT
#   UPI ID: q480748453
#   Note: UPI
# --------------------------------------------------
# Row 233:
#   Recipient Name: RESTAURA
#   UPI ID: burgerking
#   Note: Gener
# --------------------------------------------------
# Row 234:
#   Recipient Name: ICI-XX237-SAMEER B
#   UPI ID: nan
#   Note: NA-
# --------------------------------------------------
# Row 235:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: UPI
# --------------------------------------------------
# Row 236:
#   Recipient Name: MANSAROV
#   UPI ID: paytmqruee
#   Note: food
# --------------------------------------------------
# Row 237:
#   Recipient Name: BHARTI A
#   UPI ID: airtelprep
#   Note: Payme
# --------------------------------------------------
# Row 238:
#   Recipient Name: BHARTI A
#   UPI ID: airtelprep
#   Note: Payme
# --------------------------------------------------
# Row 239:
#   Recipient Name: RE1-XX470-SAMEER B
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 240:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: milk
# --------------------------------------------------
# Row 241:
#   Recipient Name: SHIVSAGA
#   UPI ID: paytmqr56u
#   Note: UPI
# --------------------------------------------------
# Row 242:
#   Recipient Name: HOTELSH
#   UPI ID: q060864871
#   Note: UPI
# --------------------------------------------------
# Row 243:
#   Recipient Name: JULFIKAR
#   UPI ID: bharatpe.8
#   Note: Pay T
# --------------------------------------------------
# Row 244:
#   Recipient Name: OM SAIT
#   UPI ID: q480748453
#   Note: food
# --------------------------------------------------
# Row 245:
#   Recipient Name: MUMBAI M
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 246:
#   Recipient Name: KRISHNAP
#   UPI ID: paytmqr1bi
#   Note: UPI
# --------------------------------------------------
# Row 247:
#   Recipient Name: SUNILSH
#   UPI ID: paytmqr3w5
#   Note: food
# --------------------------------------------------
# Row 248:
#   Recipient Name: JUMBOKI
#   UPI ID: paytmqr14h
#   Note: food
# --------------------------------------------------
# Row 249:
#   Recipient Name: APPASAHE
#   UPI ID: q698438155
#   Note: UPI
# --------------------------------------------------
# Row 250:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 251:
#   Recipient Name: SUNILSH
#   UPI ID: paytmqr3w5
#   Note: food
# --------------------------------------------------
# Row 252:
#   Recipient Name: DILIPKU
#   UPI ID: paytmqr5cb
#   Note: food
# --------------------------------------------------
# Row 253:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 254:
#   Recipient Name: ICI-XX237-SAMEER B
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 255:
#   Recipient Name: DILIPKU
#   UPI ID: paytmqr5cb
#   Note: food
# --------------------------------------------------
# Row 256:
#   Recipient Name: ALPHAVI
#   UPI ID: alpharane2
#   Note: UPI
# --------------------------------------------------
# Row 257:
#   Recipient Name: JioCinema
#   UPI ID: viacom18on
#   Note: Coll
# --------------------------------------------------
# Row 258:
#   Recipient Name: ICI-XX237-SAMEER B
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 259:
#   Recipient Name: ANAS
#   UPI ID: q582445006
#   Note: UPI
# --------------------------------------------------
# Row 260:
#   Recipient Name: PRANAV R
#   UPI ID: q674889682
#   Note: UPI
# --------------------------------------------------
# Row 261:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: UPI
# --------------------------------------------------
# Row 262:
#   Recipient Name: MCDONALDS
#   UPI ID: mcdonalds.
#   Note: Gen
# --------------------------------------------------
# Row 263:
#   Recipient Name: MANSAROV
#   UPI ID: paytmqr5dq
#   Note: food
# --------------------------------------------------
# Row 264:
#   Recipient Name: RE1-XX470-SAMEER B
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 265:
#   Recipient Name: SUNILSH
#   UPI ID: paytmqr14k
#   Note: food
# --------------------------------------------------
# Row 266:
#   Recipient Name: OM SAIT
#   UPI ID: q480748453
#   Note: UPI
# --------------------------------------------------
# Row 267:
#   Recipient Name: CANEZZA
#   UPI ID: q591263088
#   Note: UPI
# --------------------------------------------------
# Row 268:
#   Recipient Name: BHARTI A
#   UPI ID: airtelprep
#   Note: Payme
# --------------------------------------------------
# Row 269:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 270:
#   Recipient Name: RAHULY
#   UPI ID: q641304611
#   Note: UPI
# --------------------------------------------------
# Row 271:
#   Recipient Name: BHARTI A
#   UPI ID: airtelprep
#   Note: Payme
# --------------------------------------------------
# Row 272:
#   Recipient Name: RE1-XX470-SAMEER B
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 273:
#   Recipient Name: TRENTHY
#   UPI ID: starbazaar
#   Note: Payme
# --------------------------------------------------
# Row 274:
#   Recipient Name: ADITYAB
#   UPI ID: pantaloons
#   Note: UPI
# --------------------------------------------------
# Row 275:
#   Recipient Name: StyleUp
#   UPI ID: q17788785@
#   Note: UPI
# --------------------------------------------------
# Row 276:
#   Recipient Name: TRENTHY
#   UPI ID: starbazaar
#   Note: Payme
# --------------------------------------------------
# Row 277:
#   Recipient Name: FANISH F
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 278:
#   Recipient Name: ICI-XX237-SAMEER B
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 279:
#   Recipient Name: SHUBHAM
#   UPI ID: shubhamraj
#   Note: Sent
# --------------------------------------------------
# Row 280:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 281:
#   Recipient Name: MAHENDRA
#   UPI ID: paytmqr593
#   Note: UPI
# --------------------------------------------------
# Row 282:
#   Recipient Name: ICI-XX237-SAMEER B
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 283:
#   Recipient Name: Bombay B
#   UPI ID: 8850949354
#   Note: UPI
# --------------------------------------------------
# Row 284:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 285:
#   Recipient Name: KAYUMAL
#   UPI ID: bharatpe9h
#   Note: Pay t
# --------------------------------------------------
# Row 286:
#   Recipient Name: KARTIK
#   UPI ID: jayashreer
#   Note: UPI
# --------------------------------------------------
# Row 287:
#   Recipient Name: SANJAY A
#   UPI ID: sanjay.gup
#   Note: UPI
# --------------------------------------------------
# Row 288:
#   Recipient Name: JioCinema
#   UPI ID: viacom18on
#   Note: Subs
# --------------------------------------------------
# Row 289:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: UPI
# --------------------------------------------------
# Row 290:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: UPI
# --------------------------------------------------
# Row 291:
#   Recipient Name: ZOMATO L
#   UPI ID: zomatoorde
#   Note: UPI
# --------------------------------------------------
# Row 292:
#   Recipient Name: MrRAVIK
#   UPI ID: q122854506
#   Note: UPI
# --------------------------------------------------
# Row 293:
#   Recipient Name: Pradhan
#   UPI ID: paytmqr1c1
#   Note: UPI
# --------------------------------------------------
# Row 294:
#   Recipient Name: SAMEER B
#   UPI ID: sawant.123
#   Note: UPI
# --------------------------------------------------
# Row 295:
#   Recipient Name: ZOMATO L
#   UPI ID: zomatoorde
#   Note: UPI
# --------------------------------------------------
# Row 296:
#   Recipient Name: DILIPKU
#   UPI ID: paytmqr5wr
#   Note: UPI
# --------------------------------------------------
# Row 297:
#   Recipient Name: SHINDE R
#   UPI ID: shinderayc
#   Note: UPI
# --------------------------------------------------
# Row 298:
#   Recipient Name: Bombay B
#   UPI ID: 8850949354
#   Note: UPI
# --------------------------------------------------
# Row 299:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 300:
#   Recipient Name: ASIMHEM
#   UPI ID: asimshah21
#   Note: UPI
# --------------------------------------------------
# Row 301:
#   Recipient Name: SAIRAJ
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 302:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: UPI
# --------------------------------------------------
# Row 303:
#   Recipient Name: PRACHI S
#   UPI ID: prachiswt2
#   Note: Pay t
# --------------------------------------------------
# Row 304:
#   Recipient Name: SNEHADI
#   UPI ID: ss280387-2
#   Note: UPI
# --------------------------------------------------
# Row 305:
#   Recipient Name: IndianR
#   UPI ID: paytm-6467
#   Note: UPI
# --------------------------------------------------
# Row 306:
#   Recipient Name: PRATHAM
#   UPI ID: 8446278122
#   Note: nan
# --------------------------------------------------
# Row 307:
#   Recipient Name: Atharva
#   UPI ID: atharvapat
#   Note: UPI
# --------------------------------------------------
# Row 308:
#   Recipient Name: Atharva
#   UPI ID: atharvapat
#   Note: UPI
# --------------------------------------------------
# Row 309:
#   Recipient Name: SHETHNI
#   UPI ID: nimitsheth
#   Note: UPI
# --------------------------------------------------
# Row 310:
#   Recipient Name: MumbaiM
#   UPI ID: q06492713@
#   Note: UPI
# --------------------------------------------------
# Row 311:
#   Recipient Name: IndianR
#   UPI ID: railsbiupi
#   Note: Railw
# --------------------------------------------------
# Row 312:
#   Recipient Name: HARDCAST
#   UPI ID: mcdonaldsi
#   Note: Payme
# --------------------------------------------------
# Row 313:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 314:
#   Recipient Name: NAIMSHA
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 315:
#   Recipient Name: Mohammad
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 316:
#   Recipient Name: Basixxxx
#   UPI ID: paytmqr281
#   Note: nan
# --------------------------------------------------
# Row 317:
#   Recipient Name: Basixxxx
#   UPI ID: paytm-6927
#   Note: Oid20
# --------------------------------------------------
# Row 318:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 319:
#   Recipient Name: JUMBOKI
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 320:
#   Recipient Name: SUNILSH
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 321:
#   Recipient Name: AASHAY M
#   UPI ID: aashayj27@
#   Note: UPI
# --------------------------------------------------
# Row 322:
#   Recipient Name: MOBIKWIK
#   UPI ID: ombk.lbfaa
#   Note: UPI
# --------------------------------------------------
# Row 323:
#   Recipient Name: JitenIs
#   UPI ID: 9860566455
#   Note: Payme
# --------------------------------------------------
# Row 324:
#   Recipient Name: Pratham
#   UPI ID: 8446278122
#   Note: nan
# --------------------------------------------------
# Row 325:
#   Recipient Name: Vendiman
#   UPI ID: paytm-0401
#   Note: OidQy
# --------------------------------------------------
# Row 326:
#   Recipient Name: SHUSHMA
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 327:
#   Recipient Name: Vendiman
#   UPI ID: paytm-0401
#   Note: Oidrg
# --------------------------------------------------
# Row 328:
#   Recipient Name: SIDDHART
#   UPI ID: q230851695
#   Note: UPI
# --------------------------------------------------
# Row 329:
#   Recipient Name: GUDLARU
#   UPI ID: 9850344585
#   Note: Payme
# --------------------------------------------------
# Row 330:
#   Recipient Name: Pratham
#   UPI ID: 8446278122
#   Note: nan
# --------------------------------------------------
# Row 331:
#   Recipient Name: BIKANER
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 332:
#   Recipient Name: VIKASH
#   UPI ID: q927921157
#   Note: UPI
# --------------------------------------------------
# Row 333:
#   Recipient Name: SATISHPR
#   UPI ID: q506304237
#   Note: UPI
# --------------------------------------------------
# Row 334:
#   Recipient Name: GUPTAGE
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 335:
#   Recipient Name: ASHISH A
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 336:
#   Recipient Name: NIMISHB
#   UPI ID: nimishwarg
#   Note: UPI
# --------------------------------------------------
# Row 337:
#   Recipient Name: PRAVEEN
#   UPI ID: q840397115
#   Note: UPI
# --------------------------------------------------
# Row 338:
#   Recipient Name: ParamAn
#   UPI ID: paramgogia
#   Note: UPI
# --------------------------------------------------
# Row 339:
#   Recipient Name: SHUBHAM
#   UPI ID: shubhamraj
#   Note: UPI
# --------------------------------------------------
# Row 340:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 341:
#   Recipient Name: Dream11
#   UPI ID: dream11@ax
#   Note: Pay to
# --------------------------------------------------
# Row 342:
#   Recipient Name: SATISHPR
#   UPI ID: Q506304237
#   Note: nan
# --------------------------------------------------
# Row 343:
#   Recipient Name: NewIdea
#   UPI ID: gpay-11208
#   Note: UPI
# --------------------------------------------------
# Row 344:
#   Recipient Name: MANGESH
#   UPI ID: paytmqr1db
#   Note: UPI
# --------------------------------------------------
# Row 345:
#   Recipient Name: SATISHPR
#   UPI ID: q506304237
#   Note: UPI
# --------------------------------------------------
# Row 346:
#   Recipient Name: JULFIKAR
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 347:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 348:
#   Recipient Name: KIRTIBO
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 349:
#   Recipient Name: PRATIMA
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 350:
#   Recipient Name: NAIMSHA
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 351:
#   Recipient Name: DailyFr
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 352:
#   Recipient Name: KIRANSH
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 353:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: son
# --------------------------------------------------
# Row 354:
#   Recipient Name: PRABIR M
#   UPI ID: fcbizok69u
#   Note: UPI
# --------------------------------------------------
# Row 355:
#   Recipient Name: JAVEDRA
#   UPI ID: bharatpe09
#   Note: UPI
# --------------------------------------------------
# Row 356:
#   Recipient Name: JUMBOKI
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 357:
#   Recipient Name: Santosh
#   UPI ID: o111221438
#   Note: Payme
# --------------------------------------------------
# Row 358:
#   Recipient Name: prathams
#   UPI ID: prathamshi
#   Note: UPI
# --------------------------------------------------
# Row 359:
#   Recipient Name: VINAYAK
#   UPI ID: vinayakpbh
#   Note: UPI
# --------------------------------------------------
# Row 360:
#   Recipient Name: 7ELEVEN
#   UPI ID: 7eleven.42
#   Note: UPI
# --------------------------------------------------
# Row 361:
#   Recipient Name: PRAMOD A
#   UPI ID: q832205277
#   Note: UPI
# --------------------------------------------------
# Row 362:
#   Recipient Name: Mangalde
#   UPI ID: gpay-11204
#   Note: groce
# --------------------------------------------------
# Row 363:
#   Recipient Name: METROSW
#   UPI ID: paytmqr12u
#   Note: UPI
# --------------------------------------------------
# Row 364:
#   Recipient Name: SHLOKSA
#   UPI ID: shloksm28-
#   Note: UPI
# --------------------------------------------------
# Row 365:
#   Recipient Name: MMOAndh
#   UPI ID: q812920291
#   Note: UPI
# --------------------------------------------------
# Row 366:
#   Recipient Name: Pratham
#   UPI ID: 8446278122
#   Note: nan
# --------------------------------------------------
# Row 367:
#   Recipient Name: MrTUFAN
#   UPI ID: guptatufan
#   Note: UPI
# --------------------------------------------------
# Row 368:
#   Recipient Name: Pratham
#   UPI ID: prathamshi
#   Note: UPI
# --------------------------------------------------
# Row 369:
#   Recipient Name: METROBO
#   UPI ID: q378245066
#   Note: UPI
# --------------------------------------------------
# Row 370:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 371:
#   Recipient Name: INDRESH
#   UPI ID: prajapatii
#   Note: UPI
# --------------------------------------------------
# Row 372:
#   Recipient Name: SATISHPR
#   UPI ID: q506304237
#   Note: UPI
# --------------------------------------------------
# Row 373:
#   Recipient Name: ParamAn
#   UPI ID: paramgogia
#   Note: UPI
# --------------------------------------------------
# Row 374:
#   Recipient Name: Shivkuma
#   UPI ID: paytmqrrds
#   Note: UPI
# --------------------------------------------------
# Row 375:
#   Recipient Name: TANISH NX
#   UPI ID: q997530966
#   Note: UPI
# --------------------------------------------------
# Row 376:
#   Recipient Name: SNOWCRE
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 377:
#   Recipient Name: ARCHANA
#   UPI ID: q914951432
#   Note: UPI
# --------------------------------------------------
# Row 378:
#   Recipient Name: SUNILSH
#   UPI ID: q250642425
#   Note: UPI
# --------------------------------------------------
# Row 379:
#   Recipient Name: SHIVSAGA
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 380:
#   Recipient Name: ARCHANA
#   UPI ID: q685983762
#   Note: UPI
# --------------------------------------------------
# Row 381:
#   Recipient Name: MinhajA
#   UPI ID: paytm-3139
#   Note: Oid20
# --------------------------------------------------
# Row 382:
#   Recipient Name: AJAYRAD
#   UPI ID: paytmqrz32
#   Note: UPI
# --------------------------------------------------
# Row 383:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 384:
#   Recipient Name: Kamlesh
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 385:
#   Recipient Name: JUMBOKI
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 386:
#   Recipient Name: SATISHPR
#   UPI ID: q506304237
#   Note: UPI
# --------------------------------------------------
# Row 387:
#   Recipient Name: Krishna
#   UPI ID: paytmqrqio
#   Note: UPI
# --------------------------------------------------
# Row 388:
#   Recipient Name: MrBALIN
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 389:
#   Recipient Name: SAMEER B
#   UPI ID: sawant.123
#   Note: UPI
# --------------------------------------------------
# Row 390:
#   Recipient Name: SAMEER B
#   UPI ID: sawant.123
#   Note: UPI
# --------------------------------------------------
# Row 391:
#   Recipient Name: PRACHI S
#   UPI ID: prachi2477
#   Note: UPI
# --------------------------------------------------
# Row 392:
#   Recipient Name: SUNILSH
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 393:
#   Recipient Name: CHUNNILA
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 394:
#   Recipient Name: BIKANER
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 395:
#   Recipient Name: PRAMOD A
#   UPI ID: q832205277
#   Note: UPI
# --------------------------------------------------
# Row 396:
#   Recipient Name: JitenIs
#   UPI ID: 9860566455
#   Note: UPI
# --------------------------------------------------
# Row 397:
#   Recipient Name: SATISHPR
#   UPI ID: q506304237
#   Note: UPI
# --------------------------------------------------
# Row 398:
#   Recipient Name: MrVihaa
#   UPI ID: vihaanshin
#   Note: UPI
# --------------------------------------------------
# Row 399:
#   Recipient Name: INDRESH
#   UPI ID: prajapatii
#   Note: UPI
# --------------------------------------------------
# Row 400:
#   Recipient Name: Mansarov
#   UPI ID: paytmqrk49
#   Note: UPI
# --------------------------------------------------
# Row 401:
#   Recipient Name: ANANTCA
#   UPI ID: q828771384
#   Note: UPI
# --------------------------------------------------
# Row 402:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# ...
#   Note: UPI
# --------------------------------------------------
# Row 606:
#   Recipient Name: PRACHI S
#   UPI ID: rutuswt052
#   Note: UPI
# --------------------------------------------------
# Row 607:
#   Recipient Name: PRACHI S
#   UPI ID: rutuswt052
#   Note: UPI
# --------------------------------------------------
# Row 608:
#   Recipient Name: IndianR
#   UPI ID: paytm-6467
#   Note: UPI
# --------------------------------------------------
# Row 609:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 610:
#   Recipient Name: PARIJATH
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 611:
#   Recipient Name: 227364410404
#   UPI ID: nan
#   Note: 41014247
# --------------------------------------------------
# Row 612:
#   Recipient Name: Nayabse
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 613:
#   Recipient Name: RASHMANI
#   UPI ID: bharatpe90
#   Note: Pay T
# --------------------------------------------------
# Row 614:
#   Recipient Name: SAMREEN
#   UPI ID: sammulla21
#   Note: UPI
# --------------------------------------------------
# Row 615:
#   Recipient Name: BhartiA
#   UPI ID: airtel.pay
#   Note: UPITr
# --------------------------------------------------
# Row 616:
#   Recipient Name: Amul
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 617:
#   Recipient Name: Amul
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 618:
#   Recipient Name: TANISH NX
#   UPI ID: q127702016
#   Note: UPI
# --------------------------------------------------
# Row 619:
#   Recipient Name: SAMEER B
#   UPI ID: sawant.123
#   Note: UPI
# --------------------------------------------------
# Row 620:
#   Recipient Name: SAMEER B
#   UPI ID: samswt.123
#   Note: UPI P
# --------------------------------------------------
# Row 621:
#   Recipient Name: SAMEER B
#   UPI ID: ssawant.12
#   Note: UPI P
# --------------------------------------------------
# Row 622:
#   Recipient Name: Nayabse
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 623:
#   Recipient Name: SUNILSH
#   UPI ID: q25753740@
#   Note: UPI
# --------------------------------------------------
# Row 624:
#   Recipient Name: Amul
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 625:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 626:
#   Recipient Name: LOWPRIC
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 627:
#   Recipient Name: LOWPRIC
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 628:
#   Recipient Name: Vishalj
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 629:
#   Recipient Name: Amul
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 630:
#   Recipient Name: Julfikar
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 631:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 632:
#   Recipient Name: BhartiA
#   UPI ID: bhartiairt
#   Note: Airte
# --------------------------------------------------
# Row 633:
#   Recipient Name: GOOGLEPAY
#   UPI ID: goog-payme
#   Note: UPI
# --------------------------------------------------
# Row 634:
#   Recipient Name: PHSFIPL
#   UPI ID: phsfiplmah
#   Note: UPI
# --------------------------------------------------
# Row 635:
#   Recipient Name: SURYANSH
#   UPI ID: 7770074874
#   Note: Pizza
# --------------------------------------------------
# Row 636:
#   Recipient Name: Venisha
#   UPI ID: venishakal
#   Note: pizza
# --------------------------------------------------
# Row 637:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 638:
#   Recipient Name: Bharatpe
#   UPI ID: bharatpe.9
#   Note: Pay T
# --------------------------------------------------
# Row 639:
#   Recipient Name: NIRMALAS
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 640:
#   Recipient Name: PaytmUser
#   UPI ID: 7448295363
#   Note: UPI
# --------------------------------------------------
# Row 641:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 642:
#   Recipient Name: MumbaiM
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 643:
#   Recipient Name: Amul
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 644:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 645:
#   Recipient Name: ADITYAY
#   UPI ID: kharote64@
#   Note: UPI
# --------------------------------------------------
# Row 646:
#   Recipient Name: Amul
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 647:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 648:
#   Recipient Name: SATISHP
#   UPI ID: q306369335
#   Note: UPI
# --------------------------------------------------
# Row 649:
#   Recipient Name: SANJAY B
#   UPI ID: q465528979
#   Note: UPI
# --------------------------------------------------
# Row 650:
#   Recipient Name: BhartiA
#   UPI ID: airtel.pay
#   Note: UPITr
# --------------------------------------------------
# Row 651:
#   Recipient Name: BhartiA
#   UPI ID: airtel.pay
#   Note: RRRPP
# --------------------------------------------------
# Row 652:
#   Recipient Name: MumbaiM
#   UPI ID: q09778271@
#   Note: UPI
# --------------------------------------------------
# Row 653:
#   Recipient Name: MumbaiM
#   UPI ID: q09778271@
#   Note: UPI
# --------------------------------------------------
# Row 654:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 655:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 656:
#   Recipient Name: IndianR
#   UPI ID: paytm-6467
#   Note: UPI
# --------------------------------------------------
# Row 657:
#   Recipient Name: IndianR
#   UPI ID: paytm-6467
#   Note: UPI
# --------------------------------------------------
# Row 658:
#   Recipient Name: BHARAT K
#   UPI ID: jainb940-1
#   Note: UPI
# --------------------------------------------------
# Row 659:
#   Recipient Name: BHARAT K
#   UPI ID: jainb940-1
#   Note: UPI
# --------------------------------------------------
# Row 660:
#   Recipient Name: IndianR
#   UPI ID: paytm-6467
#   Note: UPI
# --------------------------------------------------
# Row 661:
#   Recipient Name: IndianR
#   UPI ID: paytm-6467
#   Note: UPI
# --------------------------------------------------
# Row 662:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 663:
#   Recipient Name: SWATINI
#   UPI ID: bavkarswat
#   Note: UPI
# --------------------------------------------------
# Row 664:
#   Recipient Name: IndianR
#   UPI ID: paytm-6467
#   Note: UPI
# --------------------------------------------------
# Row 665:
#   Recipient Name: PRATHAM
#   UPI ID: prathamshi
#   Note: UPI
# --------------------------------------------------
# Row 666:
#   Recipient Name: Venisha
#   UPI ID: venishakal
#   Note: UPI
# --------------------------------------------------
# Row 667:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 668:
#   Recipient Name: MumbaiM
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 669:
#   Recipient Name: KASHINAT
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 670:
#   Recipient Name: DESAIAV
#   UPI ID: q902324096
#   Note: UPI
# --------------------------------------------------
# Row 671:
#   Recipient Name: TANISH NX
#   UPI ID: q66063414@
#   Note: UPI
# --------------------------------------------------
# Row 672:
#   Recipient Name: ATHARV R
#   UPI ID: atharvbhag
#   Note: UPI
# --------------------------------------------------
# Row 673:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 674:
#   Recipient Name: XX4470
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 675:
#   Recipient Name: SONALDI
#   UPI ID: sonalghola
#   Note: UPI
# --------------------------------------------------
# Row 676:
#   Recipient Name: SAYKAT A
#   UPI ID: q611756441
#   Note: UPI
# --------------------------------------------------
# Row 677:
#   Recipient Name: IndianR
#   UPI ID: paytm-6467
#   Note: UPI
# --------------------------------------------------
# Row 678:
#   Recipient Name: DURGARAM
#   UPI ID: durgaraam6
#   Note: UPI
# --------------------------------------------------
# Row 679:
#   Recipient Name: Pratima
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 680:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 681:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 682:
#   Recipient Name: DILIPKU
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 683:
#   Recipient Name: AASHAY M
#   UPI ID: aashayj27@
#   Note: UPI
# --------------------------------------------------
# Row 684:
#   Recipient Name: Mahendra
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 685:
#   Recipient Name: Carters
#   UPI ID: mab.037322
#   Note: UPI
# --------------------------------------------------
# Row 686:
#   Recipient Name: BIKANER
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 687:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 688:
#   Recipient Name: SAMEER B
#   UPI ID: sawant.123
#   Note: UPI
# --------------------------------------------------
# Row 689:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 690:
#   Recipient Name: Atharva
#   UPI ID: atharvapat
#   Note: UPI
# --------------------------------------------------
# Row 691:
#   Recipient Name: BhaktiE
#   UPI ID: gpay-11193
#   Note: UPI
# --------------------------------------------------
# Row 692:
#   Recipient Name: HOTELHA
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 693:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 694:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 695:
#   Recipient Name: GulabSh
#   UPI ID: gpay-11193
#   Note: UPI
# --------------------------------------------------
# Row 696:
#   Recipient Name: VINAYSA
#   UPI ID: vinayracha
#   Note: UPI
# --------------------------------------------------
# Row 697:
#   Recipient Name: NASIRMU
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 698:
#   Recipient Name: PIZZAHUT
#   UPI ID: pizzahut.2
#   Note: UPI
# --------------------------------------------------
# Row 699:
#   Recipient Name: PRATHAM
#   UPI ID: 8446278122
#   Note: nan
# --------------------------------------------------
# Row 700:
#   Recipient Name: shaikhsa
#   UPI ID: 7045314562
#   Note: yash
# --------------------------------------------------
# Row 701:
#   Recipient Name: PRATHAM
#   UPI ID: 8446278122
#   Note: nan
# --------------------------------------------------
# Row 702:
#   Recipient Name: PRATHAM
#   UPI ID: 8446278122
#   Note: nan
# --------------------------------------------------
# Row 703:
#   Recipient Name: Pradhan
#   UPI ID: paytm-4796
#   Note: Oid20
# --------------------------------------------------
# Row 704:
#   Recipient Name: Ramdular
#   UPI ID: 9022606953
#   Note: UPI
# --------------------------------------------------
# Row 705:
#   Recipient Name: Atharva
#   UPI ID: atharvapat
#   Note: UPI
# --------------------------------------------------
# Row 706:
#   Recipient Name: Storydek
#   UPI ID: storydek45
#   Note: 365Da
# --------------------------------------------------
# Row 707:
#   Recipient Name: KIRANSH
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 708:
#   Recipient Name: DINESH D
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 709:
#   Recipient Name: Storydek
#   UPI ID: storydek45
#   Note: Razor
# --------------------------------------------------
# Row 710:
#   Recipient Name: MumbaiM
#   UPI ID: q04393494@
#   Note: UPI
# --------------------------------------------------
# Row 711:
#   Recipient Name: FARUKH U
#   UPI ID: farukhpath
#   Note: UPI
# --------------------------------------------------
# Row 712:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 713:
#   Recipient Name: SUNILSH
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 714:
#   Recipient Name: BIKANER
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 715:
#   Recipient Name: RESTAURA
#   UPI ID: burgerking
#   Note: UPI
# --------------------------------------------------
# Row 716:
#   Recipient Name: ASIMHEM
#   UPI ID: asimshah21
#   Note: UPI
# --------------------------------------------------
# Row 717:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Family-
# --------------------------------------------------
# Row 718:
#   Recipient Name: Mohammad
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 719:
#   Recipient Name: TANISH NX
#   UPI ID: q127702016
#   Note: UPI
# --------------------------------------------------
# Row 720:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 721:
#   Recipient Name: TECHANA
#   UPI ID: techanalog
#   Note: TECHA
# --------------------------------------------------
# Row 722:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Som-
# --------------------------------------------------
# Row 723:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 724:
#   Recipient Name: PRACHI S
#   UPI ID: prachiswt2
#   Note: Pay t
# --------------------------------------------------
# Row 725:
#   Recipient Name: RUCHANI
#   UPI ID: ruchankada
#   Note: UPI
# --------------------------------------------------
# Row 726:
#   Recipient Name: Pradhan
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 727:
#   Recipient Name: JitenIs
#   UPI ID: 9860566455
#   Note: UPI
# --------------------------------------------------
# Row 728:
#   Recipient Name: JAYASHRE
#   UPI ID: jrao15120@
#   Note: UPI
# --------------------------------------------------
# Row 729:
#   Recipient Name: Momories
#   UPI ID: gpay-11204
#   Note: UPI
# --------------------------------------------------
# Row 730:
#   Recipient Name: SATISHPR
#   UPI ID: q506304237
#   Note: UPI
# --------------------------------------------------
# Row 731:
#   Recipient Name: PRABIR M
#   UPI ID: fcbizok69u
#   Note: UPI
# --------------------------------------------------
# Row 732:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 733:
#   Recipient Name: PULKITM
#   UPI ID: pulkit3010
#   Note: UPI
# --------------------------------------------------
# Row 734:
#   Recipient Name: ASIMHEM
#   UPI ID: asimshah21
#   Note: UPI
# --------------------------------------------------
# Row 735:
#   Recipient Name: nan
#   UPI ID: nan
#   Note: nan
# --------------------------------------------------
# Row 736:
#   Recipient Name: SHUBHAM
#   UPI ID: shubhamraj
#   Note: UPI
# --------------------------------------------------
# Row 737:
#   Recipient Name: GUPTAGE
#   UPI ID: paytmqr281
#   Note: UPI
# --------------------------------------------------
# Row 738:
#   Recipient Name: RESTAURA
#   UPI ID: burgerking
#   Note: UPI
# --------------------------------------------------
# Row 739:
#   Recipient Name: XX8237
#   UPI ID: nan
#   Note: Son-
# --------------------------------------------------
# Row 740:
#   Recipient Name: TECHANA
#   UPI ID: techanalog
#   Note: Payvi
# --------------------------------------------------

# %%
def print_transaction_details(df):
    """
    Prints every row with all the extracted details from the DataFrame.
    """
    for index, row in df.iterrows():
        print(f"Row {index}:")
        for col in df.columns:
            print(f"  {col}: {row[col]}")
        print("-" * 50)  # Separator for better readability
print_transaction_details(transaction_counts)
# print_transaction_details(df)
# Out:
# Row 0:
#   UPI ID: paytmqr281
#   Transaction Frequency: 93
# --------------------------------------------------
# Row 1:
#   UPI ID: vihaanshin
#   Transaction Frequency: 24
# --------------------------------------------------
# Row 2:
#   UPI ID: airtelprep
#   Transaction Frequency: 14
# --------------------------------------------------
# Row 3:
#   UPI ID: shubhamraj
#   Transaction Frequency: 14
# --------------------------------------------------
# Row 4:
#   UPI ID: paytmqr1jc
#   Transaction Frequency: 13
# --------------------------------------------------
# Row 5:
#   UPI ID: prachi2477
#   Transaction Frequency: 13
# --------------------------------------------------
# Row 6:
#   UPI ID: paytm-6467
#   Transaction Frequency: 13
# --------------------------------------------------
# Row 7:
#   UPI ID: aashayj27@
#   Transaction Frequency: 11
# --------------------------------------------------
# Row 8:
#   UPI ID: vinayakpbh
#   Transaction Frequency: 11
# --------------------------------------------------
# Row 9:
#   UPI ID: sawant.123
#   Transaction Frequency: 10
# --------------------------------------------------
# Row 10:
#   UPI ID: prathamshi
#   Transaction Frequency: 10
# --------------------------------------------------
# Row 11:
#   UPI ID: 8446278122
#   Transaction Frequency: 9
# --------------------------------------------------
# Row 12:
#   UPI ID: railsbiupi
#   Transaction Frequency: 8
# --------------------------------------------------
# Row 13:
#   UPI ID: shloksm28-
#   Transaction Frequency: 8
# --------------------------------------------------
# Row 14:
#   UPI ID: pranhitsla
#   Transaction Frequency: 8
# --------------------------------------------------
# Row 15:
#   UPI ID: alpharane2
#   Transaction Frequency: 8
# --------------------------------------------------
# Row 16:
#   UPI ID: prachiswt2
#   Transaction Frequency: 7
# --------------------------------------------------
# Row 17:
#   UPI ID: pulkit3010
#   Transaction Frequency: 7
# --------------------------------------------------
# Row 18:
#   UPI ID: mcdonaldsi
#   Transaction Frequency: 6
# --------------------------------------------------
# Row 19:
#   UPI ID: airtel.pay
#   Transaction Frequency: 6
# --------------------------------------------------
# Row 20:
#   UPI ID: q506304237
#   Transaction Frequency: 6
# --------------------------------------------------
# Row 21:
#   UPI ID: q06492713@
#   Transaction Frequency: 5
# --------------------------------------------------
# Row 22:
#   UPI ID: sohamgondh
#   Transaction Frequency: 4
# --------------------------------------------------
# Row 23:
#   UPI ID: burgerking
#   Transaction Frequency: 4
# --------------------------------------------------
# Row 24:
#   UPI ID: bharatpe90
#   Transaction Frequency: 4
# --------------------------------------------------
# Row 25:
#   UPI ID: q832205277
#   Transaction Frequency: 4
# --------------------------------------------------
# Row 26:
#   UPI ID: paramgogia
#   Transaction Frequency: 4
# --------------------------------------------------
# Row 27:
#   UPI ID: atharvapat
#   Transaction Frequency: 4
# --------------------------------------------------
# Row 28:
#   UPI ID: mcdonalds.
#   Transaction Frequency: 4
# --------------------------------------------------
# Row 29:
#   UPI ID: paytmqruee
#   Transaction Frequency: 4
# --------------------------------------------------
# Row 30:
#   UPI ID: q846990111
#   Transaction Frequency: 4
# --------------------------------------------------
# Row 31:
#   UPI ID: asimshah21
#   Transaction Frequency: 4
# --------------------------------------------------
# Row 32:
#   UPI ID: paytmqr56u
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 33:
#   UPI ID: gpay-11204
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 34:
#   UPI ID: paytmqrbgj
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 35:
#   UPI ID: paytmqr12u
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 36:
#   UPI ID: paytmqr3w5
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 37:
#   UPI ID: q480748453
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 38:
#   UPI ID: 9860566455
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 39:
#   UPI ID: q840397115
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 40:
#   UPI ID: paytmqr14k
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 41:
#   UPI ID: prajapatii
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 42:
#   UPI ID: paytmqrzvz
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 43:
#   UPI ID: q09778271@
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 44:
#   UPI ID: netflixupi
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 45:
#   UPI ID: anushkashe
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 46:
#   UPI ID: shinderayc
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 47:
#   UPI ID: techanalog
#   Transaction Frequency: 3
# --------------------------------------------------
# Row 48:
#   UPI ID: 8850949354
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 49:
#   UPI ID: fcbizok69u
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 50:
#   UPI ID: paytmqr15v
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 51:
#   UPI ID: sakshisawa
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 52:
#   UPI ID: gpay-11193
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 53:
#   UPI ID: paytmqr1c1
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 54:
#   UPI ID: paytmqr1xg
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 55:
#   UPI ID: paytmqr15x
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 56:
#   UPI ID: bharatpe.9
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 57:
#   UPI ID: paytmqr5cb
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 58:
#   UPI ID: viacom18on
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 59:
#   UPI ID: q669621831
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 60:
#   UPI ID: starbazaar
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 61:
#   UPI ID: goog-payme
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 62:
#   UPI ID: paytmqrrds
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 63:
#   UPI ID: paytmqr15c
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 64:
#   UPI ID: paytmqrz2t
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 65:
#   UPI ID: vinayracha
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 66:
#   UPI ID: jayashreer
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 67:
#   UPI ID: storydek45
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 68:
#   UPI ID: zomatoorde
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 69:
#   UPI ID: q271085757
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 70:
#   UPI ID: q031373311
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 71:
#   UPI ID: sangepuapa
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 72:
#   UPI ID: q060864871
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 73:
#   UPI ID: paytm-0401
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 74:
#   UPI ID: q127702016
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 75:
#   UPI ID: paytm-8727
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 76:
#   UPI ID: paytm-5645
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 77:
#   UPI ID: 9833252222
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 78:
#   UPI ID: venishakal
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 79:
#   UPI ID: rutuswt052
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 80:
#   UPI ID: jainb940-1
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 81:
#   UPI ID: chettiarpr
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 82:
#   UPI ID: mayabhanus
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 83:
#   UPI ID: paytg.fcai
#   Transaction Frequency: 2
# --------------------------------------------------
# Row 84:
#   UPI ID: paytm-6634
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 85:
#   UPI ID: paytmqrjq2
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 86:
#   UPI ID: q04393494@
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 87:
#   UPI ID: ruchankada
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 88:
#   UPI ID: gpay-11235
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 89:
#   UPI ID: q990475495
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 90:
#   UPI ID: paytmqr9zc
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 91:
#   UPI ID: 9820588550
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 92:
#   UPI ID: paytm-8736
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 93:
#   UPI ID: sondimpi@o
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 94:
#   UPI ID: q720539729
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 95:
#   UPI ID: kavankarhi
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 96:
#   UPI ID: paytmqr1p8
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 97:
#   UPI ID: farukhpath
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 98:
#   UPI ID: 9022606953
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 99:
#   UPI ID: 0791363A00
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 100:
#   UPI ID: paytm-4776
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 101:
#   UPI ID: Q054867718
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 102:
#   UPI ID: paytm-6459
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 103:
#   UPI ID: paytm-5282
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 104:
#   UPI ID: Q172613173
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 105:
#   UPI ID: gpay-11206
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 106:
#   UPI ID: paytmqr1rd
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 107:
#   UPI ID: paytm-4274
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 108:
#   UPI ID: 9326782947
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 109:
#   UPI ID: paytmqrlrf
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 110:
#   UPI ID: paytmqr1wq
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 111:
#   UPI ID: Q06492713@
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 112:
#   UPI ID: Q197901178
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 113:
#   UPI ID: q66063414@
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 114:
#   UPI ID: airtelpaym
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 115:
#   UPI ID: q278033093
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 116:
#   UPI ID: q48179062@
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 117:
#   UPI ID: q851463720
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 118:
#   UPI ID: sammulla21
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 119:
#   UPI ID: samswt.123
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 120:
#   UPI ID: ssawant.12
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 121:
#   UPI ID: mab.037322
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 122:
#   UPI ID: q25753740@
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 123:
#   UPI ID: durgaraam6
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 124:
#   UPI ID: bhartiairt
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 125:
#   UPI ID: phsfiplmah
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 126:
#   UPI ID: q611756441
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 127:
#   UPI ID: 7770074874
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 128:
#   UPI ID: 7448295363
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 129:
#   UPI ID: sonalghola
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 130:
#   UPI ID: kharote64@
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 131:
#   UPI ID: q306369335
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 132:
#   UPI ID: atharvbhag
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 133:
#   UPI ID: q465528979
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 134:
#   UPI ID: bavkarswat
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 135:
#   UPI ID: q538435092
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 136:
#   UPI ID: paytmqr1t4
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 137:
#   UPI ID: paytmqr1ow
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 138:
#   UPI ID: paytmqrqri
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 139:
#   UPI ID: paytmqr1d7
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 140:
#   UPI ID: paytmqr7yu
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 141:
#   UPI ID: paytm-4796
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 142:
#   UPI ID: 9370649978
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 143:
#   UPI ID: paytmqrwth
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 144:
#   UPI ID: amankanoji
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 145:
#   UPI ID: anandsaars
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 146:
#   UPI ID: q902324096
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 147:
#   UPI ID: q554757059
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 148:
#   UPI ID: paytmqr1hs
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 149:
#   UPI ID: rk0381207@
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 150:
#   UPI ID: 7045314562
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 151:
#   UPI ID: q193497060
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 152:
#   UPI ID: atharvahav
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 153:
#   UPI ID: 9619877179
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 154:
#   UPI ID: parnikadas
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 155:
#   UPI ID: pizzahut.2
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 156:
#   UPI ID: q196487951
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 157:
#   UPI ID: q197901178
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 158:
#   UPI ID: q207571625
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 159:
#   UPI ID: gpay-11208
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 160:
#   UPI ID: nazuu458@o
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 161:
#   UPI ID: paytmqr1jg
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 162:
#   UPI ID: ss280387-1
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 163:
#   UPI ID: q697365409
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 164:
#   UPI ID: pfintec.gr
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 165:
#   UPI ID: mswipe.140
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 166:
#   UPI ID: q389445684
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 167:
#   UPI ID: sisinty795
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 168:
#   UPI ID: q699866917
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 169:
#   UPI ID: airtel-rec
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 170:
#   UPI ID: paytmqr1d4
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 171:
#   UPI ID: spit.easeb
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 172:
#   UPI ID: airtel-pre
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 173:
#   UPI ID: csmvscurre
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 174:
#   UPI ID: paytmqr1di
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 175:
#   UPI ID: q898155370
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 176:
#   UPI ID: swayamnpte
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 177:
#   UPI ID: paytmqr5an
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 178:
#   UPI ID: bharatpe.8
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 179:
#   UPI ID: paytmqr1bi
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 180:
#   UPI ID: paytmqr14h
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 181:
#   UPI ID: vyapar.170
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 182:
#   UPI ID: mnk2017sam
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 183:
#   UPI ID: q478627637
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 184:
#   UPI ID: 7264817938
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 185:
#   UPI ID: imagicaalo
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 186:
#   UPI ID: q168215144
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 187:
#   UPI ID: paytmqryb4
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 188:
#   UPI ID: deepanshua
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 189:
#   UPI ID: write2adit
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 190:
#   UPI ID: paytg.prem
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 191:
#   UPI ID: q753314637
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 192:
#   UPI ID: paytg.snap
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 193:
#   UPI ID: q152631433
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 194:
#   UPI ID: paytg.five
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 195:
#   UPI ID: pfintec.fi
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 196:
#   UPI ID: paytmqr8hy
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 197:
#   UPI ID: pfintec.an
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 198:
#   UPI ID: q752133341
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 199:
#   UPI ID: nirajpande
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 200:
#   UPI ID: madaboutsp
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 201:
#   UPI ID: 8237599879
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 202:
#   UPI ID: flourworks
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 203:
#   UPI ID: rohitavshe
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 204:
#   UPI ID: q698438155
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 205:
#   UPI ID: q582445006
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 206:
#   UPI ID: q674889682
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 207:
#   UPI ID: paytmqr5dq
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 208:
#   UPI ID: 7eleven.42
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 209:
#   UPI ID: q812920291
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 210:
#   UPI ID: guptatufan
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 211:
#   UPI ID: q378245066
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 212:
#   UPI ID: q997530966
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 213:
#   UPI ID: q914951432
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 214:
#   UPI ID: q250642425
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 215:
#   UPI ID: q685983762
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 216:
#   UPI ID: paytm-3139
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 217:
#   UPI ID: paytmqrz32
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 218:
#   UPI ID: paytmqrqio
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 219:
#   UPI ID: paytmqrk49
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 220:
#   UPI ID: q828771384
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 221:
#   UPI ID: q509313885
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 222:
#   UPI ID: paytmqr1su
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 223:
#   UPI ID: sahebrajya
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 224:
#   UPI ID: q260799349
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 225:
#   UPI ID: paytmqr1f4
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 226:
#   UPI ID: paytm-6210
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 227:
#   UPI ID: o111221438
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 228:
#   UPI ID: bharatpe09
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 229:
#   UPI ID: paytmqr1db
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 230:
#   UPI ID: paytmqr5wr
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 231:
#   UPI ID: q591263088
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 232:
#   UPI ID: q641304611
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 233:
#   UPI ID: pantaloons
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 234:
#   UPI ID: q17788785@
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 235:
#   UPI ID: paytmqr593
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 236:
#   UPI ID: bharatpe9h
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 237:
#   UPI ID: sanjay.gup
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 238:
#   UPI ID: q122854506
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 239:
#   UPI ID: ss280387-2
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 240:
#   UPI ID: Q506304237
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 241:
#   UPI ID: nimitsheth
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 242:
#   UPI ID: paytm-6927
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 243:
#   UPI ID: ombk.lbfaa
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 244:
#   UPI ID: q230851695
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 245:
#   UPI ID: 9850344585
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 246:
#   UPI ID: q927921157
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 247:
#   UPI ID: nimishwarg
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 248:
#   UPI ID: dream11@ax
#   Transaction Frequency: 1
# --------------------------------------------------
# Row 249:
#   UPI ID: jrao15120@
#   Transaction Frequency: 1
# --------------------------------------------------

# %%
import holidays
import pandas as pd

indian_holidays = holidays.India(years=2024)

df = pd.DataFrame(indian_holidays.items(), columns=["Date", "Holiday"])
df["Date"] = pd.to_datetime(df["Date"])

# df

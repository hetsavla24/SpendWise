# %%
transaction_modes = [
    "UPI",               # Unified Payments Interface
    "INB",               # Internet Banking
    "IMP",               # Immediate Payment Service
    "NEFT",              # National Electronic Funds Transfer
    "RTGS",              # Real-Time Gross Settlement
    "Cheque",            # Paper Cheque
    "Cash Deposit",      # Cash Deposit to account
    "Cash Withdrawal",   # Withdrawal using cash
    "POS",               # Point of Sale (Card Payment)
    "DD",                # Demand Draft
    "SWIFT",             # Society for Worldwide Interbank Financial Telecommunication
    "Wire Transfer",     # Electronic bank transfer
    "ECS",               # Electronic Clearing Service
    "Bill Pay",          # Utility Bill Payments
    "M-wallet",          # Mobile Wallet Transfer
    "EMI",               # Equated Monthly Installment
    "EFT",               # Electronic Funds Transfer
    "ACH",               # Automated Clearing House
]

# %%
transaction_categories = {
    "Essentials (Daily Necessities)": [
        "Groceries", "Rent & Housing", "Utilities & Bills", "Transportation"
    ],
    "Lifestyle & Shopping": [
        "Dining & Restaurants", "Clothing & Accessories", 
        "Electronics & Gadgets", "Entertainment & Subscriptions"
    ],
    "Financial & Investments": [
        "Loan & EMI Payments", "Savings & Investments", 
        "Insurance Payments", "Credit Card Payments"
    ],
    "Health & Wellness": [
        "Medical & Pharmacy", "Fitness & Sports", "Personal Care"
    ],
    "Travel & Leisure": [
        "Hotel & Accommodation", "Flight & Train Tickets", "Tours & Experiences"
    ],
    "Education & Professional Expenses": [
        "School & College Fees", "Books & Learning Materials", 
        "Professional Subscriptions"
    ],
    "Social & Personal Payments": [
        "Gifts & Donations", "Family & Friends Transfers", "Events & Celebrations"
    ],
    "Miscellaneous (Everything Else)": [
        "Cash Withdrawals", "Penalties & Fines", "Uncategorized"
    ]
}

# Print the dictionary
print(transaction_categories)
# Out:
# {'Essentials (Daily Necessities)': ['Groceries', 'Rent & Housing', 'Utilities & Bills', 'Transportation'], 'Lifestyle & Shopping': ['Dining & Restaurants', 'Clothing & Accessories', 'Electronics & Gadgets', 'Entertainment & Subscriptions'], 'Financial & Investments': ['Loan & EMI Payments', 'Savings & Investments', 'Insurance Payments', 'Credit Card Payments'], 'Health & Wellness': ['Medical & Pharmacy', 'Fitness & Sports', 'Personal Care'], 'Travel & Leisure': ['Hotel & Accommodation', 'Flight & Train Tickets', 'Tours & Experiences'], 'Education & Professional Expenses': ['School & College Fees', 'Books & Learning Materials', 'Professional Subscriptions'], 'Social & Personal Payments': ['Gifts & Donations', 'Family & Friends Transfers', 'Events & Celebrations'], 'Miscellaneous (Everything Else)': ['Cash Withdrawals', 'Penalties & Fines', 'Uncategorized']}

# %%
category_company={
  "Essentials (Daily Necessities)": {
    "Groceries": ["BigBazaar", "Reliance Fresh", "D-Mart", "Spencer's", "More Supermarket"],
    "Rent & Housing": ["NestAway", "OYO Life", "Zolo Stays", "NoBroker", "MagicBricks"],
    "Utilities & Bills": ["Airtel", "Vodafone", "Jio", "BSNL", "Mahanagar Gas"],
    "Transportation": ["Uber", "Ola", "RedBus", "IRCTC", "MumbaiMetro"]
  },
  "Lifestyle & Shopping": {
    "Dining & Restaurants": ["McDonald's", "BurgerKing", "Dominos", "PizzaHut", "Swiggy", "Zomato"],
    "Clothing & Accessories": ["Myntra", "Jabong", "Pantaloons", "Shoppers Stop", "Westside"],
    "Electronics & Gadgets": ["Croma", "Reliance Digital", "Vijay Sales", "Amazon", "Flipkart"],
    "Entertainment & Subscriptions": ["Netflix", "Hotstar", "Amazon Prime", "Tata Sky", "BookMyShow"]
  },
  "Financial & Investments": {
    "Loan & EMI Payments": ["Bajaj Finserv", "HDFC Bank", "ICICI Bank", "SBI", "Axis Bank"],
    "Savings & Investments": ["Zerodha", "Upstox", "Groww", "Paytm Money", "ETMoney"],
    "Insurance Payments": ["LIC", "ICICI Lombard", "HDFC Life", "SBI Life", "Max Bupa"],
    "Credit Card Payments": ["HDFC Bank", "ICICI Bank", "SBI", "Axis Bank", "Citibank"]
  },
  "Health & Wellness": {
    "Medical & Pharmacy": ["Apollo Pharmacy", "1mg", "NetMeds", "MedPlus", "PharmEasy"],
    "Fitness & Sports": ["Cult.fit", "Decathlon", "Nike", "Adidas", "Reebok"],
    "Personal Care": ["Nykaa", "Purplle", "Himalaya", "Dabur", "Patanjali"]
  },
  "Travel & Leisure": {
    "Hotel & Accommodation": ["OYO Rooms", "MakeMyTrip", "Yatra", "Airbnb", "Trivago"],
    "Flight & Train Tickets": ["IRCTC", "MakeMyTrip", "Yatra", "Goibibo", "Cleartrip"],
    "Tours & Experiences": ["Thrillophilia", "Klook", "Viator", "Musement", "Headout"]
  },
  "Education & Professional Expenses": {
    "School & College Fees": ["Paytm Education", "Instamojo", "Razorpay", "CollegeDekho", "Shiksha"],
    "Books & Learning Materials": ["Amazon", "Flipkart", "Book Depository", "Kindle", "Coursera"],
    "Professional Subscriptions": ["LinkedIn Premium", "Udemy", "Skillshare", "Adobe Creative Cloud", "Microsoft Office 365"]
  },
  "Social & Personal Payments": {
    "Gifts & Donations": ["Amazon Gift Cards", "Flipkart Gift Cards", "GiveIndia", "Ketto", "Milaap"],
    "Family & Friends Transfers": ["Google Pay", "PhonePe", "Paytm", "BHIM", "Mobikwik"],
    "Events & Celebrations": ["BookMyShow", "Insider.in", "EventsHigh", "MeraEvents", "Explara"]
  },
  "Miscellaneous (Everything Else)": {
    "Cash Withdrawals": ["HDFC Bank", "ICICI Bank", "SBI", "Axis Bank", "Kotak Mahindra Bank"],
    "Penalties & Fines": ["Traffic Police", "Municipal Corporation", "Court Fees", "Late Payment Charges", "GST Penalty"],
    "Uncategorized": ["Miscellaneous", "Others", "General", "Various", "Sundry"]
  }
}
# print(Category_Company)

# %%
Company_keywords={
  "McDonald's": ["mcdonald", "mcd", "mc donalds"],
  "BurgerKing": ["burgerking", "burger king", "burgerkingindia"],
  "Dominos": ["dominos", "domino's"],
  "PizzaHut": ["pizzahut", "pizza hut"],
  "KFC": ["kfc", "kentucky fried chicken"],
  "Subway": ["subway sandwiches", "subway"],
  "Starbucks": ["starbucks", "starbucks coffee"],
  "JumboKing": [ "jumboki"],
  "Cafe Coffee Day": ["ccd", "cafe coffee day"],
  "Haldiram's": ["haldiram", "haldirams"],
  "Baskin Robbins": ["baskin robbins", "baskinrobbins"],
  
  "Swiggy": ["swiggy"],
  "Zomato": ["zomato"],
  "Dunzo": ["dunzo"],
  "Zepto": ["zepto"],
  "BigBasket": ["bigbasket", "big basket"],
  "Blinkit": ["blinkit", "grofers"],

  "Amazon": ["amazon", "amazon pay"],
  "Flipkart": ["flipkart"],
  "Myntra": ["myntra"],
  "Nykaa": ["nykaa"],
  "Ajio": ["ajio"],
  "Tata Cliq": ["tata cliq", "tatacliq"],
  "Reliance Digital": ["reliance digital"],
  "Croma": ["croma"],
  "Vijay Sales": ["vijay sales"],
  "Snapdeal": ["snapdeal"],
  "FirstCry": ["firstcry"],
  "Pepperfry": ["pepperfry"],

  "Netflix": ["netflix"],
  "Hotstar": ["hotstar", "disney hotstar"],
  "Amazon Prime": ["amazon prime", "prime video"],
  "Tata Sky": ["tatasky"],
  "Airtel DTH": ["airtel dth"],
  "Jio Cinema": ["jio cinema", "jio tv"],
  "BookMyShow": ["bookmyshow", "bms"],
  "SonyLIV": ["sonyliv"],
  "Zee5": ["zee5"],
  "Spotify": ["spotify"],
  "Apple Music": ["apple music"],
  "Gaana": ["gaana"],
  "Wynk Music": ["wynk music"],

  "Airtel": ["airtel", "airtelpay", "bharti a", "bhartia"],
  "Vodafone": ["vodafone", "vodapay", "vi india"],
  "Jio": ["jio", "reliance jio"],
  "BSNL": ["bsnl", "bharat sanchar nigam"],
  "ACT Fibernet": ["act fibernet", "act internet"],
  "Hathway": ["hathway", "hathway broadband"],
  "Spectra": ["spectra", "spectra internet"],

  "Uber": ["uber"],
  "Rapido": ["rapido"],
  "RedBus": ["redbus"],
  "MumbaiMetro": ["mumbaim","mumbai metro"],
  "IRCTC": ["irctc", "railway"],
  "Goibibo": ["goibibo"],
  "MakeMyTrip": ["makemytrip", "mmt"],
  "Cleartrip": ["cleartrip"],
  "Yatra": ["yatra"],
  "Air India": ["airindia"],
  "IndiGo": ["indigo"],
  "SpiceJet": ["spicejet"],
  "Vistara": ["vistara"],
  "Go First": ["go first", "goair"],

  "Bajaj Finserv": ["bajaj finserv", "bajaj finance"],
  "HDFC Bank": ["hdfc", "hdfc bank"],
  "ICICI Bank": ["icici", "icici bank"],
  "SBI": ["sbi", "state bank"],
  "Axis Bank": ["axis", "axis bank"],
  "Kotak Bank": ["kotak", "kotak mahindra"],
  "IDFC First Bank": ["idfc", "idfc first"],
  "IndusInd Bank": ["indusind", "indusind bank"],
  "Razorpay": ["razorpay"],
  
  "Zerodha": ["zerodha"],
  "Upstox": ["upstox"],
  "Groww": ["groww"],
  "Paytm Money": ["paytm money"],
  "ETMoney": ["etmoney"],
  "LIC": ["lic", "life insurance corporation"],
  "ICICI Lombard": ["icici lombard"],
  "HDFC Life": ["hdfc life"],
  "SBI Life": ["sbi life"],
  "Max Bupa": ["max bupa"],

  "Apollo Pharmacy": ["apollo pharmacy"],
  "1mg": ["1mg", "tata 1mg"],
  "NetMeds": ["netmeds"],
  "MedPlus": ["medplus"],
  "PharmEasy": ["pharmeasy"],

  "Cult.fit": ["cultfit", "cult fit"],
  "Decathlon": ["decathlon"],
  "Nike": ["nike"],
  "Adidas": ["adidas"],
  "Reebok": ["reebok"],

  "OYO Rooms": ["oyo", "oyo rooms"],
  "Airbnb": ["airbnb"],
  "Trivago": ["trivago"],
  "Thrillophilia": ["thrillophilia"],
  "Klook": ["klook"],

  "LinkedIn Premium": ["linkedin premium"],
  "Udemy": ["udemy"],
  "Coursera": ["coursera"],
  "Skillshare": ["skillshare"],
  "Adobe Creative Cloud": ["adobe cc"],
  "Microsoft Office 365": ["office365", "microsoft 365"],

  "GiveIndia": ["giveindia"],
  "Ketto": ["ketto"],
  "Milaap": ["milaap"],

  "BookMyShow": ["bookmyshow", "bms"],
  "Insider.in": ["insider", "insider in"],
  "EventsHigh": ["eventshigh"],
  "MeraEvents": ["meraevents"],
  "Explara": ["explara"]
}

# %%
# print(Company_keywords)

# %%
import pandas as pd
from tqdm import tqdm

# Load the dataset
df = pd.read_csv("Merge_Proccessed.csv")

# Merge text from Recipient_Name and UPI_ID to create a searchable field
df['merged_text'] = (
    df['Recipient_Name'].fillna('').str.strip().str.lower() + " " +
    df['UPI_ID'].fillna('').str.strip().str.lower()
).str.strip()

# Function to extract company name from text
def extract_company(text):
    for company, keywords in Company_keywords.items():
        for keyword in keywords:
            if keyword in text:
                return company
    return None

# Function to categorize the company
def categorize_company(company):
    for category, subcategories in category_company.items():
        for subcategory, companies in subcategories.items():
            if company in companies:
                return category, subcategory
    return None, None

# Apply extraction and categorization
tqdm.pandas(desc="Processing Transactions")
df['Company'] = df['merged_text'].progress_apply(extract_company)
df[['Transaction_Category', 'Sub_Category']] = df['Company'].apply(lambda x: pd.Series(categorize_company(x)))

# Filter only categorized transactions
df_categorized = df[df['Company'].notnull()].copy()

# Save the categorized data
df_categorized.to_csv("Categorized_Transactions.csv", index=False)

print("✅ Processing complete! Categorized transactions saved.")
# Out:
# Processing Transactions: 100%|█████████████| 741/741 [00:00<00:00, 32335.71it/s]
# ✅ Processing complete! Categorized transactions saved.

# %%
df_categorized['Transaction_Category'].unique()
# Out:
# array(['Essentials (Daily Necessities)', 'Lifestyle & Shopping',
#        'Financial & Investments', None], dtype=object)

# %%
df_categorized.columns
# Out:
# Index(['Transaction_Date', 'Description', 'Reference No./Cheque No.', 'Debit',
#        'Credit', 'Balance', 'Transaction_Type', 'Transaction_Mode',
#        'DR/CR_Indicator', 'Transaction_ID', 'Recipient_Name', 'Bank', 'UPI_ID',
#        'Note', 'merged_text', 'Company', 'Transaction_Category',
#        'Sub_Category'],
#       dtype='object')

# %%
df_categorized['Sub_Category'].unique()
# Out:
# array(['Utilities & Bills', 'Entertainment & Subscriptions',
#        'Loan & EMI Payments', 'Transportation', 'Dining & Restaurants',
#        None], dtype=object)

# %%
import dash
from dash import dcc, html, Input, Output
import plotly.express as px
import pandas as pd

# Load your categorized transactions dataset
df = pd.read_csv("CSVS/Categorized_Transactions.csv")

df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'], errors='coerce')  # Ensure proper datetime format
df['Month'] = df['Transaction_Date'].dt.strftime('%B')  # Extract Month as string

# Ensure Amount Spent is calculated
df['Amount_Spent'] = df['Debit'].fillna(0)  # Using Debit column to represent spending

# Group data for visualization
category_summary = df.groupby("Transaction_Category")["Amount_Spent"].sum().reset_index()
subcategory_summary = df.groupby(["Transaction_Category", "Sub_Category"])["Amount_Spent"].sum().reset_index()
monthly_summary = df.groupby("Month")["Amount_Spent"].sum().reset_index()

# Initialize Dash app
app = dash.Dash(__name__)
app.title = "Expense Dashboard"

# Layout
app.layout = html.Div([
    html.H1("💰 Expense Dashboard", style={'textAlign': 'center', 'color': '#4A90E2'}),
    html.P("Track where your money is going!", style={'textAlign': 'center'}),
    
    dcc.Graph(id='category-pie-chart'),
    dcc.Graph(id='subcategory-bar-chart'),
    dcc.Graph(id='monthly-trend-chart')
])

# Callbacks for interactivity
@app.callback(
    Output('category-pie-chart', 'figure'),
    Output('subcategory-bar-chart', 'figure'),
    Output('monthly-trend-chart', 'figure'),
    Input('category-pie-chart', 'clickData')
)
def update_charts(clickData):
    # Pie Chart (Category-wise Spending)
    fig1 = px.pie(category_summary, values='Amount_Spent', names='Transaction_Category', 
                  title="Category-wise Spending Breakdown",
                  color_discrete_sequence=px.colors.qualitative.Pastel)
    
    # Bar Chart (Subcategory-wise Spending)
    fig2 = px.bar(subcategory_summary, x='Sub_Category', y='Amount_Spent', 
                  title="Subcategory-wise Breakdown", color='Transaction_Category',
                  color_discrete_sequence=px.colors.qualitative.Safe)
    
    # Line Chart (Monthly Trend)
    fig3 = px.line(monthly_summary, x='Month', y='Amount_Spent', markers=True, 
                   title="Monthly Spending Trend", line_shape='spline',
                   color_discrete_sequence=['#2E91E5'])
    
    return fig1, fig2, fig3

# Run app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# import dash
# from dash import dcc, html, Input, Output
# import plotly.express as px
# import pandas as pd

# # Load your categorized transactions dataset
# df = pd.read_csv("Categorized_Transactions.csv")

# # Convert Transaction_Date to datetime
# df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'], errors='coerce')
# df['Month'] = df['Transaction_Date'].dt.strftime('%B')

# # Calculate Amount_Spent (using Debit column for spending)
# df['Amount_Spent'] = df['Debit'].fillna(0)

# # Group data for visualization
# category_summary = df.groupby("Transaction_Category")["Amount_Spent"].sum().reset_index()
# subcategory_summary = df.groupby(["Transaction_Category", "Sub_Category"])["Amount_Spent"].sum().reset_index()
# monthly_summary = df.groupby("Month")["Amount_Spent"].sum().reset_index()

# # Initialize Dash app
# app = dash.Dash(__name__)
# app.title = "Expense Dashboard"

# # Layout: Category Pie chart on top (big) and two charts side by side below
# app.layout = html.Div([
#     html.H1("💰 Expense Dashboard", style={'textAlign': 'center', 'color': '#4A90E2'}),
#     html.P("Track where your money is going!", style={'textAlign': 'center'}),
    
#     # Row 1: Big Category Pie Chart
#     html.Div(
#         dcc.Graph(
#             id='category-pie-chart', 
#             config={'displayModeBar': False}, 
#             style={'height': '400px'}
#         ),
#         style={'width': '90%', 'margin': 'auto', 'padding': '10px'}
#     ),
    
#     # Row 2: Two charts side by side (Subcategory Bar and Monthly Trend)
#     html.Div([
#         html.Div(
#             dcc.Graph(
#                 id='subcategory-bar-chart', 
#                 config={'displayModeBar': False}, 
#                 style={'height': '300px'}
#             ),
#             style={'width': '48%', 'display': 'inline-block', 'padding': '10px', 'verticalAlign': 'top'}
#         ),
#         html.Div(
#             dcc.Graph(
#                 id='monthly-trend-chart', 
#                 config={'displayModeBar': False}, 
#                 style={'height': '300px'}
#             ),
#             style={'width': '48%', 'display': 'inline-block', 'padding': '10px', 'verticalAlign': 'top'}
#         )
#     ], style={'width': '100%', 'display': 'flex', 'justifyContent': 'center'})
# ])

# # Callback for updating the charts; clickData from pie chart is still used if needed
# @app.callback(
#     Output('category-pie-chart', 'figure'),
#     Output('subcategory-bar-chart', 'figure'),
#     Output('monthly-trend-chart', 'figure'),
#     Input('category-pie-chart', 'clickData')
# )
# def update_charts(clickData):
#     # Create the Category Pie Chart with short text and larger font
#     fig1 = px.pie(
#         category_summary, 
#         values='Amount_Spent', 
#         names='Transaction_Category', 
#         title="Category Spending",
#         color_discrete_sequence=px.colors.qualitative.Pastel
#     )
#     fig1.update_traces(textinfo='label+percent', textfont_size=14)
#     fig1.update_layout(title_font_size=18, font=dict(size=12))
    
#     # Create the Subcategory Bar Chart with concise labels
#     fig2 = px.bar(
#         subcategory_summary, 
#         x='Sub_Category', 
#         y='Amount_Spent', 
#         title="Subcategory Breakdown", 
#         color='Transaction_Category',
#         color_discrete_sequence=px.colors.qualitative.Safe
#     )
#     fig2.update_layout(title_font_size=16, font=dict(size=10))
    
#     # Create the Monthly Trend Line Chart with markers and concise title
#     fig3 = px.line(
#         monthly_summary, 
#         x='Month', 
#         y='Amount_Spent', 
#         markers=True, 
#         title="Monthly Trend",
#         line_shape='spline',
#         color_discrete_sequence=['#2E91E5']
#     )
#     fig3.update_layout(title_font_size=16, font=dict(size=10))
    
#     return fig1, fig2, fig3

# # Run app
# if __name__ == '__main__':
#     app.run_server(debug=True)

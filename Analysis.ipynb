# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from prophet import Prophet

from sklearn.metrics import mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
pd.set_option('display.max_colwidth', None)  # Display full content of each column
pd.set_option('display.max_columns', None)   # Display all columns
pd.set_option('display.width', 5000)         # Set display width

plt.style.use('ggplot')
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv("Features.csv")  # Update with your file path
df.columns
# Out:
# Index(['Transaction Date', 'Description', 'Reference No./Cheque No.', 'Debit', 'Credit', 'Balance', 'Transaction Type', 'Transaction Mode', 'DR/CR Indicator', 'Transaction ID', 'Recipient Name', 'Bank', 'UPI ID', 'Note', 'dayofweek', 'quarter', 'month', 'year', 'dayofyear', 'dayofmonth', 'weekofyear', 'weekday', 'is_weekend', 'transaction_amount', 'is_large_transaction', 'Balance.1'], dtype='object')

# %%
import dtale

dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://YASH:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 2025-02-23 08:52:18,958 - INFO     - Executing shutdown due to inactivity...
# 2025-02-23 08:52:27,250 - INFO     - Executing shutdown...
# 2025-02-23 08:52:27,253 - INFO     - Not running with the Werkzeug Server, exiting by searching gc for BaseWSGIServer

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("Features.csv")  # Replace with actual filename

# Convert Transaction Date to datetime
df["Transaction Date"] = pd.to_datetime(df["Transaction Date"], errors="coerce")

# Define Start and End Dates (Modify as needed)
start_date = "2024-01-01"
end_date = "2024-12-31"

selected_columns = ['Transaction Date', 'Debit', 'Credit', 'Balance','Transaction Mode', 'Recipient Name','Transaction ID' ,'Bank', 
    'UPI ID', 'Note', 'transaction_amount']

df = df[selected_columns]
df = df[(df["Transaction Date"] >= start_date) & (df["Transaction Date"] <= end_date)].copy()

# %%
df
# Out:
#     Transaction Date   Debit  Credit  Balance Transaction Mode Recipient Name Transaction ID  Bank      UPI ID   Note  transaction_amount
# 0         2024-04-02   30.00     0.0   954.40              UPI       JULFIKAR   409378221768  YESB  paytmqr1jc  baker               30.00
# 1         2024-04-04    0.00   500.0  1454.40              INB         XX8237     9890160567   NaN         NaN   Son-                0.00
# 2         2024-04-05   64.00     0.0  1390.40              UPI       VINAYAK    409652615602  HDFC  vinayakpbh    UPI               64.00
# 3         2024-04-06    0.00  1500.0  2890.40              INB         XX8237     9890160567   NaN         NaN   Son-                0.00
# 4         2024-04-09  719.00     0.0  2171.40              UPI       BHARTI A   410014886005  AIRP  airtelprep  Payme              719.00
# ..               ...     ...     ...      ...              ...            ...            ...   ...         ...    ...                 ...
# 294       2024-11-04    0.00   300.0  1244.81              UPI       SAMEER B   430929085524  ICIC  sawant.123    UPI                0.00
# 295       2024-11-04  295.78     0.0   949.03              UPI       ZOMATO L   430902812486  UTIB  zomatoorde    UPI              295.78
# 296       2024-11-05   79.00     0.0   870.03              UPI        DILIPKU   467686807162  YESB  paytmqr5wr    UPI               79.00
# 297       2024-11-05   15.00     0.0   855.03              UPI       SHINDE R   431057312820  COSB  shinderayc    UPI               15.00
# 298       2024-11-06   70.00     0.0   785.03              UPI       Bombay B   431165845160  UTIB  8850949354    UPI               70.00
#
# [299 rows x 11 columns]

# %%
import pandas as pd
import panel as pn
import plotly.express as px

# Enable Panel extension
pn.extension('plotly')

df['Month'] = df['Transaction Date'].dt.strftime('%B')  # Full month name

monthly_summary = df.groupby('Month')[['Debit', 'Credit']].sum().reset_index()

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 
               'August', 'September', 'October', 'November', 'December']
monthly_summary['Month'] = pd.Categorical(monthly_summary['Month'], categories=month_order, ordered=True)
monthly_summary = monthly_summary.sort_values('Month')

fig = px.pie(
    monthly_summary.melt(id_vars=['Month'], var_name='Type', value_name='Amount'),  
    names='Type',
    values='Amount',
    title="Monthly Credit (Income) vs. Debit (Expenses)",
    color='Type',
    color_discrete_map={'Credit': 'green', 'Debit': 'red'}
)

dashboard = pn.Column(
    "# Monthly Financial Overview",
    pn.pane.Plotly(fig),
)

dashboard.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='bed44743-4c5e-4712-bb07-33ff597b78b0'>
#   <div id="cec0a1d2-18a3-4744-8e62-8fd0dca858ed" data-root-id="bed44743-4c5e-4712-bb07-33ff597b78b0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"00695c72-8491-4689-90b1-233c0ebfe8d9":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"bed44743-4c5e-4712-bb07-33ff597b78b0"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"5f98c31a-8b50-4bc3-9bc4-9478641d3565","attributes":{"plot_id":"bed44743-4c5e-4712-bb07-33ff597b78b0","comm_id":"7c2e837e6fb0421aa6508eb61fa8fefe","client_comm_id":"42b205f73ab24d01a2fbf5bf03d6ffd3"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"00695c72-8491-4689-90b1-233c0ebfe8d9","roots":{"bed44743-4c5e-4712-bb07-33ff597b78b0":"cec0a1d2-18a3-4744-8e62-8fd0dca858ed"},"root_ids":["bed44743-4c5e-4712-bb07-33ff597b78b0"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Column
#     [0] Markdown(str)
#     [1] Plotly(Figure)

# %%
# Use UPI ID if available; otherwise, use Recipient Name


# Extract Date Components
df_filtered["year"] = df_filtered["Transaction Date"].dt.year
df_filtered["month"] = df_filtered["Transaction Date"].dt.month
df_filtered["weekofyear"] = df_filtered["Transaction Date"].dt.isocalendar().week
df_filtered["Transaction Date"] = df_filtered["Transaction Date"].dt.date

# Aggregate Unique UPI IDs (or Recipient Name)
agg_data = df_filtered.groupby(["Unique ID"]).agg(
    First_Transaction=("Transaction Date", "min"),  # First transaction date
    Last_Transaction=("Transaction Date", "max"),  # Last transaction date
    Total_Transactions=("Transaction Date", "count"),  # Total transactions
    Total_Debit=("Debit", "sum"),  # Sum of all debits
    Total_Credit=("Credit", "sum"),  # Sum of all credits
    Max_Balance=("Balance", "max"),  # Maximum balance recorded
    Min_Balance=("Balance", "min"),  # Minimum balance recorded
    Avg_Balance=("Balance", "mean"),  # Average balance over transactions
).reset_index()

# Count Transactions at Different Intervals
daily_counts = df_filtered.groupby(["Transaction Date", "Unique ID"]).size().reset_index(name="Daily Count")
weekly_counts = df_filtered.groupby(["year", "weekofyear", "Unique ID"]).size().reset_index(name="Weekly Count")
monthly_counts = df_filtered.groupby(["year", "month", "Unique ID"]).size().reset_index(name="Monthly Count")
yearly_counts = df_filtered.groupby(["year", "Unique ID"]).size().reset_index(name="Yearly Count")

# Merge counts into the main dataset
agg_data = agg_data.merge(daily_counts.groupby("Unique ID")["Daily Count"].sum().reset_index(), on="Unique ID", how="left")
agg_data = agg_data.merge(weekly_counts.groupby("Unique ID")["Weekly Count"].sum().reset_index(), on="Unique ID", how="left")
agg_data = agg_data.merge(monthly_counts.groupby("Unique ID")["Monthly Count"].sum().reset_index(), on="Unique ID", how="left")
agg_data = agg_data.merge(yearly_counts.groupby("Unique ID")["Yearly Count"].sum().reset_index(), on="Unique ID", how="left")

# Fill NaN values with 0 (for cases where counts might be missing)
agg_data.fillna(0, inplace=True)

# Save the final unique UPI-based transaction summary to CSV
agg_data.to_csv("unique_upi_transaction_summary.csv", index=False)

print("✅ Processed unique UPI transaction summary saved successfully!")
# Out:
# ✅ Processed unique UPI transaction summary saved successfully!

# %%
agg_data
# Out:
#       Unique ID First_Transaction Last_Transaction  Total_Transactions  Total_Debit  Total_Credit  Max_Balance  Min_Balance  Avg_Balance  Daily Count  Weekly Count  Monthly Count  Yearly Count
# 0    0791363A00        2023-08-30       2023-08-30                   1        30.00          0.00       806.92       806.92   806.920000            1             1              1             1
# 1    7045314562        2023-02-24       2023-02-24                   1         0.00        157.00      1398.88      1398.88  1398.880000            1             1              1             1
# 2    7264817938        2024-06-05       2024-06-05                   1         0.00        200.00      1042.31      1042.31  1042.310000            1             1              1             1
# 3    7eleven.42        2023-05-10       2023-05-10                   1        70.00          0.00      1210.82      1210.82  1210.820000            1             1              1             1
# 4    8237599879        2024-06-04       2024-06-04                   1       125.00          0.00      1008.31      1008.31  1008.310000            1             1              1             1
# ..          ...               ...              ...                 ...          ...           ...          ...          ...          ...          ...           ...            ...           ...
# 239  vinayakpbh        2023-05-10       2024-04-23                  11       300.00       2276.06      5415.46       696.92  2148.612727           11            11             11            11
# 240  vinayracha        2023-02-22       2023-09-24                   2       116.00         15.00      1752.88       403.92  1078.400000            2             2              2             2
# 241  vyapar.170        2024-06-15       2024-06-15                   1       210.00          0.00      1493.31      1493.31  1493.310000            1             1              1             1
# 242  write2adit        2024-04-23       2024-04-23                   1        71.00          0.00       695.02       695.02   695.020000            1             1              1             1
# 243  zomatoorde        2024-10-30       2024-11-04                   2       871.78          0.00      1064.81       949.03  1006.920000            2             2              2             2
#
# [244 rows x 13 columns]

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("Features.csv")  # Replace with actual filename

# Convert Transaction Date to datetime
df["Transaction Date"] = pd.to_datetime(df["Transaction Date"], errors="coerce")

# Define Start and End Dates (Modify as needed)
start_date = "2022-01-01"
end_date = "2025-12-31"

# Filter transactions within the date range
df_filtered = df[(df["Transaction Date"] >= start_date) & (df["Transaction Date"] <= end_date)].copy()

# Use UPI ID if available; otherwise, use Recipient Name
df_filtered["Unique ID"] = df_filtered["UPI ID"].fillna(df_filtered["Recipient Name"])

# Extract Date Components
df_filtered["year"] = df_filtered["Transaction Date"].dt.year
df_filtered["month"] = df_filtered["Transaction Date"].dt.month
df_filtered["weekofyear"] = df_filtered["Transaction Date"].dt.isocalendar().week
df_filtered["Transaction Date"] = df_filtered["Transaction Date"].dt.date

# Function to calculate daily transaction count
def calculate_daily_transactions(df):
    """Calculate the number of transactions for each unique ID per day."""
    daily_counts = df.groupby(["Transaction Date", "Unique ID"]).size().reset_index(name="Daily Count")
    return daily_counts

# Function to calculate weekly transaction count
def calculate_weekly_transactions(df):
    """Calculate the number of transactions for each unique ID per week (resetting weekly)."""
    df = df.sort_values(["Unique ID", "year", "weekofyear", "Transaction Date"])
    df["Weekly Count"] = df.groupby(["Unique ID", "year", "weekofyear"]).cumcount() + 1
    return df[["Transaction Date", "Unique ID", "Weekly Count"]]

# Function to calculate monthly transaction count
def calculate_monthly_transactions(df):
    """Calculate the number of transactions for each unique ID per month (resetting monthly)."""
    df = df.sort_values(["Unique ID", "year", "month", "Transaction Date"])
    df["Monthly Count"] = df.groupby(["Unique ID", "year", "month"]).cumcount() + 1
    return df[["Transaction Date", "Unique ID", "Monthly Count"]]

# Function to calculate total transactions till date for each unique ID
def calculate_total_transactions(df):
    """Calculate the cumulative total transactions for each unique ID."""
    df = df.sort_values(["Unique ID", "Transaction Date"])
    df["Total Transactions"] = df.groupby("Unique ID").cumcount() + 1
    return df[["Transaction Date", "Unique ID", "Total Transactions"]]

# Calculate all metrics
daily_counts = calculate_daily_transactions(df_filtered)
weekly_counts = calculate_weekly_transactions(df_filtered)
monthly_counts = calculate_monthly_transactions(df_filtered)
total_transactions = calculate_total_transactions(df_filtered)

# # Merge all calculated counts into one dataset
# df_final = df_filtered.merge(daily_counts, on=["Transaction Date", "Unique ID"], how="left")
# df_final = df_final.merge(weekly_counts, on=["Transaction Date", "Unique ID"], how="left")
# df_final = df_final.merge(monthly_counts, on=["Transaction Date", "Unique ID"], how="left")
# df_final = df_final.merge(total_transactions, on=["Transaction Date", "Unique ID"], how="left")

# # Fill NaN values with 0 (for cases where counts might be missing)
# df_final.fillna(0, inplace=True)

# Save the final transaction summary to CSV

print("✅ Processed unique UPI transaction summary saved successfully!")
# Out:
# ✅ Processed unique UPI transaction summary saved successfully!

# %%
# df["UPI ID"] = df["UPI ID"].fillna(df["Recipient Name"])
# nan_rows = df[df['UPI ID'].isna() | (df['UPI ID'] == "nan")]
# nan_rows

# %%
print(daily_counts.shape)

print(monthly_counts.shape)
print(total_transactions.shape)
print(weekly_counts.shape)
daily_counts.isna().sum()
# df.shape
# Out:
# (650, 3)
# (741, 3)
# (741, 3)
# (741, 3)
# Transaction Date    0
# Unique ID           0
# Daily Count         0
# dtype: int64

# %%
def print_transaction_details(df):
    """
    Prints every row with all the extracted details from the DataFrame.
    """
    for index, row in df.iterrows():
        print(f"Row {index}:")
        for col in df.columns:
            print(f"  {col}: {row[col]}")
        print("-" * 50)  # Separator for better readability
print_transaction_details(daily_counts)
# print_transaction_details(df)
# Out:
# Row 0:
#   Transaction Date: 2022-05-31
#   Unique ID: XX4470
#   Daily Count: 1
# --------------------------------------------------
# Row 1:
#   Transaction Date: 2022-06-18
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 2:
#   Transaction Date: 2022-06-24
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 3:
#   Transaction Date: 2022-08-27
#   Unique ID: prachiswt2
#   Daily Count: 2
# --------------------------------------------------
# Row 4:
#   Transaction Date: 2022-09-10
#   Unique ID: prachiswt2
#   Daily Count: 1
# --------------------------------------------------
# Row 5:
#   Transaction Date: 2022-09-10
#   Unique ID: rutuswt052
#   Daily Count: 1
# --------------------------------------------------
# Row 6:
#   Transaction Date: 2022-09-19
#   Unique ID: rutuswt052
#   Daily Count: 1
# --------------------------------------------------
# Row 7:
#   Transaction Date: 2022-09-20
#   Unique ID: paytm-6467
#   Daily Count: 1
# --------------------------------------------------
# Row 8:
#   Transaction Date: 2022-09-28
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 9:
#   Transaction Date: 2022-09-30
#   Unique ID: 227364410404
#   Daily Count: 1
# --------------------------------------------------
# Row 10:
#   Transaction Date: 2022-10-16
#   Unique ID: bharatpe90
#   Daily Count: 1
# --------------------------------------------------
# Row 11:
#   Transaction Date: 2022-10-16
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 12:
#   Transaction Date: 2022-10-17
#   Unique ID: airtel.pay
#   Daily Count: 1
# --------------------------------------------------
# Row 13:
#   Transaction Date: 2022-10-17
#   Unique ID: sammulla21
#   Daily Count: 1
# --------------------------------------------------
# Row 14:
#   Transaction Date: 2022-10-23
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 15:
#   Transaction Date: 2022-10-25
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 16:
#   Transaction Date: 2022-10-26
#   Unique ID: q127702016
#   Daily Count: 1
# --------------------------------------------------
# Row 17:
#   Transaction Date: 2022-10-26
#   Unique ID: sawant.123
#   Daily Count: 1
# --------------------------------------------------
# Row 18:
#   Transaction Date: 2022-11-05
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 19:
#   Transaction Date: 2022-11-05
#   Unique ID: q25753740@
#   Daily Count: 1
# --------------------------------------------------
# Row 20:
#   Transaction Date: 2022-11-05
#   Unique ID: samswt.123
#   Daily Count: 1
# --------------------------------------------------
# Row 21:
#   Transaction Date: 2022-11-05
#   Unique ID: ssawant.12
#   Daily Count: 1
# --------------------------------------------------
# Row 22:
#   Transaction Date: 2022-11-07
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 23:
#   Transaction Date: 2022-11-09
#   Unique ID: paytmqr281
#   Daily Count: 5
# --------------------------------------------------
# Row 24:
#   Transaction Date: 2022-11-17
#   Unique ID: bhartiairt
#   Daily Count: 1
# --------------------------------------------------
# Row 25:
#   Transaction Date: 2022-11-17
#   Unique ID: goog-payme
#   Daily Count: 1
# --------------------------------------------------
# Row 26:
#   Transaction Date: 2022-11-18
#   Unique ID: 7770074874
#   Daily Count: 1
# --------------------------------------------------
# Row 27:
#   Transaction Date: 2022-11-18
#   Unique ID: phsfiplmah
#   Daily Count: 1
# --------------------------------------------------
# Row 28:
#   Transaction Date: 2022-11-18
#   Unique ID: venishakal
#   Daily Count: 1
# --------------------------------------------------
# Row 29:
#   Transaction Date: 2022-11-22
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 30:
#   Transaction Date: 2022-11-25
#   Unique ID: bharatpe.9
#   Daily Count: 1
# --------------------------------------------------
# Row 31:
#   Transaction Date: 2022-11-25
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 32:
#   Transaction Date: 2022-12-08
#   Unique ID: 7448295363
#   Daily Count: 1
# --------------------------------------------------
# Row 33:
#   Transaction Date: 2022-12-09
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 34:
#   Transaction Date: 2022-12-09
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 35:
#   Transaction Date: 2022-12-10
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 36:
#   Transaction Date: 2022-12-13
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 37:
#   Transaction Date: 2022-12-14
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 38:
#   Transaction Date: 2022-12-14
#   Unique ID: kharote64@
#   Daily Count: 1
# --------------------------------------------------
# Row 39:
#   Transaction Date: 2022-12-14
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 40:
#   Transaction Date: 2022-12-17
#   Unique ID: q306369335
#   Daily Count: 1
# --------------------------------------------------
# Row 41:
#   Transaction Date: 2022-12-18
#   Unique ID: q465528979
#   Daily Count: 1
# --------------------------------------------------
# Row 42:
#   Transaction Date: 2022-12-19
#   Unique ID: airtel.pay
#   Daily Count: 2
# --------------------------------------------------
# Row 43:
#   Transaction Date: 2022-12-19
#   Unique ID: q09778271@
#   Daily Count: 2
# --------------------------------------------------
# Row 44:
#   Transaction Date: 2022-12-22
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 45:
#   Transaction Date: 2022-12-23
#   Unique ID: jainb940-1
#   Daily Count: 2
# --------------------------------------------------
# Row 46:
#   Transaction Date: 2022-12-23
#   Unique ID: paytm-6467
#   Daily Count: 4
# --------------------------------------------------
# Row 47:
#   Transaction Date: 2022-12-27
#   Unique ID: bavkarswat
#   Daily Count: 1
# --------------------------------------------------
# Row 48:
#   Transaction Date: 2022-12-30
#   Unique ID: paytm-6467
#   Daily Count: 1
# --------------------------------------------------
# Row 49:
#   Transaction Date: 2022-12-31
#   Unique ID: prathamshi
#   Daily Count: 1
# --------------------------------------------------
# Row 50:
#   Transaction Date: 2023-01-09
#   Unique ID: venishakal
#   Daily Count: 1
# --------------------------------------------------
# Row 51:
#   Transaction Date: 2023-01-13
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 52:
#   Transaction Date: 2023-01-13
#   Unique ID: paytmqr281
#   Daily Count: 2
# --------------------------------------------------
# Row 53:
#   Transaction Date: 2023-01-13
#   Unique ID: q902324096
#   Daily Count: 1
# --------------------------------------------------
# Row 54:
#   Transaction Date: 2023-01-15
#   Unique ID: q66063414@
#   Daily Count: 1
# --------------------------------------------------
# Row 55:
#   Transaction Date: 2023-01-16
#   Unique ID: atharvbhag
#   Daily Count: 1
# --------------------------------------------------
# Row 56:
#   Transaction Date: 2023-01-17
#   Unique ID: XX4470
#   Daily Count: 1
# --------------------------------------------------
# Row 57:
#   Transaction Date: 2023-01-17
#   Unique ID: sonalghola
#   Daily Count: 1
# --------------------------------------------------
# Row 58:
#   Transaction Date: 2023-01-18
#   Unique ID: q611756441
#   Daily Count: 1
# --------------------------------------------------
# Row 59:
#   Transaction Date: 2023-01-19
#   Unique ID: durgaraam6
#   Daily Count: 1
# --------------------------------------------------
# Row 60:
#   Transaction Date: 2023-01-19
#   Unique ID: paytm-6467
#   Daily Count: 1
# --------------------------------------------------
# Row 61:
#   Transaction Date: 2023-01-19
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 62:
#   Transaction Date: 2023-01-21
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 63:
#   Transaction Date: 2023-01-22
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 64:
#   Transaction Date: 2023-01-25
#   Unique ID: aashayj27@
#   Daily Count: 1
# --------------------------------------------------
# Row 65:
#   Transaction Date: 2023-01-28
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 66:
#   Transaction Date: 2023-01-29
#   Unique ID: mab.037322
#   Daily Count: 1
# --------------------------------------------------
# Row 67:
#   Transaction Date: 2023-01-29
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 68:
#   Transaction Date: 2023-02-01
#   Unique ID: sawant.123
#   Daily Count: 1
# --------------------------------------------------
# Row 69:
#   Transaction Date: 2023-02-02
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 70:
#   Transaction Date: 2023-02-07
#   Unique ID: atharvapat
#   Daily Count: 1
# --------------------------------------------------
# Row 71:
#   Transaction Date: 2023-02-12
#   Unique ID: gpay-11193
#   Daily Count: 1
# --------------------------------------------------
# Row 72:
#   Transaction Date: 2023-02-17
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 73:
#   Transaction Date: 2023-02-20
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 74:
#   Transaction Date: 2023-02-22
#   Unique ID: gpay-11193
#   Daily Count: 1
# --------------------------------------------------
# Row 75:
#   Transaction Date: 2023-02-22
#   Unique ID: vinayracha
#   Daily Count: 1
# --------------------------------------------------
# Row 76:
#   Transaction Date: 2023-02-24
#   Unique ID: 7045314562
#   Daily Count: 1
# --------------------------------------------------
# Row 77:
#   Transaction Date: 2023-02-24
#   Unique ID: 8446278122
#   Daily Count: 3
# --------------------------------------------------
# Row 78:
#   Transaction Date: 2023-02-24
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 79:
#   Transaction Date: 2023-02-24
#   Unique ID: pizzahut.2
#   Daily Count: 1
# --------------------------------------------------
# Row 80:
#   Transaction Date: 2023-02-25
#   Unique ID: 9022606953
#   Daily Count: 1
# --------------------------------------------------
# Row 81:
#   Transaction Date: 2023-02-25
#   Unique ID: atharvapat
#   Daily Count: 1
# --------------------------------------------------
# Row 82:
#   Transaction Date: 2023-02-25
#   Unique ID: paytm-4796
#   Daily Count: 1
# --------------------------------------------------
# Row 83:
#   Transaction Date: 2023-02-28
#   Unique ID: storydek45
#   Daily Count: 1
# --------------------------------------------------
# Row 84:
#   Transaction Date: 2023-03-01
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 85:
#   Transaction Date: 2023-03-05
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 86:
#   Transaction Date: 2023-03-05
#   Unique ID: storydek45
#   Daily Count: 1
# --------------------------------------------------
# Row 87:
#   Transaction Date: 2023-03-06
#   Unique ID: farukhpath
#   Daily Count: 1
# --------------------------------------------------
# Row 88:
#   Transaction Date: 2023-03-06
#   Unique ID: q04393494@
#   Daily Count: 1
# --------------------------------------------------
# Row 89:
#   Transaction Date: 2023-03-09
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 90:
#   Transaction Date: 2023-03-09
#   Unique ID: paytmqr281
#   Daily Count: 2
# --------------------------------------------------
# Row 91:
#   Transaction Date: 2023-03-10
#   Unique ID: burgerking
#   Daily Count: 1
# --------------------------------------------------
# Row 92:
#   Transaction Date: 2023-03-13
#   Unique ID: asimshah21
#   Daily Count: 1
# --------------------------------------------------
# Row 93:
#   Transaction Date: 2023-03-14
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 94:
#   Transaction Date: 2023-03-14
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 95:
#   Transaction Date: 2023-03-15
#   Unique ID: q127702016
#   Daily Count: 1
# --------------------------------------------------
# Row 96:
#   Transaction Date: 2023-03-16
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 97:
#   Transaction Date: 2023-03-18
#   Unique ID: techanalog
#   Daily Count: 1
# --------------------------------------------------
# Row 98:
#   Transaction Date: 2023-03-19
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 99:
#   Transaction Date: 2023-03-19
#   Unique ID: prachiswt2
#   Daily Count: 1
# --------------------------------------------------
# Row 100:
#   Transaction Date: 2023-03-21
#   Unique ID: 9860566455
#   Daily Count: 1
# --------------------------------------------------
# Row 101:
#   Transaction Date: 2023-03-21
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 102:
#   Transaction Date: 2023-03-21
#   Unique ID: ruchankada
#   Daily Count: 1
# --------------------------------------------------
# Row 103:
#   Transaction Date: 2023-03-23
#   Unique ID: gpay-11204
#   Daily Count: 1
# --------------------------------------------------
# Row 104:
#   Transaction Date: 2023-03-23
#   Unique ID: jrao15120@
#   Daily Count: 1
# --------------------------------------------------
# Row 105:
#   Transaction Date: 2023-03-24
#   Unique ID: q506304237
#   Daily Count: 1
# --------------------------------------------------
# Row 106:
#   Transaction Date: 2023-03-25
#   Unique ID: fcbizok69u
#   Daily Count: 1
# --------------------------------------------------
# Row 107:
#   Transaction Date: 2023-03-26
#   Unique ID: asimshah21
#   Daily Count: 1
# --------------------------------------------------
# Row 108:
#   Transaction Date: 2023-03-26
#   Unique ID: pulkit3010
#   Daily Count: 1
# --------------------------------------------------
# Row 109:
#   Transaction Date: 2023-03-27
#   Unique ID: shubhamraj
#   Daily Count: 1
# --------------------------------------------------
# Row 110:
#   Transaction Date: 2023-03-29
#   Unique ID: burgerking
#   Daily Count: 1
# --------------------------------------------------
# Row 111:
#   Transaction Date: 2023-03-29
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 112:
#   Transaction Date: 2023-03-31
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 113:
#   Transaction Date: 2023-03-31
#   Unique ID: techanalog
#   Daily Count: 1
# --------------------------------------------------
# Row 114:
#   Transaction Date: 2023-04-01
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 115:
#   Transaction Date: 2023-04-01
#   Unique ID: asimshah21
#   Daily Count: 1
# --------------------------------------------------
# Row 116:
#   Transaction Date: 2023-04-02
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 117:
#   Transaction Date: 2023-04-02
#   Unique ID: prachi2477
#   Daily Count: 1
# --------------------------------------------------
# Row 118:
#   Transaction Date: 2023-04-02
#   Unique ID: prachiswt2
#   Daily Count: 1
# --------------------------------------------------
# Row 119:
#   Transaction Date: 2023-04-03
#   Unique ID: 8446278122
#   Daily Count: 1
# --------------------------------------------------
# Row 120:
#   Transaction Date: 2023-04-03
#   Unique ID: atharvapat
#   Daily Count: 2
# --------------------------------------------------
# Row 121:
#   Transaction Date: 2023-04-03
#   Unique ID: paytm-6467
#   Daily Count: 1
# --------------------------------------------------
# Row 122:
#   Transaction Date: 2023-04-03
#   Unique ID: ss280387-2
#   Daily Count: 1
# --------------------------------------------------
# Row 123:
#   Transaction Date: 2023-04-05
#   Unique ID: nimitsheth
#   Daily Count: 1
# --------------------------------------------------
# Row 124:
#   Transaction Date: 2023-04-05
#   Unique ID: q06492713@
#   Daily Count: 1
# --------------------------------------------------
# Row 125:
#   Transaction Date: 2023-04-06
#   Unique ID: railsbiupi
#   Daily Count: 1
# --------------------------------------------------
# Row 126:
#   Transaction Date: 2023-04-09
#   Unique ID: mcdonaldsi
#   Daily Count: 1
# --------------------------------------------------
# Row 127:
#   Transaction Date: 2023-04-09
#   Unique ID: paytmqr281
#   Daily Count: 3
# --------------------------------------------------
# Row 128:
#   Transaction Date: 2023-04-10
#   Unique ID: paytm-6927
#   Daily Count: 1
# --------------------------------------------------
# Row 129:
#   Transaction Date: 2023-04-10
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 130:
#   Transaction Date: 2023-04-11
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 131:
#   Transaction Date: 2023-04-12
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 132:
#   Transaction Date: 2023-04-13
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 133:
#   Transaction Date: 2023-04-15
#   Unique ID: 9860566455
#   Daily Count: 1
# --------------------------------------------------
# Row 134:
#   Transaction Date: 2023-04-15
#   Unique ID: aashayj27@
#   Daily Count: 1
# --------------------------------------------------
# Row 135:
#   Transaction Date: 2023-04-15
#   Unique ID: ombk.lbfaa
#   Daily Count: 1
# --------------------------------------------------
# Row 136:
#   Transaction Date: 2023-04-17
#   Unique ID: 8446278122
#   Daily Count: 1
# --------------------------------------------------
# Row 137:
#   Transaction Date: 2023-04-20
#   Unique ID: paytm-0401
#   Daily Count: 1
# --------------------------------------------------
# Row 138:
#   Transaction Date: 2023-04-20
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 139:
#   Transaction Date: 2023-04-21
#   Unique ID: paytm-0401
#   Daily Count: 1
# --------------------------------------------------
# Row 140:
#   Transaction Date: 2023-04-21
#   Unique ID: q230851695
#   Daily Count: 1
# --------------------------------------------------
# Row 141:
#   Transaction Date: 2023-04-24
#   Unique ID: 9850344585
#   Daily Count: 1
# --------------------------------------------------
# Row 142:
#   Transaction Date: 2023-04-25
#   Unique ID: 8446278122
#   Daily Count: 1
# --------------------------------------------------
# Row 143:
#   Transaction Date: 2023-04-25
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 144:
#   Transaction Date: 2023-04-25
#   Unique ID: q927921157
#   Daily Count: 1
# --------------------------------------------------
# Row 145:
#   Transaction Date: 2023-04-26
#   Unique ID: paytmqr281
#   Daily Count: 2
# --------------------------------------------------
# Row 146:
#   Transaction Date: 2023-04-26
#   Unique ID: q506304237
#   Daily Count: 1
# --------------------------------------------------
# Row 147:
#   Transaction Date: 2023-04-27
#   Unique ID: dream11@ax
#   Daily Count: 1
# --------------------------------------------------
# Row 148:
#   Transaction Date: 2023-04-27
#   Unique ID: nimishwarg
#   Daily Count: 1
# --------------------------------------------------
# Row 149:
#   Transaction Date: 2023-04-27
#   Unique ID: paramgogia
#   Daily Count: 1
# --------------------------------------------------
# Row 150:
#   Transaction Date: 2023-04-27
#   Unique ID: q840397115
#   Daily Count: 1
# --------------------------------------------------
# Row 151:
#   Transaction Date: 2023-04-27
#   Unique ID: shubhamraj
#   Daily Count: 1
# --------------------------------------------------
# Row 152:
#   Transaction Date: 2023-04-27
#   Unique ID: vihaanshin
#   Daily Count: 1
# --------------------------------------------------
# Row 153:
#   Transaction Date: 2023-04-28
#   Unique ID: Q506304237
#   Daily Count: 1
# --------------------------------------------------
# Row 154:
#   Transaction Date: 2023-04-28
#   Unique ID: gpay-11208
#   Daily Count: 1
# --------------------------------------------------
# Row 155:
#   Transaction Date: 2023-04-29
#   Unique ID: paytmqr1db
#   Daily Count: 1
# --------------------------------------------------
# Row 156:
#   Transaction Date: 2023-04-29
#   Unique ID: q506304237
#   Daily Count: 1
# --------------------------------------------------
# Row 157:
#   Transaction Date: 2023-05-01
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 158:
#   Transaction Date: 2023-05-02
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 159:
#   Transaction Date: 2023-05-03
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 160:
#   Transaction Date: 2023-05-04
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 161:
#   Transaction Date: 2023-05-05
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 162:
#   Transaction Date: 2023-05-06
#   Unique ID: paytmqr281
#   Daily Count: 2
# --------------------------------------------------
# Row 163:
#   Transaction Date: 2023-05-07
#   Unique ID: prachi2477
#   Daily Count: 1
# --------------------------------------------------
# Row 164:
#   Transaction Date: 2023-05-08
#   Unique ID: fcbizok69u
#   Daily Count: 1
# --------------------------------------------------
# Row 165:
#   Transaction Date: 2023-05-09
#   Unique ID: bharatpe09
#   Daily Count: 1
# --------------------------------------------------
# Row 166:
#   Transaction Date: 2023-05-09
#   Unique ID: o111221438
#   Daily Count: 1
# --------------------------------------------------
# Row 167:
#   Transaction Date: 2023-05-09
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 168:
#   Transaction Date: 2023-05-10
#   Unique ID: 7eleven.42
#   Daily Count: 1
# --------------------------------------------------
# Row 169:
#   Transaction Date: 2023-05-10
#   Unique ID: prathamshi
#   Daily Count: 1
# --------------------------------------------------
# Row 170:
#   Transaction Date: 2023-05-10
#   Unique ID: vinayakpbh
#   Daily Count: 1
# --------------------------------------------------
# Row 171:
#   Transaction Date: 2023-05-11
#   Unique ID: q832205277
#   Daily Count: 1
# --------------------------------------------------
# Row 172:
#   Transaction Date: 2023-05-14
#   Unique ID: gpay-11204
#   Daily Count: 1
# --------------------------------------------------
# Row 173:
#   Transaction Date: 2023-05-14
#   Unique ID: paytmqr12u
#   Daily Count: 1
# --------------------------------------------------
# Row 174:
#   Transaction Date: 2023-05-15
#   Unique ID: 8446278122
#   Daily Count: 1
# --------------------------------------------------
# Row 175:
#   Transaction Date: 2023-05-15
#   Unique ID: guptatufan
#   Daily Count: 1
# --------------------------------------------------
# Row 176:
#   Transaction Date: 2023-05-15
#   Unique ID: q812920291
#   Daily Count: 1
# --------------------------------------------------
# Row 177:
#   Transaction Date: 2023-05-15
#   Unique ID: shloksm28-
#   Daily Count: 1
# --------------------------------------------------
# Row 178:
#   Transaction Date: 2023-05-16
#   Unique ID: prathamshi
#   Daily Count: 1
# --------------------------------------------------
# Row 179:
#   Transaction Date: 2023-05-17
#   Unique ID: q378245066
#   Daily Count: 1
# --------------------------------------------------
# Row 180:
#   Transaction Date: 2023-05-18
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 181:
#   Transaction Date: 2023-05-18
#   Unique ID: prajapatii
#   Daily Count: 1
# --------------------------------------------------
# Row 182:
#   Transaction Date: 2023-05-19
#   Unique ID: paramgogia
#   Daily Count: 1
# --------------------------------------------------
# Row 183:
#   Transaction Date: 2023-05-19
#   Unique ID: paytmqrrds
#   Daily Count: 1
# --------------------------------------------------
# Row 184:
#   Transaction Date: 2023-05-19
#   Unique ID: q506304237
#   Daily Count: 1
# --------------------------------------------------
# Row 185:
#   Transaction Date: 2023-05-21
#   Unique ID: paytm-3139
#   Daily Count: 1
# --------------------------------------------------
# Row 186:
#   Transaction Date: 2023-05-21
#   Unique ID: paytmqr281
#   Daily Count: 2
# --------------------------------------------------
# Row 187:
#   Transaction Date: 2023-05-21
#   Unique ID: q250642425
#   Daily Count: 1
# --------------------------------------------------
# Row 188:
#   Transaction Date: 2023-05-21
#   Unique ID: q685983762
#   Daily Count: 1
# --------------------------------------------------
# Row 189:
#   Transaction Date: 2023-05-21
#   Unique ID: q914951432
#   Daily Count: 1
# --------------------------------------------------
# Row 190:
#   Transaction Date: 2023-05-21
#   Unique ID: q997530966
#   Daily Count: 1
# --------------------------------------------------
# Row 191:
#   Transaction Date: 2023-05-22
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 192:
#   Transaction Date: 2023-05-22
#   Unique ID: paytmqrz32
#   Daily Count: 1
# --------------------------------------------------
# Row 193:
#   Transaction Date: 2023-05-23
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 194:
#   Transaction Date: 2023-05-24
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 195:
#   Transaction Date: 2023-05-25
#   Unique ID: paytmqrqio
#   Daily Count: 1
# --------------------------------------------------
# Row 196:
#   Transaction Date: 2023-05-25
#   Unique ID: q506304237
#   Daily Count: 1
# --------------------------------------------------
# Row 197:
#   Transaction Date: 2023-05-26
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 198:
#   Transaction Date: 2023-05-28
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 199:
#   Transaction Date: 2023-05-28
#   Unique ID: prachi2477
#   Daily Count: 1
# --------------------------------------------------
# Row 200:
#   Transaction Date: 2023-05-28
#   Unique ID: sawant.123
#   Daily Count: 2
# --------------------------------------------------
# Row 201:
#   Transaction Date: 2023-05-29
#   Unique ID: 9860566455
#   Daily Count: 1
# --------------------------------------------------
# Row 202:
#   Transaction Date: 2023-05-29
#   Unique ID: paytmqr281
#   Daily Count: 2
# --------------------------------------------------
# Row 203:
#   Transaction Date: 2023-05-29
#   Unique ID: q832205277
#   Daily Count: 1
# --------------------------------------------------
# Row 204:
#   Transaction Date: 2023-05-30
#   Unique ID: q506304237
#   Daily Count: 1
# --------------------------------------------------
# Row 205:
#   Transaction Date: 2023-05-31
#   Unique ID: prajapatii
#   Daily Count: 1
# --------------------------------------------------
# Row 206:
#   Transaction Date: 2023-05-31
#   Unique ID: vihaanshin
#   Daily Count: 1
# --------------------------------------------------
# Row 207:
#   Transaction Date: 2023-06-01
#   Unique ID: paytmqrk49
#   Daily Count: 1
# --------------------------------------------------
# Row 208:
#   Transaction Date: 2023-06-02
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 209:
#   Transaction Date: 2023-06-02
#   Unique ID: aashayj27@
#   Daily Count: 1
# --------------------------------------------------
# Row 210:
#   Transaction Date: 2023-06-02
#   Unique ID: prajapatii
#   Daily Count: 1
# --------------------------------------------------
# Row 211:
#   Transaction Date: 2023-06-02
#   Unique ID: q828771384
#   Daily Count: 1
# --------------------------------------------------
# Row 212:
#   Transaction Date: 2023-06-03
#   Unique ID: shubhamraj
#   Daily Count: 1
# --------------------------------------------------
# Row 213:
#   Transaction Date: 2023-06-05
#   Unique ID: prathamshi
#   Daily Count: 1
# --------------------------------------------------
# Row 214:
#   Transaction Date: 2023-06-06
#   Unique ID: q06492713@
#   Daily Count: 1
# --------------------------------------------------
# Row 215:
#   Transaction Date: 2023-06-06
#   Unique ID: q509313885
#   Daily Count: 1
# --------------------------------------------------
# Row 216:
#   Transaction Date: 2023-06-07
#   Unique ID: burgerking
#   Daily Count: 1
# --------------------------------------------------
# Row 217:
#   Transaction Date: 2023-06-07
#   Unique ID: q846990111
#   Daily Count: 1
# --------------------------------------------------
# Row 218:
#   Transaction Date: 2023-06-08
#   Unique ID: paytmqr1su
#   Daily Count: 1
# --------------------------------------------------
# Row 219:
#   Transaction Date: 2023-06-10
#   Unique ID: bharatpe90
#   Daily Count: 2
# --------------------------------------------------
# Row 220:
#   Transaction Date: 2023-06-10
#   Unique ID: pranhitsla
#   Daily Count: 1
# --------------------------------------------------
# Row 221:
#   Transaction Date: 2023-06-10
#   Unique ID: q260799349
#   Daily Count: 1
# --------------------------------------------------
# Row 222:
#   Transaction Date: 2023-06-10
#   Unique ID: sahebrajya
#   Daily Count: 1
# --------------------------------------------------
# Row 223:
#   Transaction Date: 2023-06-10
#   Unique ID: shubhamraj
#   Daily Count: 1
# --------------------------------------------------
# Row 224:
#   Transaction Date: 2023-06-10
#   Unique ID: vihaanshin
#   Daily Count: 1
# --------------------------------------------------
# Row 225:
#   Transaction Date: 2023-06-10
#   Unique ID: vinayakpbh
#   Daily Count: 1
# --------------------------------------------------
# Row 226:
#   Transaction Date: 2023-06-12
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 227:
#   Transaction Date: 2023-06-15
#   Unique ID: paytm-6210
#   Daily Count: 1
# --------------------------------------------------
# Row 228:
#   Transaction Date: 2023-06-15
#   Unique ID: paytmqr1f4
#   Daily Count: 1
# --------------------------------------------------
# Row 229:
#   Transaction Date: 2023-06-15
#   Unique ID: q846990111
#   Daily Count: 1
# --------------------------------------------------
# Row 230:
#   Transaction Date: 2023-06-16
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 231:
#   Transaction Date: 2023-06-17
#   Unique ID: airtel.pay
#   Daily Count: 1
# --------------------------------------------------
# Row 232:
#   Transaction Date: 2023-06-19
#   Unique ID: paytmqr281
#   Daily Count: 3
# --------------------------------------------------
# Row 233:
#   Transaction Date: 2023-06-19
#   Unique ID: paytmqrrds
#   Daily Count: 1
# --------------------------------------------------
# Row 234:
#   Transaction Date: 2023-06-19
#   Unique ID: q478627637
#   Daily Count: 1
# --------------------------------------------------
# Row 235:
#   Transaction Date: 2023-06-20
#   Unique ID: paytm-6467
#   Daily Count: 1
# --------------------------------------------------
# Row 236:
#   Transaction Date: 2023-06-21
#   Unique ID: XX4470
#   Daily Count: 1
# --------------------------------------------------
# Row 237:
#   Transaction Date: 2023-06-21
#   Unique ID: nazuu458@o
#   Daily Count: 1
# --------------------------------------------------
# Row 238:
#   Transaction Date: 2023-06-21
#   Unique ID: q197901178
#   Daily Count: 1
# --------------------------------------------------
# Row 239:
#   Transaction Date: 2023-06-21
#   Unique ID: q846990111
#   Daily Count: 1
# --------------------------------------------------
# Row 240:
#   Transaction Date: 2023-06-22
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 241:
#   Transaction Date: 2023-06-23
#   Unique ID: paramgogia
#   Daily Count: 1
# --------------------------------------------------
# Row 242:
#   Transaction Date: 2023-06-23
#   Unique ID: q207571625
#   Daily Count: 1
# --------------------------------------------------
# Row 243:
#   Transaction Date: 2023-06-25
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 244:
#   Transaction Date: 2023-07-04
#   Unique ID: sawant.123
#   Daily Count: 1
# --------------------------------------------------
# Row 245:
#   Transaction Date: 2023-07-05
#   Unique ID: pranhitsla
#   Daily Count: 1
# --------------------------------------------------
# Row 246:
#   Transaction Date: 2023-07-06
#   Unique ID: prachiswt2
#   Daily Count: 1
# --------------------------------------------------
# Row 247:
#   Transaction Date: 2023-07-10
#   Unique ID: vihaanshin
#   Daily Count: 1
# --------------------------------------------------
# Row 248:
#   Transaction Date: 2023-07-12
#   Unique ID: pranhitsla
#   Daily Count: 1
# --------------------------------------------------
# Row 249:
#   Transaction Date: 2023-07-13
#   Unique ID: paytm-8736
#   Daily Count: 1
# --------------------------------------------------
# Row 250:
#   Transaction Date: 2023-07-13
#   Unique ID: pranhitsla
#   Daily Count: 2
# --------------------------------------------------
# Row 251:
#   Transaction Date: 2023-07-14
#   Unique ID: airtelprep
#   Daily Count: 1
# --------------------------------------------------
# Row 252:
#   Transaction Date: 2023-07-14
#   Unique ID: prachiswt2
#   Daily Count: 1
# --------------------------------------------------
# Row 253:
#   Transaction Date: 2023-08-02
#   Unique ID: paytmqr281
#   Daily Count: 2
# --------------------------------------------------
# Row 254:
#   Transaction Date: 2023-08-02
#   Unique ID: paytmqr9zc
#   Daily Count: 1
# --------------------------------------------------
# Row 255:
#   Transaction Date: 2023-08-04
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 256:
#   Transaction Date: 2023-08-04
#   Unique ID: q832205277
#   Daily Count: 1
# --------------------------------------------------
# Row 257:
#   Transaction Date: 2023-08-05
#   Unique ID: gpay-11235
#   Daily Count: 1
# --------------------------------------------------
# Row 258:
#   Transaction Date: 2023-08-05
#   Unique ID: paytmqrbgj
#   Daily Count: 1
# --------------------------------------------------
# Row 259:
#   Transaction Date: 2023-08-05
#   Unique ID: pulkit3010
#   Daily Count: 1
# --------------------------------------------------
# Row 260:
#   Transaction Date: 2023-08-06
#   Unique ID: paytm-6634
#   Daily Count: 1
# --------------------------------------------------
# Row 261:
#   Transaction Date: 2023-08-08
#   Unique ID: 9326782947
#   Daily Count: 1
# --------------------------------------------------
# Row 262:
#   Transaction Date: 2023-08-08
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 263:
#   Transaction Date: 2023-08-08
#   Unique ID: gpay-11206
#   Daily Count: 1
# --------------------------------------------------
# Row 264:
#   Transaction Date: 2023-08-08
#   Unique ID: kavankarhi
#   Daily Count: 1
# --------------------------------------------------
# Row 265:
#   Transaction Date: 2023-08-08
#   Unique ID: paytm-5282
#   Daily Count: 1
# --------------------------------------------------
# Row 266:
#   Transaction Date: 2023-08-08
#   Unique ID: paytmqr1rd
#   Daily Count: 1
# --------------------------------------------------
# Row 267:
#   Transaction Date: 2023-08-08
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 268:
#   Transaction Date: 2023-08-08
#   Unique ID: paytmqrlrf
#   Daily Count: 1
# --------------------------------------------------
# Row 269:
#   Transaction Date: 2023-08-08
#   Unique ID: q720539729
#   Daily Count: 1
# --------------------------------------------------
# Row 270:
#   Transaction Date: 2023-08-13
#   Unique ID: XX4470
#   Daily Count: 1
# --------------------------------------------------
# Row 271:
#   Transaction Date: 2023-08-14
#   Unique ID: airtel.pay
#   Daily Count: 1
# --------------------------------------------------
# Row 272:
#   Transaction Date: 2023-08-16
#   Unique ID: paytmqr281
#   Daily Count: 2
# --------------------------------------------------
# Row 273:
#   Transaction Date: 2023-08-16
#   Unique ID: q832205277
#   Daily Count: 1
# --------------------------------------------------
# Row 274:
#   Transaction Date: 2023-08-19
#   Unique ID: Q054867718
#   Daily Count: 1
# --------------------------------------------------
# Row 275:
#   Transaction Date: 2023-08-19
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 276:
#   Transaction Date: 2023-08-19
#   Unique ID: paytm-4776
#   Daily Count: 1
# --------------------------------------------------
# Row 277:
#   Transaction Date: 2023-08-20
#   Unique ID: XX3007
#   Daily Count: 1
# --------------------------------------------------
# Row 278:
#   Transaction Date: 2023-08-21
#   Unique ID: paytm-5645
#   Daily Count: 1
# --------------------------------------------------
# Row 279:
#   Transaction Date: 2023-08-22
#   Unique ID: paytm-8727
#   Daily Count: 1
# --------------------------------------------------
# Row 280:
#   Transaction Date: 2023-08-24
#   Unique ID: Q06492713@
#   Daily Count: 1
# --------------------------------------------------
# Row 281:
#   Transaction Date: 2023-08-27
#   Unique ID: Q197901178
#   Daily Count: 1
# --------------------------------------------------
# Row 282:
#   Transaction Date: 2023-08-27
#   Unique ID: paytm-5645
#   Daily Count: 1
# --------------------------------------------------
# Row 283:
#   Transaction Date: 2023-08-28
#   Unique ID: XX4470
#   Daily Count: 1
# --------------------------------------------------
# Row 284:
#   Transaction Date: 2023-08-30
#   Unique ID: 0791363A00
#   Daily Count: 1
# --------------------------------------------------
# Row 285:
#   Transaction Date: 2023-08-30
#   Unique ID: Q172613173
#   Daily Count: 1
# --------------------------------------------------
# Row 286:
#   Transaction Date: 2023-08-30
#   Unique ID: paytm-6459
#   Daily Count: 1
# --------------------------------------------------
# Row 287:
#   Transaction Date: 2023-08-31
#   Unique ID: pranhitsla
#   Daily Count: 1
# --------------------------------------------------
# Row 288:
#   Transaction Date: 2023-09-01
#   Unique ID: paytm-4274
#   Daily Count: 1
# --------------------------------------------------
# Row 289:
#   Transaction Date: 2023-09-03
#   Unique ID: XX8237
#   Daily Count: 2
# --------------------------------------------------
# Row 290:
#   Transaction Date: 2023-09-03
#   Unique ID: sakshisawa
#   Daily Count: 1
# --------------------------------------------------
# Row 291:
#   Transaction Date: 2023-09-04
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 292:
#   Transaction Date: 2023-09-04
#   Unique ID: pranhitsla
#   Daily Count: 1
# --------------------------------------------------
# Row 293:
#   Transaction Date: 2023-09-04
#   Unique ID: q846990111
#   Daily Count: 1
# --------------------------------------------------
# Row 294:
#   Transaction Date: 2023-09-04
#   Unique ID: railsbiupi
#   Daily Count: 1
# --------------------------------------------------
# Row 295:
#   Transaction Date: 2023-09-05
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 296:
#   Transaction Date: 2023-09-06
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 297:
#   Transaction Date: 2023-09-08
#   Unique ID: paytmqr1wq
#   Daily Count: 1
# --------------------------------------------------
# Row 298:
#   Transaction Date: 2023-09-11
#   Unique ID: airtel.pay
#   Daily Count: 1
# --------------------------------------------------
# Row 299:
#   Transaction Date: 2023-09-12
#   Unique ID: XX4470
#   Daily Count: 1
# --------------------------------------------------
# Row 300:
#   Transaction Date: 2023-09-13
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 301:
#   Transaction Date: 2023-09-15
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 302:
#   Transaction Date: 2023-09-15
#   Unique ID: vinayakpbh
#   Daily Count: 1
# --------------------------------------------------
# Row 303:
#   Transaction Date: 2023-09-18
#   Unique ID: paytmqr1p8
#   Daily Count: 1
# --------------------------------------------------
# Row 304:
#   Transaction Date: 2023-09-18
#   Unique ID: paytmqrjq2
#   Daily Count: 1
# --------------------------------------------------
# Row 305:
#   Transaction Date: 2023-09-18
#   Unique ID: pranhitsla
#   Daily Count: 1
# --------------------------------------------------
# Row 306:
#   Transaction Date: 2023-09-24
#   Unique ID: vinayracha
#   Daily Count: 1
# --------------------------------------------------
# Row 307:
#   Transaction Date: 2023-09-25
#   Unique ID: q840397115
#   Daily Count: 1
# --------------------------------------------------
# Row 308:
#   Transaction Date: 2023-09-27
#   Unique ID: q06492713@
#   Daily Count: 1
# --------------------------------------------------
# Row 309:
#   Transaction Date: 2023-10-01
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 310:
#   Transaction Date: 2023-10-03
#   Unique ID: q990475495
#   Daily Count: 1
# --------------------------------------------------
# Row 311:
#   Transaction Date: 2023-10-04
#   Unique ID: paytmqr1xg
#   Daily Count: 1
# --------------------------------------------------
# Row 312:
#   Transaction Date: 2023-10-04
#   Unique ID: q031373311
#   Daily Count: 1
# --------------------------------------------------
# Row 313:
#   Transaction Date: 2023-10-05
#   Unique ID: 9820588550
#   Daily Count: 1
# --------------------------------------------------
# Row 314:
#   Transaction Date: 2023-10-07
#   Unique ID: paytmqrbgj
#   Daily Count: 1
# --------------------------------------------------
# Row 315:
#   Transaction Date: 2023-10-08
#   Unique ID: sondimpi@o
#   Daily Count: 1
# --------------------------------------------------
# Row 316:
#   Transaction Date: 2023-10-10
#   Unique ID: airtelpaym
#   Daily Count: 1
# --------------------------------------------------
# Row 317:
#   Transaction Date: 2023-10-13
#   Unique ID: aashayj27@
#   Daily Count: 1
# --------------------------------------------------
# Row 318:
#   Transaction Date: 2023-10-16
#   Unique ID: paytmqr1d7
#   Daily Count: 1
# --------------------------------------------------
# Row 319:
#   Transaction Date: 2023-10-16
#   Unique ID: paytmqr1ow
#   Daily Count: 1
# --------------------------------------------------
# Row 320:
#   Transaction Date: 2023-10-16
#   Unique ID: q840397115
#   Daily Count: 1
# --------------------------------------------------
# Row 321:
#   Transaction Date: 2023-10-17
#   Unique ID: vihaanshin
#   Daily Count: 1
# --------------------------------------------------
# Row 322:
#   Transaction Date: 2023-10-19
#   Unique ID: paytmqr7yu
#   Daily Count: 1
# --------------------------------------------------
# Row 323:
#   Transaction Date: 2023-10-20
#   Unique ID: 9370649978
#   Daily Count: 1
# --------------------------------------------------
# Row 324:
#   Transaction Date: 2023-10-20
#   Unique ID: anushkashe
#   Daily Count: 1
# --------------------------------------------------
# Row 325:
#   Transaction Date: 2023-10-21
#   Unique ID: alpharane2
#   Daily Count: 1
# --------------------------------------------------
# Row 326:
#   Transaction Date: 2023-10-21
#   Unique ID: paytmqrwth
#   Daily Count: 1
# --------------------------------------------------
# Row 327:
#   Transaction Date: 2023-10-22
#   Unique ID: 9833252222
#   Daily Count: 1
# --------------------------------------------------
# Row 328:
#   Transaction Date: 2023-10-23
#   Unique ID: paramgogia
#   Daily Count: 1
# --------------------------------------------------
# Row 329:
#   Transaction Date: 2023-10-23
#   Unique ID: sangepuapa
#   Daily Count: 1
# --------------------------------------------------
# Row 330:
#   Transaction Date: 2023-10-25
#   Unique ID: vihaanshin
#   Daily Count: 1
# --------------------------------------------------
# Row 331:
#   Transaction Date: 2023-10-27
#   Unique ID: XX8237
#   Daily Count: 2
# --------------------------------------------------
# Row 332:
#   Transaction Date: 2023-10-27
#   Unique ID: amankanoji
#   Daily Count: 1
# --------------------------------------------------
# Row 333:
#   Transaction Date: 2023-10-28
#   Unique ID: anandsaars
#   Daily Count: 1
# --------------------------------------------------
# Row 334:
#   Transaction Date: 2023-10-28
#   Unique ID: paytm-6467
#   Daily Count: 1
# --------------------------------------------------
# Row 335:
#   Transaction Date: 2023-10-30
#   Unique ID: q06492713@
#   Daily Count: 1
# --------------------------------------------------
# Row 336:
#   Transaction Date: 2023-10-30
#   Unique ID: shubhamraj
#   Daily Count: 1
# --------------------------------------------------
# Row 337:
#   Transaction Date: 2023-10-31
#   Unique ID: bharatpe90
#   Daily Count: 1
# --------------------------------------------------
# Row 338:
#   Transaction Date: 2023-10-31
#   Unique ID: jayashreer
#   Daily Count: 1
# --------------------------------------------------
# Row 339:
#   Transaction Date: 2023-10-31
#   Unique ID: paytmqrz2t
#   Daily Count: 1
# --------------------------------------------------
# Row 340:
#   Transaction Date: 2023-11-04
#   Unique ID: paytmqr12u
#   Daily Count: 2
# --------------------------------------------------
# Row 341:
#   Transaction Date: 2023-11-05
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 342:
#   Transaction Date: 2023-11-05
#   Unique ID: paytmqr15c
#   Daily Count: 1
# --------------------------------------------------
# Row 343:
#   Transaction Date: 2023-11-05
#   Unique ID: paytmqrbgj
#   Daily Count: 1
# --------------------------------------------------
# Row 344:
#   Transaction Date: 2023-11-05
#   Unique ID: q554757059
#   Daily Count: 1
# --------------------------------------------------
# Row 345:
#   Transaction Date: 2023-11-05
#   Unique ID: sawant.123
#   Daily Count: 1
# --------------------------------------------------
# Row 346:
#   Transaction Date: 2023-11-06
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 347:
#   Transaction Date: 2023-11-07
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 348:
#   Transaction Date: 2023-11-07
#   Unique ID: airtelprep
#   Daily Count: 1
# --------------------------------------------------
# Row 349:
#   Transaction Date: 2023-11-07
#   Unique ID: paytmqr1hs
#   Daily Count: 1
# --------------------------------------------------
# Row 350:
#   Transaction Date: 2023-11-12
#   Unique ID: airtelprep
#   Daily Count: 1
# --------------------------------------------------
# Row 351:
#   Transaction Date: 2023-11-16
#   Unique ID: paytmqrz2t
#   Daily Count: 1
# --------------------------------------------------
# Row 352:
#   Transaction Date: 2023-11-16
#   Unique ID: paytmqrzvz
#   Daily Count: 1
# --------------------------------------------------
# Row 353:
#   Transaction Date: 2023-11-16
#   Unique ID: rk0381207@
#   Daily Count: 1
# --------------------------------------------------
# Row 354:
#   Transaction Date: 2023-11-17
#   Unique ID: q669621831
#   Daily Count: 1
# --------------------------------------------------
# Row 355:
#   Transaction Date: 2023-11-22
#   Unique ID: q193497060
#   Daily Count: 1
# --------------------------------------------------
# Row 356:
#   Transaction Date: 2023-11-23
#   Unique ID: 8446278122
#   Daily Count: 1
# --------------------------------------------------
# Row 357:
#   Transaction Date: 2023-11-24
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 358:
#   Transaction Date: 2023-11-24
#   Unique ID: paytmqrzvz
#   Daily Count: 1
# --------------------------------------------------
# Row 359:
#   Transaction Date: 2023-11-24
#   Unique ID: q669621831
#   Daily Count: 1
# --------------------------------------------------
# Row 360:
#   Transaction Date: 2023-11-27
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 361:
#   Transaction Date: 2023-11-28
#   Unique ID: aashayj27@
#   Daily Count: 1
# --------------------------------------------------
# Row 362:
#   Transaction Date: 2023-11-28
#   Unique ID: atharvahav
#   Daily Count: 1
# --------------------------------------------------
# Row 363:
#   Transaction Date: 2023-11-28
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 364:
#   Transaction Date: 2023-11-29
#   Unique ID: vihaanshin
#   Daily Count: 1
# --------------------------------------------------
# Row 365:
#   Transaction Date: 2023-12-01
#   Unique ID: 9619877179
#   Daily Count: 1
# ...
#   Daily Count: 1
# --------------------------------------------------
# Row 530:
#   Transaction Date: 2024-06-26
#   Unique ID: paytmqr1jc
#   Daily Count: 1
# --------------------------------------------------
# Row 531:
#   Transaction Date: 2024-06-26
#   Unique ID: sisinty795
#   Daily Count: 1
# --------------------------------------------------
# Row 532:
#   Transaction Date: 2024-06-30
#   Unique ID: XX9209
#   Daily Count: 2
# --------------------------------------------------
# Row 533:
#   Transaction Date: 2024-06-30
#   Unique ID: prathamshi
#   Daily Count: 1
# --------------------------------------------------
# Row 534:
#   Transaction Date: 2024-06-30
#   Unique ID: shubhamraj
#   Daily Count: 1
# --------------------------------------------------
# Row 535:
#   Transaction Date: 2024-06-30
#   Unique ID: vihaanshin
#   Daily Count: 1
# --------------------------------------------------
# Row 536:
#   Transaction Date: 2024-07-01
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 537:
#   Transaction Date: 2024-07-01
#   Unique ID: q699866917
#   Daily Count: 1
# --------------------------------------------------
# Row 538:
#   Transaction Date: 2024-07-02
#   Unique ID: airtelprep
#   Daily Count: 1
# --------------------------------------------------
# Row 539:
#   Transaction Date: 2024-07-03
#   Unique ID: paytmqr1jc
#   Daily Count: 1
# --------------------------------------------------
# Row 540:
#   Transaction Date: 2024-07-05
#   Unique ID: XX8237
#   Daily Count: 1
# --------------------------------------------------
# Row 541:
#   Transaction Date: 2024-07-08
#   Unique ID: mcdonaldsi
#   Daily Count: 1
# --------------------------------------------------
# Row 542:
#   Transaction Date: 2024-07-09
#   Unique ID: airtel-rec
#   Daily Count: 1
# --------------------------------------------------
# Row 543:
#   Transaction Date: 2024-07-09
#   Unique ID: netflixupi
#   Daily Count: 1
# --------------------------------------------------
# Row 544:
#   Transaction Date: 2024-07-09
#   Unique ID: prachi2477
#   Daily Count: 1
# --------------------------------------------------
# Row 545:
#   Transaction Date: 2024-07-11
#   Unique ID: paytmqr14k
#   Daily Count: 1
# --------------------------------------------------
# Row 546:
#   Transaction Date: 2024-07-13
#   Unique ID: paytmqr1d4
#   Daily Count: 1
# --------------------------------------------------
# Row 547:
#   Transaction Date: 2024-07-13
#   Unique ID: prachi2477
#   Daily Count: 1
# --------------------------------------------------
# Row 548:
#   Transaction Date: 2024-07-14
#   Unique ID: XX4470
#   Daily Count: 1
# --------------------------------------------------
# Row 549:
#   Transaction Date: 2024-07-14
#   Unique ID: paytmqr1jc
#   Daily Count: 1
# --------------------------------------------------
# Row 550:
#   Transaction Date: 2024-07-14
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 551:
#   Transaction Date: 2024-07-14
#   Unique ID: spit.easeb
#   Daily Count: 1
# --------------------------------------------------
# Row 552:
#   Transaction Date: 2024-07-18
#   Unique ID: sawant.123
#   Daily Count: 1
# --------------------------------------------------
# Row 553:
#   Transaction Date: 2024-07-20
#   Unique ID: airtel-pre
#   Daily Count: 1
# --------------------------------------------------
# Row 554:
#   Transaction Date: 2024-07-25
#   Unique ID: paytmqr1jc
#   Daily Count: 1
# --------------------------------------------------
# Row 555:
#   Transaction Date: 2024-07-25
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 556:
#   Transaction Date: 2024-07-25
#   Unique ID: paytmqr56u
#   Daily Count: 1
# --------------------------------------------------
# Row 557:
#   Transaction Date: 2024-07-31
#   Unique ID: paytmqr1jc
#   Daily Count: 1
# --------------------------------------------------
# Row 558:
#   Transaction Date: 2024-07-31
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 559:
#   Transaction Date: 2024-07-31
#   Unique ID: prachi2477
#   Daily Count: 1
# --------------------------------------------------
# Row 560:
#   Transaction Date: 2024-08-01
#   Unique ID: ICI-XX237-SAMEER B
#   Daily Count: 1
# --------------------------------------------------
# Row 561:
#   Transaction Date: 2024-08-01
#   Unique ID: paytm-8727
#   Daily Count: 1
# --------------------------------------------------
# Row 562:
#   Transaction Date: 2024-08-02
#   Unique ID: alpharane2
#   Daily Count: 2
# --------------------------------------------------
# Row 563:
#   Transaction Date: 2024-08-02
#   Unique ID: chettiarpr
#   Daily Count: 1
# --------------------------------------------------
# Row 564:
#   Transaction Date: 2024-08-02
#   Unique ID: csmvscurre
#   Daily Count: 1
# --------------------------------------------------
# Row 565:
#   Transaction Date: 2024-08-02
#   Unique ID: railsbiupi
#   Daily Count: 1
# --------------------------------------------------
# Row 566:
#   Transaction Date: 2024-08-04
#   Unique ID: RE1-XX470-SAMEER B
#   Daily Count: 1
# --------------------------------------------------
# Row 567:
#   Transaction Date: 2024-08-05
#   Unique ID: paytmqr1di
#   Daily Count: 1
# --------------------------------------------------
# Row 568:
#   Transaction Date: 2024-08-05
#   Unique ID: railsbiupi
#   Daily Count: 2
# --------------------------------------------------
# Row 569:
#   Transaction Date: 2024-08-06
#   Unique ID: q060864871
#   Daily Count: 1
# --------------------------------------------------
# Row 570:
#   Transaction Date: 2024-08-06
#   Unique ID: q898155370
#   Daily Count: 1
# --------------------------------------------------
# Row 571:
#   Transaction Date: 2024-08-07
#   Unique ID: paytmqr15v
#   Daily Count: 1
# --------------------------------------------------
# Row 572:
#   Transaction Date: 2024-08-08
#   Unique ID: ICI-XX237-SAMEER B
#   Daily Count: 1
# --------------------------------------------------
# Row 573:
#   Transaction Date: 2024-08-11
#   Unique ID: ICI-XX237-SAMEER B
#   Daily Count: 1
# --------------------------------------------------
# Row 574:
#   Transaction Date: 2024-08-11
#   Unique ID: sakshisawa
#   Daily Count: 1
# --------------------------------------------------
# Row 575:
#   Transaction Date: 2024-08-11
#   Unique ID: swayamnpte
#   Daily Count: 1
# --------------------------------------------------
# Row 576:
#   Transaction Date: 2024-08-12
#   Unique ID: q09778271@
#   Daily Count: 1
# --------------------------------------------------
# Row 577:
#   Transaction Date: 2024-08-13
#   Unique ID: paytmqr15v
#   Daily Count: 1
# --------------------------------------------------
# Row 578:
#   Transaction Date: 2024-08-13
#   Unique ID: paytmqr1c1
#   Daily Count: 1
# --------------------------------------------------
# Row 579:
#   Transaction Date: 2024-08-13
#   Unique ID: paytmqr3w5
#   Daily Count: 1
# --------------------------------------------------
# Row 580:
#   Transaction Date: 2024-08-16
#   Unique ID: mcdonalds.
#   Daily Count: 1
# --------------------------------------------------
# Row 581:
#   Transaction Date: 2024-08-18
#   Unique ID: airtelprep
#   Daily Count: 1
# --------------------------------------------------
# Row 582:
#   Transaction Date: 2024-08-18
#   Unique ID: prachi2477
#   Daily Count: 1
# --------------------------------------------------
# Row 583:
#   Transaction Date: 2024-08-19
#   Unique ID: paytmqr1xg
#   Daily Count: 1
# --------------------------------------------------
# Row 584:
#   Transaction Date: 2024-08-19
#   Unique ID: paytmqr5an
#   Daily Count: 1
# --------------------------------------------------
# Row 585:
#   Transaction Date: 2024-08-23
#   Unique ID: paytmqruee
#   Daily Count: 1
# --------------------------------------------------
# Row 586:
#   Transaction Date: 2024-08-30
#   Unique ID: prathamshi
#   Daily Count: 1
# --------------------------------------------------
# Row 587:
#   Transaction Date: 2024-09-02
#   Unique ID: burgerking
#   Daily Count: 1
# --------------------------------------------------
# Row 588:
#   Transaction Date: 2024-09-02
#   Unique ID: q480748453
#   Daily Count: 1
# --------------------------------------------------
# Row 589:
#   Transaction Date: 2024-09-07
#   Unique ID: ICI-XX237-SAMEER B
#   Daily Count: 1
# --------------------------------------------------
# Row 590:
#   Transaction Date: 2024-09-07
#   Unique ID: prachi2477
#   Daily Count: 1
# --------------------------------------------------
# Row 591:
#   Transaction Date: 2024-09-09
#   Unique ID: paytmqruee
#   Daily Count: 1
# --------------------------------------------------
# Row 592:
#   Transaction Date: 2024-09-13
#   Unique ID: airtelprep
#   Daily Count: 1
# --------------------------------------------------
# Row 593:
#   Transaction Date: 2024-09-14
#   Unique ID: airtelprep
#   Daily Count: 1
# --------------------------------------------------
# Row 594:
#   Transaction Date: 2024-09-17
#   Unique ID: RE1-XX470-SAMEER B
#   Daily Count: 1
# --------------------------------------------------
# Row 595:
#   Transaction Date: 2024-09-17
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 596:
#   Transaction Date: 2024-09-17
#   Unique ID: paytmqr56u
#   Daily Count: 1
# --------------------------------------------------
# Row 597:
#   Transaction Date: 2024-09-17
#   Unique ID: q060864871
#   Daily Count: 1
# --------------------------------------------------
# Row 598:
#   Transaction Date: 2024-09-18
#   Unique ID: bharatpe.8
#   Daily Count: 1
# --------------------------------------------------
# Row 599:
#   Transaction Date: 2024-09-19
#   Unique ID: paytmqr1bi
#   Daily Count: 1
# --------------------------------------------------
# Row 600:
#   Transaction Date: 2024-09-19
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 601:
#   Transaction Date: 2024-09-19
#   Unique ID: paytmqr3w5
#   Daily Count: 1
# --------------------------------------------------
# Row 602:
#   Transaction Date: 2024-09-19
#   Unique ID: q480748453
#   Daily Count: 1
# --------------------------------------------------
# Row 603:
#   Transaction Date: 2024-09-20
#   Unique ID: paytmqr14h
#   Daily Count: 1
# --------------------------------------------------
# Row 604:
#   Transaction Date: 2024-09-24
#   Unique ID: paytmqr3w5
#   Daily Count: 1
# --------------------------------------------------
# Row 605:
#   Transaction Date: 2024-09-24
#   Unique ID: q698438155
#   Daily Count: 1
# --------------------------------------------------
# Row 606:
#   Transaction Date: 2024-09-25
#   Unique ID: paytmqr5cb
#   Daily Count: 1
# --------------------------------------------------
# Row 607:
#   Transaction Date: 2024-09-28
#   Unique ID: ICI-XX237-SAMEER B
#   Daily Count: 1
# --------------------------------------------------
# Row 608:
#   Transaction Date: 2024-09-28
#   Unique ID: alpharane2
#   Daily Count: 1
# --------------------------------------------------
# Row 609:
#   Transaction Date: 2024-09-28
#   Unique ID: paytmqr5cb
#   Daily Count: 1
# --------------------------------------------------
# Row 610:
#   Transaction Date: 2024-09-29
#   Unique ID: viacom18on
#   Daily Count: 1
# --------------------------------------------------
# Row 611:
#   Transaction Date: 2024-10-01
#   Unique ID: ICI-XX237-SAMEER B
#   Daily Count: 1
# --------------------------------------------------
# Row 612:
#   Transaction Date: 2024-10-03
#   Unique ID: prachi2477
#   Daily Count: 1
# --------------------------------------------------
# Row 613:
#   Transaction Date: 2024-10-03
#   Unique ID: q582445006
#   Daily Count: 1
# --------------------------------------------------
# Row 614:
#   Transaction Date: 2024-10-03
#   Unique ID: q674889682
#   Daily Count: 1
# --------------------------------------------------
# Row 615:
#   Transaction Date: 2024-10-04
#   Unique ID: mcdonalds.
#   Daily Count: 1
# --------------------------------------------------
# Row 616:
#   Transaction Date: 2024-10-05
#   Unique ID: paytmqr5dq
#   Daily Count: 1
# --------------------------------------------------
# Row 617:
#   Transaction Date: 2024-10-06
#   Unique ID: RE1-XX470-SAMEER B
#   Daily Count: 1
# --------------------------------------------------
# Row 618:
#   Transaction Date: 2024-10-08
#   Unique ID: paytmqr14k
#   Daily Count: 1
# --------------------------------------------------
# Row 619:
#   Transaction Date: 2024-10-09
#   Unique ID: q480748453
#   Daily Count: 1
# --------------------------------------------------
# Row 620:
#   Transaction Date: 2024-10-10
#   Unique ID: q591263088
#   Daily Count: 1
# --------------------------------------------------
# Row 621:
#   Transaction Date: 2024-10-11
#   Unique ID: airtelprep
#   Daily Count: 1
# --------------------------------------------------
# Row 622:
#   Transaction Date: 2024-10-11
#   Unique ID: vihaanshin
#   Daily Count: 1
# --------------------------------------------------
# Row 623:
#   Transaction Date: 2024-10-12
#   Unique ID: ICI-XX237-SAMEER B
#   Daily Count: 1
# --------------------------------------------------
# Row 624:
#   Transaction Date: 2024-10-12
#   Unique ID: RE1-XX470-SAMEER B
#   Daily Count: 1
# --------------------------------------------------
# Row 625:
#   Transaction Date: 2024-10-12
#   Unique ID: airtelprep
#   Daily Count: 1
# --------------------------------------------------
# Row 626:
#   Transaction Date: 2024-10-12
#   Unique ID: pantaloons
#   Daily Count: 1
# --------------------------------------------------
# Row 627:
#   Transaction Date: 2024-10-12
#   Unique ID: paytmqr281
#   Daily Count: 1
# --------------------------------------------------
# Row 628:
#   Transaction Date: 2024-10-12
#   Unique ID: q17788785@
#   Daily Count: 1
# --------------------------------------------------
# Row 629:
#   Transaction Date: 2024-10-12
#   Unique ID: q641304611
#   Daily Count: 1
# --------------------------------------------------
# Row 630:
#   Transaction Date: 2024-10-12
#   Unique ID: starbazaar
#   Daily Count: 2
# --------------------------------------------------
# Row 631:
#   Transaction Date: 2024-10-13
#   Unique ID: shubhamraj
#   Daily Count: 1
# --------------------------------------------------
# Row 632:
#   Transaction Date: 2024-10-17
#   Unique ID: vihaanshin
#   Daily Count: 1
# --------------------------------------------------
# Row 633:
#   Transaction Date: 2024-10-18
#   Unique ID: paytmqr593
#   Daily Count: 1
# --------------------------------------------------
# Row 634:
#   Transaction Date: 2024-10-23
#   Unique ID: ICI-XX237-SAMEER B
#   Daily Count: 1
# --------------------------------------------------
# Row 635:
#   Transaction Date: 2024-10-24
#   Unique ID: 8850949354
#   Daily Count: 1
# --------------------------------------------------
# Row 636:
#   Transaction Date: 2024-10-24
#   Unique ID: vihaanshin
#   Daily Count: 1
# --------------------------------------------------
# Row 637:
#   Transaction Date: 2024-10-25
#   Unique ID: bharatpe9h
#   Daily Count: 1
# --------------------------------------------------
# Row 638:
#   Transaction Date: 2024-10-25
#   Unique ID: jayashreer
#   Daily Count: 1
# --------------------------------------------------
# Row 639:
#   Transaction Date: 2024-10-26
#   Unique ID: sanjay.gup
#   Daily Count: 1
# --------------------------------------------------
# Row 640:
#   Transaction Date: 2024-10-30
#   Unique ID: prachi2477
#   Daily Count: 2
# --------------------------------------------------
# Row 641:
#   Transaction Date: 2024-10-30
#   Unique ID: viacom18on
#   Daily Count: 1
# --------------------------------------------------
# Row 642:
#   Transaction Date: 2024-10-30
#   Unique ID: zomatoorde
#   Daily Count: 1
# --------------------------------------------------
# Row 643:
#   Transaction Date: 2024-10-31
#   Unique ID: q122854506
#   Daily Count: 1
# --------------------------------------------------
# Row 644:
#   Transaction Date: 2024-11-01
#   Unique ID: paytmqr1c1
#   Daily Count: 1
# --------------------------------------------------
# Row 645:
#   Transaction Date: 2024-11-04
#   Unique ID: sawant.123
#   Daily Count: 1
# --------------------------------------------------
# Row 646:
#   Transaction Date: 2024-11-04
#   Unique ID: zomatoorde
#   Daily Count: 1
# --------------------------------------------------
# Row 647:
#   Transaction Date: 2024-11-05
#   Unique ID: paytmqr5wr
#   Daily Count: 1
# --------------------------------------------------
# Row 648:
#   Transaction Date: 2024-11-05
#   Unique ID: shinderayc
#   Daily Count: 1
# --------------------------------------------------
# Row 649:
#   Transaction Date: 2024-11-06
#   Unique ID: 8850949354
#   Daily Count: 1
# --------------------------------------------------
